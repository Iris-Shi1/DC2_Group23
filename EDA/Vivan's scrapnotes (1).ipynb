# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from tqdm import tqdm

# %%
MPS_df = pd.read_excel("../project_data/PAS_T&Cdashboard_to Q3 23-24.xlsx",  sheet_name='MPS')
Borough_df = pd.read_excel("../project_data/PAS_T&Cdashboard_to Q3 23-24.xlsx", sheet_name='Borough')
Borough_df = Borough_df.loc[:, ~Borough_df.columns.str.contains('^Unnamed')]
MPS_df
# Out:
#           Date Survey Borough                Measure  Proportion
# 0   2014-12-31    PAS     MPS       "Good Job" local        0.67
# 1   2014-12-31    PAS     MPS   Contact ward officer        0.41
# 2   2014-12-31    PAS     MPS         Informed local        0.49
# 3   2014-12-31    PAS     MPS     Listen to concerns        0.74
# 4   2014-12-31    PAS     MPS  Relied on to be there        0.77
# ..         ...    ...     ...                    ...         ...
# 286 2023-12-31    PAS     MPS     Listen to concerns        0.57
# 287 2023-12-31    PAS     MPS  Relied on to be there        0.59
# 288 2023-12-31    PAS     MPS  Treat everyone fairly        0.62
# 289 2023-12-31    PAS     MPS              Trust MPS        0.69
# 290 2023-12-31    PAS     MPS      Understand issues        0.57
#
# [291 rows x 5 columns]

# %%
all_measures = set(Borough_df['Measure'].to_list())
all_measures
# Out:
# {'"Good Job" local',
#  'Contact ward officer',
#  'Informed local',
#  'Listen to concerns',
#  'Relied on to be there',
#  'Treat everyone fairly',
#  'Trust MPS',
#  'Understand issues'}

# %%
all_borough = set(Borough_df['Borough'].to_list())
all_borough
# Out:
# {'Barking and Dagenham',
#  'Barnet',
#  'Bexley',
#  'Brent',
#  'Bromley',
#  'Camden',
#  'City of Westminster',
#  'Croydon',
#  'Ealing',
#  'Enfield',
#  'Greenwich',
#  'Hackney',
#  'Hammersmith and Fulham',
#  'Haringey',
#  'Harrow',
#  'Havering',
#  'Hillingdon',
#  'Hounslow',
#  'Islington',
#  'Kensington and Chelsea',
#  'Kingston upon Thames',
#  'Lambeth',
#  'Lewisham',
#  'Merton',
#  'Newham',
#  'Redbridge',
#  'Richmond Upon Thames',
#  'Richmond upon Thames',
#  'Southwark',
#  'Sutton',
#  'Tower Hamlets',
#  'Waltham Forest',
#  'Wandsworth'}

# %%
# Group by Date and Measure, then calculate the average proportion for each quarter and measure
average_proportion = Borough_df.groupby(['Date', 'Measure'])['Proportion'].mean().reset_index()

# Line plot for the average proportion of each measure over time
plt.figure(figsize=(12, 6))

# Iterate over each measure
for measure_name, data in average_proportion.groupby('Measure'):
    plt.plot(data['Date'], data['Proportion'], label=measure_name)

plt.title('Average Proportion of Each Measure over Time')
plt.xlabel('Date')
plt.ylabel('Average Proportion')
plt.xticks(rotation=45)
plt.legend(title='Measure')
plt.grid(True)
plt.show()

# %%
# Bar plot for average Proportion by Measure
plt.figure(figsize=(12, 6))
sns.barplot(x='Measure', y='Proportion', data=Borough_df)
plt.title('Average Proportion by Measure')
plt.xlabel('Measure')
plt.ylabel('Average Proportion')
plt.xticks(rotation=45)
plt.show()

# %%
# Filter the DataFrame for a specific measure
measure_name = 'Trust MPS'
measure_df = Borough_df[Borough_df['Measure'] == measure_name]

# Line plot for the proportion of the chosen measure in different boroughs over time
average_proportion = measure_df.groupby('Date')['Proportion'].mean().reset_index()

# Line plot for the average proportion of the chosen measure over time
plt.figure(figsize=(12, 6))
plt.plot(average_proportion['Date'], average_proportion['Proportion'], marker='o', linestyle='-')
plt.title(f'Average Proportion of {measure_name} over Time')
plt.xlabel('Date')
plt.ylabel('Average Proportion')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Extract year from the 'Date' column
measure_df['Year'] = measure_df['Date'].dt.year

# Aggregate the data by year and borough, calculating the mean proportion
yearly_data = measure_df.groupby(['Year', 'Borough']).mean().reset_index()
# Out:
# C:\Users\ambra\AppData\Local\Temp\ipykernel_10816\3257201463.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   measure_df['Year'] = measure_df['Date'].dt.year
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'PASPASPASPAS' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 5
#       2 measure_df['Year'] = measure_df['Date'].dt.year
#       4 # Aggregate the data by year and borough, calculating the mean proportion
# ----> 5 yearly_data = measure_df.groupby(['Year', 'Borough']).mean().reset_index()
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File ~\PycharmProjects\DC2_Group23\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
year_to_visualize = 2022 
measure_name = 'Trust MPS'

# Filter the data for the specified year and measure
filtered_df = Borough_df[(Borough_df['Date'].dt.year == year_to_visualize) & (Borough_df['Measure'] == measure_name)]

# Bar plot for the proportion of the chosen measure in different boroughs for the specified year
plt.figure(figsize=(12, 6))
sns.barplot(x='Borough', y='Proportion', data=filtered_df)
plt.title(f'Proportion of {measure_name} by Borough in {year_to_visualize}')
plt.xlabel('Borough')
plt.ylabel('Proportion')
plt.xticks(rotation=45)
plt.show()

# %%
measures_data = Borough_df[['Borough','Measure', 'Proportion']]

# Pivot the DataFrame to have measures as columns and Borough as index
pivot_data = measures_data.pivot_table(index='Borough', columns='Measure', values='Proportion')

# Calculate the correlation matrix
correlation_matrix = pivot_data.corr()

# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Acceptance Rates for Different Measures')
plt.xlabel('Measure')
plt.ylabel('Measure')
plt.show()

# %%
Borough_df.columns
# Out:
# Index(['Date', 'Survey', 'Borough', 'Measure', 'Proportion', 'MPS'], dtype='object')

# %%
Borough_df['Date']
# Out:
# 0      2014-12-31
# 1      2014-12-31
# 2      2014-12-31
# 3      2014-12-31
# 4      2014-12-31
#           ...
# 9307   2023-12-31
# 9308   2023-12-31
# 9309   2023-12-31
# 9310   2023-12-31
# 9311   2023-12-31
# Name: Date, Length: 9312, dtype: datetime64[ns]

# %%
Borough_df['Date'] = pd.to_datetime(Borough_df['Date'], format='%d/%m/%Y')
Borough_df['month'] = Borough_df['Date'].dt.strftime('%b')
Borough_df['month']
# Out:
# 0       Dec
# 1       Dec
# 2       Dec
# 3       Dec
# 4       Dec
#        ...
# 9307    Dec
# 9308    Dec
# 9309    Dec
# 9310    Dec
# 9311    Dec
# Name: month, Length: 9312, dtype: object

# %%
# Convert 'Date' column to datetime format
Borough_df['Date'] = pd.to_datetime(Borough_df['Date'], format='%d/%m/%Y')

# Extract month and store it in a new column 'Month'
Borough_df['Month'] = Borough_df['Date'].dt.strftime('%b')

# Specify the year and measure to visualize
year_to_visualize = 2022
measure_name = 'Trust MPS'

# Filter the data for the specified year and measure
filtered_df = Borough_df[(Borough_df['Date'].dt.year == year_to_visualize) & (Borough_df['Measure'] == measure_name)]

# Bar plot for average Proportion by Measure
plt.figure(figsize=(12, 6))
sns.barplot(x='month', y='Proportion', data=filtered_df)  # Use 'month' instead of 'Month'
plt.title(f'Average Proportion of {measure_name} in {year_to_visualize} by Month')
plt.xlabel('Month')
plt.ylabel('Average Proportion')
plt.xticks(rotation=45)
plt.show()

# %%
filtered_df
# Out:
#            Date Survey               Borough    Measure  Proportion   MPS  \
# 7488 2022-03-31    PAS  Barking and Dagenham  Trust MPS        0.77  0.73
# 7489 2022-03-31    PAS                Barnet  Trust MPS        0.77  0.73
# 7490 2022-03-31    PAS                Bexley  Trust MPS        0.79  0.73
# 7491 2022-03-31    PAS                 Brent  Trust MPS        0.78  0.73
# 7492 2022-03-31    PAS               Bromley  Trust MPS        0.75  0.73
# ...         ...    ...                   ...        ...         ...   ...
# 8059 2022-12-31    PAS                Sutton  Trust MPS        0.80  0.71
# 8060 2022-12-31    PAS         Tower Hamlets  Trust MPS        0.68  0.71
# 8061 2022-12-31    PAS        Waltham Forest  Trust MPS        0.64  0.71
# 8062 2022-12-31    PAS            Wandsworth  Trust MPS        0.71  0.71
# 8063 2022-12-31    PAS   City of Westminster  Trust MPS        0.74  0.71
#
#      month Month
# 7488   Mar   Mar
# 7489   Mar   Mar
# 7490   Mar   Mar
# 7491   Mar   Mar
# 7492   Mar   Mar
# ...    ...   ...
# 8059   Dec   Dec
# 8060   Dec   Dec
# 8061   Dec   Dec
# 8062   Dec   Dec
# 8063   Dec   Dec
#
# [128 rows x 8 columns]

# %%
# for year_to_visualize in [2014,2023]
MPS_2016 = Borough_df[(Borough_df['Date'].dt.year == 2016) & (Borough_df['Date'].dt.month == 3) & (Borough_df['Measure'] == measure_name)]
MPS_2022 = Borough_df[(Borough_df['Date'].dt.year == 2022) & (Borough_df['Date'].dt.month == 12) & (Borough_df['Measure'] == measure_name)]

Dif_2022 = MPS_2022['Proportion'].to_list()
Dif_2016 = MPS_2016['Proportion'].to_list()

# %%
MPS_2016
# Out:
#            Date Survey                 Borough    Measure  Proportion   MPS  \
# 6720 2016-03-31    PAS    Barking and Dagenham  Trust MPS        0.83  0.86
# 6721 2016-03-31    PAS                  Barnet  Trust MPS        0.87  0.86
# 6722 2016-03-31    PAS                  Bexley  Trust MPS        0.90  0.86
# 6723 2016-03-31    PAS                   Brent  Trust MPS        0.83  0.86
# 6724 2016-03-31    PAS                 Bromley  Trust MPS        0.88  0.86
# 6725 2016-03-31    PAS                  Camden  Trust MPS        0.84  0.86
# 6726 2016-03-31    PAS                 Croydon  Trust MPS        0.82  0.86
# 6727 2016-03-31    PAS                  Ealing  Trust MPS        0.86  0.86
# 6728 2016-03-31    PAS                 Enfield  Trust MPS        0.77  0.86
# 6729 2016-03-31    PAS               Greenwich  Trust MPS        0.86  0.86
# 6730 2016-03-31    PAS                 Hackney  Trust MPS        0.82  0.86
# 6731 2016-03-31    PAS  Hammersmith and Fulham  Trust MPS        0.92  0.86
# 6732 2016-03-31    PAS                Haringey  Trust MPS        0.82  0.86
# 6733 2016-03-31    PAS                  Harrow  Trust MPS        0.86  0.86
# 6734 2016-03-31    PAS                Havering  Trust MPS        0.92  0.86
# 6735 2016-03-31    PAS              Hillingdon  Trust MPS        0.84  0.86
# 6736 2016-03-31    PAS                Hounslow  Trust MPS        0.87  0.86
# 6737 2016-03-31    PAS               Islington  Trust MPS        0.88  0.86
# 6738 2016-03-31    PAS  Kensington and Chelsea  Trust MPS        0.92  0.86
# 6739 2016-03-31    PAS    Kingston upon Thames  Trust MPS        0.89  0.86
# 6740 2016-03-31    PAS                 Lambeth  Trust MPS        0.85  0.86
# 6741 2016-03-31    PAS                Lewisham  Trust MPS        0.84  0.86
# 6742 2016-03-31    PAS                  Merton  Trust MPS        0.86  0.86
# 6743 2016-03-31    PAS                  Newham  Trust MPS        0.85  0.86
# 6744 2016-03-31    PAS               Redbridge  Trust MPS        0.89  0.86
# 6745 2016-03-31    PAS    Richmond upon Thames  Trust MPS        0.92  0.86
# 6746 2016-03-31    PAS               Southwark  Trust MPS        0.89  0.86
# 6747 2016-03-31    PAS                  Sutton  Trust MPS        0.85  0.86
# 6748 2016-03-31    PAS           Tower Hamlets  Trust MPS        0.87  0.86
# 6749 2016-03-31    PAS          Waltham Forest  Trust MPS        0.84  0.86
# 6750 2016-03-31    PAS              Wandsworth  Trust MPS        0.88  0.86
# 6751 2016-03-31    PAS     City of Westminster  Trust MPS        0.94  0.86
#
#      month Month
# 6720   Mar   Mar
# 6721   Mar   Mar
# 6722   Mar   Mar
# 6723   Mar   Mar
# 6724   Mar   Mar
# 6725   Mar   Mar
# 6726   Mar   Mar
# 6727   Mar   Mar
# 6728   Mar   Mar
# 6729   Mar   Mar
# 6730   Mar   Mar
# 6731   Mar   Mar
# 6732   Mar   Mar
# 6733   Mar   Mar
# 6734   Mar   Mar
# 6735   Mar   Mar
# 6736   Mar   Mar
# 6737   Mar   Mar
# 6738   Mar   Mar
# 6739   Mar   Mar
# 6740   Mar   Mar
# 6741   Mar   Mar
# 6742   Mar   Mar
# 6743   Mar   Mar
# 6744   Mar   Mar
# 6745   Mar   Mar
# 6746   Mar   Mar
# 6747   Mar   Mar
# 6748   Mar   Mar
# 6749   Mar   Mar
# 6750   Mar   Mar
# 6751   Mar   Mar

# %%
all_borough = ['Barking and Dagenham',
 'Barnet',
 'Bexley',
 'Brent',
 'Bromley',
 'Camden',
 'Croydon',
 'Ealing',
 'Enfield',
 'Greenwich',
 'Hackney',
 'Hammersmith and Fulham',
 'Haringey',
 'Harrow',
 'Havering',
 'Hillingdon',
 'Hounslow',
 'Islington',
 'Kensington and Chelsea',
 'Kingston upon Thames',
 'Lambeth',
 'Lewisham',
 'Merton',
 'Newham',
 'Redbridge',
 'Richmond upon Thames',
 'Southwark',
 'Sutton',
 'Tower Hamlets',
 'Waltham Forest',
 'Wandsworth', 'Westminster']

# %%
difference = [abs(p2 - p1) for p1, p2 in zip(Dif_2016, Dif_2022)]
difference
# Out:
# [0.09999999999999998,
#  0.10999999999999999,
#  0.17000000000000004,
#  0.09999999999999998,
#  0.16000000000000003,
#  0.15999999999999992,
#  0.19999999999999996,
#  0.09999999999999998,
#  0.07000000000000006,
#  0.17999999999999994,
#  0.16999999999999993,
#  0.2300000000000001,
#  0.1499999999999999,
#  0.06999999999999995,
#  0.16000000000000003,
#  0.010000000000000009,
#  0.12,
#  0.27,
#  0.17000000000000004,
#  0.13,
#  0.2899999999999999,
#  0.19999999999999996,
#  0.08999999999999997,
#  0.15000000000000002,
#  0.17000000000000004,
#  0.21000000000000008,
#  0.22999999999999998,
#  0.04999999999999993,
#  0.18999999999999995,
#  0.19999999999999996,
#  0.17000000000000004,
#  0.19999999999999996]

# %%
new_dict = {}
for i, j in zip(all_borough, difference):
    new_dict[i] = j

max_key = max(new_dict, key=lambda k: new_dict[k])
min_key = min(new_dict, key=lambda k: new_dict[k])

print(f'max: {max_key}, min: {min_key}')
# Out:
# max: Lambeth, min: Hillingdon

# %%
city_df = Borough_df[(Borough_df['Measure'] == measure_name) & (Borough_df['Borough'] == 'Lambeth')]
plt.plot(city_df['Date'], city_df['Proportion'])
plt.ylim(0.5, 1);

# %%
city_df = Borough_df[(Borough_df['Measure'] == measure_name) & (Borough_df['Borough'] == 'Wandsworth')]
plt.plot(city_df['Date'], city_df['Proportion'])
plt.ylim(0.5, 1);

# %%
for i in all_borough:
    city_df = Borough_df[(Borough_df['Measure'] == measure_name) & (Borough_df['Borough'] == i)]
    plt.figure()
    plt.plot(city_df['Date'], city_df['Proportion'])
    plt.ylim(0.5, 1)
    plt.title(f'{i} Proportion over Time')
    plt.xlabel('Date')
    plt.ylabel('Proportion')
    plt.show()

# %%
crime_df = pd.read_csv("../project_data/combined_crime.csv")
# Out:
# C:\Users\ambra\AppData\Local\Temp\ipykernel_10816\545607846.py:1: DtypeWarning: Columns (0,4,5,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   crime_df = pd.read_csv("../project_data/combined_crime.csv")

# %%
crime_df.columns
# Out:
# Index(['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type',
#        'Last outcome category', 'Context'],
#       dtype='object')

# %%
list_of_lsoa_names = list(set(crime_df["LSOA name"].to_list()))
list_of_lsoa_names
# Out:
# ['Dacorum 005A',
#  'Chelmsford 009F',
#  'Barnet 019F',
#  'Islington 014E',
#  'Harrow 022B',
#  'St Albans 006D',
#  'Newham 003C',
#  'Richmond upon Thames 010C',
#  'Harrow 015C',
#  'Southwark 013B',
#  'Rugby 007E',
#  'Isle of Anglesey 001B',
#  'Poole 017A',
#  'Huntingdonshire 002B',
#  'Wandsworth 026B',
#  'Gravesham 012C',
#  'Buckinghamshire 064E',
#  'Stockport 016C',
#  'Croydon 033B',
#  'Bexley 015E',
#  'Adur 001B',
#  'Crawley 005B',
#  'Bournemouth 006D',
#  'Camden 016B',
#  'Harrow 033D',
#  'Westminster 024E',
#  'Runnymede 007F',
#  'Bracknell Forest 010B',
#  'Greenwich 004D',
#  'Croydon 046B',
#  'Doncaster 001A',
#  'Bromley 002E',
#  'Islington 023D',
#  'Kingston upon Thames 006B',
#  'Kingston upon Thames 011B',
#  'Plymouth 008A',
#  'Hyndburn 009B',
#  'Leicester 036A',
#  'Maidstone 014A',
#  'Barking and Dagenham 004D',
#  'Luton 016A',
#  'Wandsworth 010K',
#  'Manchester 006B',
#  'Croydon 042C',
#  'Newham 036D',
#  'Newham 030B',
#  'St Albans 012A',
#  'Maidstone 019B',
#  'Manchester 017A',
#  'Birmingham 096E',
#  'Tower Hamlets 014A',
#  'Tunbridge Wells 008E',
#  'Winchester 013A',
#  'Newham 018D',
#  'Neath Port Talbot 002C',
#  'Islington 011J',
#  'South Gloucestershire 036C',
#  'Westminster 002E',
#  'Ealing 023D',
#  'Wakefield 040C',
#  'Stafford 005E',
#  'Central Bedfordshire 026D',
#  'Sheffield 022B',
#  'Waltham Forest 003A',
#  'Crawley 013A',
#  'Leeds 055A',
#  'Bradford 012C',
#  'Gravesham 005E',
#  'Lewisham 009B',
#  'Hounslow 025C',
#  'Bromley 028C',
#  'Cornwall 018C',
#  'Bury 014B',
#  'Brent 035A',
#  'Birmingham 004A',
#  'Rushcliffe 011A',
#  'Sunderland 007C',
#  'Castle Point 001A',
#  'Slough 013B',
#  'Mid Suffolk 009D',
#  'Wandsworth 039C',
#  'Wandsworth 022B',
#  'Medway 004A',
#  'East Hertfordshire 010A',
#  'Oldham 008B',
#  'Waltham Forest 006B',
#  'Southend-on-Sea 006F',
#  'Medway 034A',
#  'Spelthorne 012B',
#  'Tonbridge and Malling 012E',
#  'Welwyn Hatfield 003A',
#  'Croydon 026A',
#  'Basildon 009C',
#  'Rochford 010C',
#  'Leeds 082E',
#  'Huntingdonshire 012B',
#  'Elmbridge 014E',
#  'Wycombe 006D',
#  'Slough 005A',
#  'Slough 004D',
#  'Oldham 019C',
#  'Sedgemoor 011G',
#  'Southampton 022C',
#  'Uttlesford 006C',
#  'Epping Forest 007E',
#  'Tewkesbury 003B',
#  'Sunderland 016B',
#  'Stratford-on-Avon 012B',
#  'Havant 015C',
#  'Tower Hamlets 007C',
#  'Leicester 012B',
#  'Stevenage 001D',
#  'Barnet 005D',
#  'Bromley 019C',
#  'Merton 013E',
#  'Manchester 020D',
#  'Broxbourne 004A',
#  'Crawley 008B',
#  'St. Helens 013B',
#  'Rother 001B',
#  'Tandridge 004A',
#  'Plymouth 019D',
#  'Derby 026F',
#  'Sheffield 012B',
#  'Merton 024A',
#  'Birmingham 082D',
#  'Sutton 006B',
#  'Slough 007B',
#  'Hillingdon 004D',
#  'Gateshead 011D',
#  'Pendle 004B',
#  'Bradford 029A',
#  'Brent 001C',
#  'Bracknell Forest 005A',
#  'Southwark 034E',
#  'Barnet 035C',
#  'Bath and North East Somerset 010C',
#  'South Norfolk 008D',
#  'Camden 025C',
#  'Southampton 026B',
#  'Gravesham 004C',
#  'East Hertfordshire 010B',
#  'South Gloucestershire 025E',
#  'Wealden 003C',
#  'Redcar and Cleveland 021B',
#  'Kensington and Chelsea 011D',
#  'Elmbridge 001A',
#  'Hillingdon 003C',
#  'South Cambridgeshire 004A',
#  'Central Bedfordshire 001B',
#  'Havant 009D',
#  'Kingston upon Thames 001E',
#  'Bexley 007A',
#  'Greenwich 040B',
#  'Sevenoaks 010F',
#  'Cardiff 039E',
#  'Selby 004E',
#  'Broadland 003A',
#  'Wandsworth 010I',
#  'Waltham Forest 001B',
#  'Redbridge 007G',
#  'Waveney 001C',
#  'Haringey 009B',
#  'Reigate and Banstead 012D',
#  'Slough 003C',
#  'Wycombe 023C',
#  'Preston 017G',
#  'Luton 018A',
#  'Torbay 010C',
#  'Southwark 024C',
#  'Windsor and Maidenhead 018B',
#  'Basingstoke and Deane 021D',
#  'Bexley 028B',
#  'Rother 001A',
#  'Suffolk Coastal 011E',
#  'Herefordshire 010B',
#  'Reigate and Banstead 010A',
#  'Bassetlaw 016G',
#  'Salford 027D',
#  'Tendring 015D',
#  'Peterborough 010C',
#  'Haringey 035B',
#  'Sedgemoor 013B',
#  'Nottingham 026F',
#  'West Berkshire 004B',
#  'Elmbridge 010B',
#  'Havering 019B',
#  'Scarborough 004F',
#  'Wealden 006D',
#  'Three Rivers 002C',
#  'Peterborough 011C',
#  'Chelmsford 005F',
#  'Kensington and Chelsea 017B',
#  'Bexley 021C',
#  'St Albans 015C',
#  'Milton Keynes 016E',
#  'Brent 003F',
#  'Bedford 021A',
#  'Barnet 028D',
#  'Westminster 001A',
#  'Newham 003A',
#  'Stoke-on-Trent 022B',
#  'Colchester 008D',
#  'Southend-on-Sea 015A',
#  'Redbridge 007E',
#  'Horsham 003A',
#  'Hackney 008C',
#  'Haringey 011C',
#  'North Norfolk 004B',
#  'Windsor and Maidenhead 002E',
#  'St Albans 015B',
#  'Northampton 029A',
#  'Luton 023D',
#  'Southend-on-Sea 008D',
#  'Westminster 021D',
#  'South Norfolk 007C',
#  'Haringey 008C',
#  'Hounslow 015A',
#  'Islington 010E',
#  'Kirklees 031B',
#  'South Holland 009D',
#  'Bassetlaw 004E',
#  'Croydon 024A',
#  'Hackney 024C',
#  'Tower Hamlets 030C',
#  'St Albans 016C',
#  'Hillingdon 026E',
#  'Bournemouth 015A',
#  'Richmond upon Thames 001A',
#  'Brighton and Hove 023B',
#  'Reading 006C',
#  'North Hertfordshire 008A',
#  'Portsmouth 016G',
#  'Havering 018D',
#  'Merton 024D',
#  'Redcar and Cleveland 012B',
#  'Camden 004C',
#  'Lewisham 016C',
#  'Richmond upon Thames 020A',
#  'Dudley 030D',
#  'Norwich 005A',
#  'South Northamptonshire 002B',
#  'Spelthorne 005C',
#  'Epping Forest 001A',
#  'Powys 017E',
#  'Allerdale 005B',
#  'Hounslow 017G',
#  'Kettering 006B',
#  'Enfield 014E',
#  'Coventry 038D',
#  'Wandsworth 004C',
#  'Leicester 003D',
#  'Wealden 001B',
#  'Brent 019B',
#  'Islington 021C',
#  'Croydon 045C',
#  'Hillingdon 016H',
#  'Bromley 012A',
#  'Spelthorne 004A',
#  'Ealing 032B',
#  'Horsham 001D',
#  'North East Lincolnshire 016A',
#  'Braintree 012E',
#  'Oxford 016E',
#  'Brent 002B',
#  'Trafford 012A',
#  'Northampton 020B',
#  'Hackney 031A',
#  'Lewisham 041C',
#  'Dartford 001I',
#  'Swale 004E',
#  'Eden 004E',
#  'Lewes 008C',
#  'Oxford 004D',
#  'Harrow 025B',
#  'Wirral 020B',
#  'Redbridge 022A',
#  'Haringey 023C',
#  'Haringey 022A',
#  'Wandsworth 033D',
#  'Slough 012F',
#  'Tendring 014E',
#  'Richmond upon Thames 013A',
#  'Lambeth 014C',
#  'Herefordshire 015D',
#  'Cheshire East 038D',
#  'Windsor and Maidenhead 014A',
#  'Kensington and Chelsea 007A',
#  'Medway 027D',
#  'Peterborough 002A',
#  'Epsom and Ewell 007F',
#  'Rushcliffe 008D',
#  'Bromley 005E',
#  'Reigate and Banstead 003B',
#  'Greenwich 023C',
#  'Chelmsford 015C',
#  'Sandwell 023F',
#  'Hackney 002A',
#  'Greenwich 007C',
#  'Three Rivers 009C',
#  'Runnymede 007E',
#  'South Oxfordshire 016C',
#  'Lambeth 029E',
#  'Leicester 020C',
#  'Lambeth 003G',
#  'Redbridge 040A',
#  'Isle of Wight 010A',
#  'Milton Keynes 006C',
#  'Tower Hamlets 020D',
#  'Shropshire 011D',
#  'Wokingham 008C',
#  'Liverpool 014E',
#  'Wokingham 009D',
#  'Waltham Forest 004A',
#  'Southend-on-Sea 009B',
#  'Birmingham 014B',
#  'Brent 035D',
#  'Fylde 001B',
#  'Hartlepool 005B',
#  'Buckinghamshire 036F',
#  'Central Bedfordshire 026C',
#  'Gloucester 005D',
#  'Croydon 009B',
#  'Spelthorne 007C',
#  'Mid Suffolk 009C',
#  'Sheffield 068E',
#  'Nottingham 018E',
#  'Haringey 001C',
#  'Lewisham 038A',
#  'Reading 018A',
#  'Boston 001C',
#  'Buckinghamshire 041A',
#  'Bournemouth, Christchurch and Poole 041B',
#  'Enfield 029B',
#  'Hounslow 020E',
#  'Leicester 030E',
#  'Gravesham 003C',
#  'Peterborough 012D',
#  'Broxbourne 013B',
#  'Lambeth 035B',
#  'Barking and Dagenham 002D',
#  'Hounslow 013E',
#  'Lambeth 003F',
#  'Lambeth 025B',
#  'South Northamptonshire 007A',
#  'Bexley 019F',
#  'Kirklees 008D',
#  'Hastings 008A',
#  'Lewisham 028A',
#  'Doncaster 009F',
#  'Walsall 031B',
#  'Doncaster 022C',
#  'Welwyn Hatfield 006A',
#  'Elmbridge 006C',
#  'Stockport 002C',
#  'Coventry 043A',
#  'Kensington and Chelsea 016F',
#  'Woking 002E',
#  'Dacorum 008C',
#  'Tamworth 003A',
#  'Luton 012A',
#  'Stevenage 009B',
#  'South Bucks 004C',
#  'Nottingham 030D',
#  'Wycombe 012A',
#  'Manchester 057A',
#  'West Berkshire 007C',
#  'Hertsmere 011C',
#  'Swale 007H',
#  'Mid Sussex 001F',
#  'Havering 011A',
#  'Croydon 037B',
#  'Barnet 015D',
#  'Newham 011A',
#  'Kirklees 044D',
#  'Weymouth and Portland 004B',
#  'Milton Keynes 014B',
#  'Surrey Heath 005C',
#  'North Devon 009A',
#  'Mole Valley 002C',
#  'Swale 005B',
#  'Croydon 020B',
#  'Tonbridge and Malling 012D',
#  'Barnet 022E',
#  'Bromley 011D',
#  'Barnet 037C',
#  'Central Bedfordshire 008A',
#  'St Albans 017B',
#  'Gloucester 012A',
#  'Thanet 003D',
#  'Wandsworth 010F',
#  'Kingston upon Thames 003E',
#  "King's Lynn and West Norfolk 002A",
#  'Tower Hamlets 027A',
#  'Southwark 018A',
#  'Knowsley 018B',
#  'Harrow 010A',
#  'Enfield 022B',
#  'Plymouth 024B',
#  'Braintree 015D',
#  'Kingston upon Hull 029A',
#  'Liverpool 012A',
#  'Bristol 047D',
#  'Northampton 031C',
#  'Croydon 014B',
#  'Northumberland 002A',
#  'Thurrock 013B',
#  'South Oxfordshire 012F',
#  'Elmbridge 018E',
#  'Luton 022B',
#  'Tower Hamlets 023B',
#  'Westminster 009K',
#  'Richmond upon Thames 004H',
#  'Bromley 008A',
#  'Great Yarmouth 003C',
#  'North Tyneside 022B',
#  'Southampton 026A',
#  'Croydon 007C',
#  'Manchester 022C',
#  'Ealing 010E',
#  'Derby 011B',
#  'Sutton 006A',
#  'South Northamptonshire 007B',
#  'Hammersmith and Fulham 021D',
#  'York 017B',
#  'Manchester 034E',
#  'Spelthorne 008D',
#  'Haringey 034C',
#  'Croydon 011D',
#  'Redbridge 012D',
#  'Sefton 007B',
#  'Elmbridge 015C',
#  'Merton 025A',
#  'Birmingham 138B',
#  'Runnymede 007C',
#  'South Derbyshire 002F',
#  'Hounslow 024C',
#  'Aylesbury Vale 007E',
#  'Epping Forest 015F',
#  'Lewisham 040B',
#  'Epsom and Ewell 003A',
#  'Brighton and Hove 029A',
#  'Hounslow 019D',
#  'Central Bedfordshire 024H',
#  'Gloucester 003B',
#  'Newcastle upon Tyne 025E',
#  'Welwyn Hatfield 009A',
#  'Wirral 021D',
#  'Elmbridge 005C',
#  'North Hertfordshire 015F',
#  'Northumberland 002C',
#  'Reading 017F',
#  'North Hertfordshire 002D',
#  'Cheshire West and Chester 011C',
#  'Wirral 033D',
#  'Bolton 010C',
#  'Reading 009C',
#  'Waverley 011B',
#  'Trafford 024E',
#  'Greenwich 033C',
#  'Medway 020B',
#  'Central Bedfordshire 024E',
#  'Cornwall 007B',
#  'Barnet 006A',
#  'Southwark 028C',
#  'Waltham Forest 002A',
#  'Bexley 024B',
#  'North Norfolk 008B',
#  'Kingston upon Thames 001D',
#  'County Durham 010A',
#  'Westminster 015B',
#  'Harrogate 003D',
#  'Ealing 031B',
#  'Manchester 054B',
#  'Charnwood 010D',
#  'Leeds 093C',
#  'Sutton 019E',
#  'Westminster 005E',
#  'Bedford 009C',
#  'Guildford 015C',
#  'South Derbyshire 009D',
#  'North East Lincolnshire 021C',
#  'Brentwood 001E',
#  'Nottingham 015E',
#  'New Forest 023C',
#  'Tower Hamlets 005D',
#  'Wychavon 007A',
#  'Basingstoke and Deane 007F',
#  'Kettering 009C',
#  'Cambridge 005C',
#  'Trafford 019D',
#  'Gravesham 004E',
#  'Greenwich 038E',
#  'Hounslow 029C',
#  'Islington 022D',
#  'Enfield 036C',
#  'Wandsworth 010E',
#  'Brighton and Hove 015B',
#  'Newham 039C',
#  'Thanet 007D',
#  'Lambeth 013D',
#  'Middlesbrough 008B',
#  'Harlow 011C',
#  'Luton 016D',
#  'Birmingham 084B',
#  'Newham 005A',
#  'Epsom and Ewell 009F',
#  'Croydon 015D',
#  'North Tyneside 028B',
#  'Wandsworth 037B',
#  'Wealden 021B',
#  'St Albans 010C',
#  'Enfield 006B',
#  'Leicester 035D',
#  'Leeds 027C',
#  'Southwark 032B',
#  'Central Bedfordshire 007A',
#  'Derby 001D',
#  'Cheshire East 009C',
#  'Birmingham 116C',
#  'Wellingborough 010B',
#  'Cheshire East 049G',
#  'Croydon 015A',
#  'Wandsworth 020E',
#  'Bromley 004C',
#  'Barnet 028C',
#  'Luton 018E',
#  'Luton 011E',
#  'Luton 007F',
#  'Basildon 016D',
#  'Basildon 006C',
#  'Epping Forest 012A',
#  'Rushmoor 008A',
#  'Broxbourne 006D',
#  'Newham 007D',
#  'Tendring 017D',
#  'Kensington and Chelsea 015B',
#  'Basildon 014C',
#  'Milton Keynes 006A',
#  'Worthing 008E',
#  'Maidstone 005A',
#  'Stratford-on-Avon 013A',
#  'Oxford 013D',
#  'Guildford 002B',
#  'Thurrock 009A',
#  'Barnet 032B',
#  'Norwich 006C',
#  'Ashford 012E',
#  'New Forest 016B',
#  'Sevenoaks 005A',
#  'Tendring 004C',
#  'Hackney 021B',
#  'Tandridge 004D',
#  'Welwyn Hatfield 013B',
#  'Braintree 007F',
#  'Barnet 002E',
#  'Dartford 008B',
#  'South Bucks 001E',
#  'Brentwood 006D',
#  'Stratford-on-Avon 014B',
#  'Sevenoaks 016D',
#  'Enfield 018B',
#  'Newham 011E',
#  'Birmingham 011A',
#  'Hackney 003A',
#  'Brent 013A',
#  'Chiltern 012C',
#  'Salford 006C',
#  'County Durham 049C',
#  'New Forest 010E',
#  'Portsmouth 016H',
#  'Barnet 031D',
#  'Telford and Wrekin 010B',
#  'Birmingham 073A',
#  'Milton Keynes 024B',
#  'Kingston upon Hull 029D',
#  'Camden 026B',
#  'Croydon 026E',
#  'North Somerset 010E',
#  'Poole 011E',
#  'Enfield 032D',
#  'South Cambridgeshire 002D',
#  'Bolton 029A',
#  'Sheffield 018C',
#  'Castle Point 007C',
#  'Tower Hamlets 019F',
#  'Derbyshire Dales 008C',
#  'County Durham 057B',
#  'Rochdale 022D',
#  'Birmingham 092D',
#  'Wandsworth 011A',
#  'Fylde 001E',
#  'Wandsworth 018D',
#  'Crawley 013D',
#  'Hillingdon 004B',
#  'Kingston upon Hull 029C',
#  'Greenwich 029E',
#  'Dacorum 013A',
#  'Havering 026A',
#  'Southampton 015E',
#  'Nottingham 014B',
#  'Spelthorne 001C',
#  'Havering 006C',
#  'Tonbridge and Malling 006D',
#  'Slough 011H',
#  'Chichester 007C',
#  'Richmond upon Thames 003D',
#  'Milton Keynes 022E',
#  'Merton 006C',
#  'Reigate and Banstead 009D',
#  'Solihull 022B',
#  'Corby 008C',
#  'Ealing 001B',
#  'Bristol 008A',
#  'Brentwood 006B',
#  'Lewisham 015B',
#  'Barking and Dagenham 021G',
#  'Wandsworth 016A',
#  'Bromley 015B',
#  'Haringey 027B',
#  'Tewkesbury 007H',
#  'Lewisham 012A',
#  'Lewisham 011D',
#  'Great Yarmouth 001E',
#  'Islington 003E',
#  'Enfield 002D',
#  'Hillingdon 018B',
#  'Southwark 008A',
#  'Solihull 011A',
#  'Thanet 014B',
#  'Cherwell 010B',
#  'Central Bedfordshire 011F',
#  'Bedford 019A',
#  'Barking and Dagenham 014D',
#  'Welwyn Hatfield 016B',
#  'Crawley 011B',
#  'Hastings 011E',
#  'Greenwich 042B',
#  'Hackney 029A',
#  'Bedford 015A',
#  'Shepway 013D',
#  'Merton 004B',
#  'Rushmoor 001C',
#  'Redbridge 040D',
#  'Harrow 008C',
#  'Preston 007B',
#  'Luton 006D',
#  'Epsom and Ewell 002D',
#  'Barnet 041C',
#  'Bexley 002B',
#  'Tower Hamlets 025B',
#  'Leicester 010F',
#  'Epsom and Ewell 001C',
#  'Suffolk Coastal 011A',
#  'Cherwell 007C',
#  'Coventry 012C',
#  'Harlow 007A',
#  'Birmingham 088C',
#  'Derby 025B',
#  'Windsor and Maidenhead 018A',
#  'Hounslow 028D',
#  'Rother 004A',
#  'Camden 029B',
#  'South Lakeland 002C',
#  'Croydon 038E',
#  'Bradford 007A',
#  'Havering 009E',
#  'South Kesteven 007D',
#  'Enfield 021C',
#  'Sutton 013E',
#  'Mole Valley 005A',
#  'Wycombe 008D',
#  'Merton 012E',
#  'Merton 005A',
#  'Cherwell 008C',
#  'Cotswold 001D',
#  'Three Rivers 009A',
#  'Rochdale 010D',
#  'Three Rivers 001G',
#  'Hillingdon 033E',
#  'Brent 028B',
#  'Enfield 013A',
#  'Hackney 011E',
#  'Lincoln 008A',
#  'Stoke-on-Trent 028B',
#  'Brent 011B',
#  'Bournemouth 013D',
#  'Exeter 014B',
#  'Hertsmere 005B',
#  'East Staffordshire 007E',
#  'Tower Hamlets 004A',
#  'Hertsmere 009C',
#  'Medway 032D',
#  'Lambeth 024B',
#  'Cheshire West and Chester 002E',
#  'Harlow 001C',
#  'East Hertfordshire 018B',
#  'Croydon 044E',
#  'Castle Point 005D',
#  'Crawley 009C',
#  'Liverpool 015C',
#  'Slough 011C',
#  'Newham 029D',
#  'Southwark 026B',
#  'Rushmoor 008B',
#  'Dartford 006B',
#  'Leeds 112E',
#  'Kensington and Chelsea 010D',
#  'Wiltshire 043D',
#  'Haringey 036B',
#  'Arun 001C',
#  'Wiltshire 043B',
#  'Wealden 012A',
#  'Hammersmith and Fulham 023C',
#  'Wellingborough 003B',
#  'Hounslow 013D',
#  'Wolverhampton 016C',
#  'Gateshead 027C',
#  'Birmingham 117B',
#  'Nottingham 024A',
#  'North Somerset 027C',
#  'Brent 011A',
#  'Babergh 007F',
#  'Southwark 004B',
#  'Croydon 016C',
#  'Hillingdon 001E',
#  'Derby 011D',
#  'Hackney 016E',
#  'Lambeth 003B',
#  'Greenwich 014A',
#  'Enfield 020D',
#  'Brent 023B',
#  'Harrow 006E',
#  'Lambeth 019C',
#  'Mid Sussex 001E',
#  'St Edmundsbury 009B',
#  'Sheffield 019D',
#  'Middlesbrough 015A',
#  'Bexley 014A',
#  'Crawley 005D',
#  'Nottingham 026B',
#  'Ashford 001F',
#  'Haringey 015F',
#  'Hammersmith and Fulham 009D',
#  'Wycombe 014C',
#  'Kingston upon Thames 004B',
#  'Newham 007B',
#  'West Dorset 001F',
#  'Waltham Forest 025D',
#  'Hillingdon 021E',
#  'Bromley 034E',
#  'Merton 017B',
#  'North East Lincolnshire 022C',
#  'Hertsmere 012E',
#  'Trafford 003C',
#  'Doncaster 015C',
#  'Brent 009F',
#  'Waltham Forest 024E',
#  'Thurrock 016A',
#  'Broadland 003C',
#  'Kensington and Chelsea 020B',
#  'Croydon 005B',
#  'Reading 006E',
#  'Chiltern 013D',
#  'Hounslow 022E',
#  'South Tyneside 015F',
#  'Bexley 013E',
#  'Brent 005D',
#  'Hillingdon 019A',
#  'Nottingham 015D',
#  'Harlow 005A',
#  'Ipswich 008A',
#  'Isle of Wight 009A',
#  'Enfield 003G',
#  'Telford and Wrekin 003C',
#  'Croydon 022A',
#  'Brighton and Hove 014C',
#  'Greenwich 011F',
#  'Manchester 050B',
#  'Hackney 031C',
#  'Leeds 079B',
#  'Pembrokeshire 004C',
#  'Coventry 034A',
#  'Southwark 007C',
#  'Waltham Forest 004D',
#  'Greenwich 029C',
#  'Salford 010A',
#  'Islington 011C',
#  'East Hertfordshire 008B',
#  'Stockport 030C',
#  'Enfield 031E',
#  'Rushcliffe 014C',
#  'East Suffolk 005C',
#  'Bromley 027E',
#  'Reigate and Banstead 006C',
#  'Hackney 019B',
#  'Camden 005B',
#  'Cheltenham 011E',
#  'Brentwood 008E',
#  'Redbridge 030A',
#  'Hounslow 003B',
#  'Gravesham 004A',
#  'Barking and Dagenham 013F',
#  'North Warwickshire 005E',
#  'Stevenage 012B',
#  'Kingston upon Thames 017A',
#  'Slough 013C',
#  'Westminster 023G',
#  'Wigan 016E',
#  'Basildon 011D',
#  'Bristol 025D',
#  'Hertsmere 001C',
#  'Greenwich 009B',
#  'Wolverhampton 020F',
#  'Newham 033E',
#  'South Staffordshire 005B',
#  'Hounslow 016C',
#  'Bromsgrove 007C',
#  'Newham 008A',
#  'Gateshead 026C',
#  'Slough 011F',
#  'Rochdale 008G',
#  'Salford 003B',
#  'Neath Port Talbot 008A',
#  'Maidstone 003C',
#  'Wakefield 011E',
#  'Waltham Forest 025A',
#  'Thurrock 018G',
#  'Ealing 023E',
#  'Bradford 037D',
#  'East Devon 011C',
#  'Kingston upon Thames 004A',
#  'Stockport 014B',
#  'North Hertfordshire 017C',
#  'Kingston upon Thames 018C',
#  'Denbighshire 011A',
#  'Barnet 036A',
#  'Elmbridge 004A',
#  'South Gloucestershire 004B',
#  'Reading 014F',
#  'Brent 005C',
#  'Kingston upon Thames 008D',
#  'Spelthorne 013A',
#  'Doncaster 007E',
#  'Basildon 018A',
#  'West Lindsey 004F',
#  'Haringey 031C',
#  'Tameside 011B',
#  'Great Yarmouth 006C',
#  'Brighton and Hove 001B',
#  'Stockport 026C',
#  'Leicester 017A',
#  'Watford 012A',
#  'York 019E',
#  'Sutton 015B',
#  'Waltham Forest 008A',
#  'Birmingham 095D',
#  'Bromley 027B',
#  'Newham 014A',
#  'Coventry 042A',
#  'North Hertfordshire 016D',
#  'Harrow 033G',
#  'Tower Hamlets 018C',
#  'Hackney 028E',
#  'Adur 002A',
#  'Brent 017F',
#  'Merton 011D',
#  'Leicester 028A',
#  'Fylde 006A',
#  'Waltham Forest 028A',
#  'Wandsworth 024A',
#  'Walsall 033B',
#  'Bradford 051B',
#  'Wandsworth 026F',
#  'Maidstone 004G',
#  'Ashford 006D',
#  'County Durham 045E',
#  'Bromley 008B',
#  'Southend-on-Sea 014D',
#  'Rochford 006E',
#  'Lewisham 007D',
#  'Elmbridge 014C',
#  'Bournemouth 001C',
#  'Redbridge 038C',
#  'Swale 016D',
#  'Haringey 006D',
#  'Sutton 022C',
#  'Trafford 002D',
#  'Hounslow 008D',
#  'Arun 007D',
#  'Solihull 009A',
#  'Bury 008C',
#  'Swansea 012B',
#  'Runnymede 007G',
#  'Lambeth 002C',
#  'Brighton and Hove 003A',
#  'Dacorum 022B',
#  'Redbridge 037D',
#  'West Berkshire 009D',
#  'Herefordshire 004F',
#  'Lewisham 019D',
#  'Hillingdon 030E',
#  'Swansea 026E',
#  'Leeds 006A',
#  'Reigate and Banstead 009A',
#  'Bristol 041C',
#  'Derby 018A',
#  'West Devon 002D',
#  'Haringey 021B',
#  'Great Yarmouth 006D',
#  'Tower Hamlets 033A',
#  'Hounslow 027D',
#  'Norwich 014A',
#  'Westminster 008B',
#  "King's Lynn and West Norfolk 017H",
#  'Tonbridge and Malling 006A',
#  'Bexley 004D',
#  'Cardiff 032G',
#  'Braintree 013B',
#  'Manchester 038D',
#  'Tunbridge Wells 008D',
#  'Wandsworth 027C',
#  'Bath and North East Somerset 021D',
#  'Chiltern 005D',
#  'Wycombe 015B',
#  'Wandsworth 036D',
#  'Westminster 019D',
#  'Chelmsford 021A',
#  'Bedford 019B',
#  'Hammersmith and Fulham 024C',
#  'Mid Devon 001C',
#  'Tower Hamlets 009E',
#  'Haringey 005A',
#  'Brent 014A',
#  'Lewisham 021B',
#  'Thurrock 009B',
#  'Newham 007C',
#  'Worthing 011A',
#  'Sandwell 005D',
#  'Croydon 018A',
#  'Cardiff 036A',
#  'Lichfield 011A',
#  'Worcester 013A',
#  'Wokingham 006C',
#  'Stockport 007C',
#  'Elmbridge 009C',
#  'Medway 038B',
#  'Hammersmith and Fulham 019D',
#  'Central Bedfordshire 009B',
#  'Sefton 033E',
#  'Bromley 013E',
#  'Newham 007A',
#  'Bath and North East Somerset 019D',
#  'East Lindsey 008B',
#  'Tower Hamlets 017D',
#  'Bexley 024C',
#  'Sutton 004A',
#  'Bromley 001F',
#  'Milton Keynes 003D',
#  'New Forest 019C',
#  'North Hertfordshire 004G',
#  'Bexley 014C',
#  'Brighton and Hove 010B',
#  'Hounslow 021E',
#  'South Cambridgeshire 016F',
#  'Kingston upon Thames 016A',
#  'Islington 014F',
#  'Brent 015E',
#  'Bromley 008F',
#  'Isle of Wight 003E',
#  'Lambeth 027C',
#  'Brighton and Hove 031E',
#  'South Staffordshire 003E',
#  'Sheffield 007D',
#  'Test Valley 012C',
#  'Cambridge 007D',
#  'Harrow 013D',
#  'Rochdale 016C',
#  'Oldham 018A',
#  'Harrow 012A',
#  'Newham 010C',
#  'Ealing 029D',
#  'Enfield 031B',
#  'Huntingdonshire 011B',
#  'Basingstoke and Deane 007C',
#  'Poole 018E',
#  'Croydon 039A',
#  'Epping Forest 010B',
#  'Wokingham 012H',
#  'Staffordshire Moorlands 011C',
#  'Lewisham 034C',
#  'Manchester 004A',
#  'Lewisham 001B',
#  'Merton 009C',
#  'Wakefield 019A',
#  'Three Rivers 005B',
#  'Lewisham 038E',
#  'Tower Hamlets 022C',
#  'Havering 028D',
#  'Ealing 028D',
#  ...]

# %%
import re
list_of_boroughs = []
pattern = r'^([a-zA-Z\s]+)'
for i in list_of_lsoa_names[1:len(list_of_lsoa_names)]:
    match = re.findall(pattern, i)[0]
    match = match[0:len(match)-1]
    list_of_boroughs.append(match)
list_of_boroughs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 5
#       3 pattern = r'^([a-zA-Z\s]+)'
#       4 for i in list_of_lsoa_names[1:len(list_of_lsoa_names)]:
# ----> 5     match = re.findall(pattern, i)[0]
#       6     match = match[0:len(match)-1]
#       7     list_of_boroughs.append(match)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\re\__init__.py:217, in findall(pattern, string, flags)
#     209 def findall(pattern, string, flags=0):
#     210     """Return a list of all non-overlapping matches in the string.
#     211
#     212     If one or more capturing groups are present in the pattern, return
#    (...)
#     215
#     216     Empty matches are included in the result."""
# --> 217     return _compile(pattern, flags).findall(string)
#
# TypeError: expected string or bytes-like object, got 'float'

# %%
pattern = r'^([a-zA-Z\s]+)'

def add_borough(i, pattern):
    if pd.isna(i):
        return None
    else:
        match = re.findall(pattern, i)[0]
        match = match[0:len(match)-1]
        return match

# %%
add_borough('Barking and Dagenham 011B', pattern)
# Out:
# 'Barking and Dagenham'

# %%
tqdm.pandas(desc="Adding Boroughs")
crime_df['Borough'] = crime_df['LSOA name'].progress_apply(lambda x: add_borough(x, pattern))
# Out:
# Adding Boroughs: 100%|██████████| 14131357/14131357 [00:23<00:00, 599108.74it/s]

# %%
tqdm.pandas()
filtered_crime_df = crime_df[crime_df['Borough'].progress_apply(lambda x: x in all_borough)]
borough_counts = filtered_crime_df['Borough'].value_counts()

plt.figure(figsize=(12, 8))
borough_counts.plot(kind='bar')
plt.title('Distribution of Crimes by Borough')
plt.xlabel('Borough')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 14131357/14131357 [00:09<00:00, 1478956.04it/s]

# %%
filtered_crime_df
# Out:
#                                                    Crime ID    Month  \
# 0                                                       NaN  2010-12
# 1                                                       NaN  2010-12
# 2                                                       NaN  2010-12
# 3                                                       NaN  2010-12
# 4                                                       NaN  2010-12
# ...                                                     ...      ...
# 14130675  cb73daf6b8479ac3c6f0393ccaed8ba09d656bc8ec7daf...  2024-01
# 14130676  9bf4d909cbf838f713421c29a173c1fd1578393789ce37...  2024-01
# 14130677  90ce6cc23afb135dcbc5eb17784b4d363375f9a076a2fd...  2024-01
# 14130678  be7a1b283771dc0aefcef2b191a4f7e91403771e1d6065...  2024-01
# 14130679  9006968a8e2fb5779017e7c6f1887ad21232b565cfe6df...  2024-01
#
#                           Reported by                 Falls within Longitude  \
# 0         Metropolitan Police Service  Metropolitan Police Service  0.145949
# 1         Metropolitan Police Service  Metropolitan Police Service  0.140192
# 2         Metropolitan Police Service  Metropolitan Police Service  0.134947
# 3         Metropolitan Police Service  Metropolitan Police Service  0.134947
# 4         Metropolitan Police Service  Metropolitan Police Service  0.134947
# ...                               ...                          ...       ...
# 14130675  Metropolitan Police Service  Metropolitan Police Service  -0.13348
# 14130676  Metropolitan Police Service  Metropolitan Police Service -0.136284
# 14130677  Metropolitan Police Service  Metropolitan Police Service -0.136284
# 14130678  Metropolitan Police Service  Metropolitan Police Service  -0.13723
# 14130679  Metropolitan Police Service  Metropolitan Police Service -0.136284
#
#            Latitude                            Location  LSOA code  \
# 0         51.593914         On or near Providence Place  E01000027
# 1         51.582311              On or near Hatch Grove  E01000027
# 2         51.588063               On or near Mead Grove  E01000027
# 3         51.588063               On or near Mead Grove  E01000027
# 4         51.588063               On or near Mead Grove  E01000027
# ...             ...                                 ...        ...
# 14130675  51.486807  On or near St George'S Square Mews  E01035722
# 14130676  51.485152           On or near Petrol Station  E01035722
# 14130677  51.485152           On or near Petrol Station  E01035722
# 14130678  51.486309             On or near Parking Area  E01035722
# 14130679  51.485152           On or near Petrol Station  E01035722
#
#                           LSOA name                    Crime type  \
# 0         Barking and Dagenham 001A         Anti-social behaviour
# 1         Barking and Dagenham 001A         Anti-social behaviour
# 2         Barking and Dagenham 001A         Anti-social behaviour
# 3         Barking and Dagenham 001A         Anti-social behaviour
# 4         Barking and Dagenham 001A         Anti-social behaviour
# ...                             ...                           ...
# 14130675           Westminster 024G     Criminal damage and arson
# 14130676           Westminster 024G                   Other theft
# 14130677           Westminster 024G         Theft from the person
# 14130678           Westminster 024G  Violence and sexual offences
# 14130679           Westminster 024G  Violence and sexual offences
#
#                                   Last outcome category Context  \
# 0                                                   NaN     NaN
# 1                                                   NaN     NaN
# 2                                                   NaN     NaN
# 3                                                   NaN     NaN
# 4                                                   NaN     NaN
# ...                                                 ...     ...
# 14130675                            Under investigation     NaN
# 14130676                            Under investigation     NaN
# 14130677  Investigation complete; no suspect identified     NaN
# 14130678                            Under investigation     NaN
# 14130679  Investigation complete; no suspect identified     NaN
#
#                        Borough
# 0         Barking and Dagenham
# 1         Barking and Dagenham
# 2         Barking and Dagenham
# 3         Barking and Dagenham
# 4         Barking and Dagenham
# ...                        ...
# 14130675           Westminster
# 14130676           Westminster
# 14130677           Westminster
# 14130678           Westminster
# 14130679           Westminster
#
# [13931526 rows x 13 columns]

# %%
filtered_crime_df.to_csv('../project_data/filtered_crime_data.csv')
