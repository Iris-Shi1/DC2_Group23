# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from tqdm import tqdm
# Out:
# C:\Users\assis\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
MPS_df = pd.read_excel(r"C:\Users\assis\Downloads\PAS_T&Cdashboard_to Q3 23-24.xlsx",  sheet_name='MPS')
Borough_df = pd.read_excel(r"C:\Users\assis\Downloads\PAS_T&Cdashboard_to Q3 23-24.xlsx", sheet_name='Borough')
Borough_df = Borough_df.loc[:, ~Borough_df.columns.str.contains('^Unnamed')]
MPS_df
# Out:
#           Date Survey Borough                Measure  Proportion
# 0   2014-12-31    PAS     MPS       "Good Job" local        0.67
# 1   2014-12-31    PAS     MPS   Contact ward officer        0.41
# 2   2014-12-31    PAS     MPS         Informed local        0.49
# 3   2014-12-31    PAS     MPS     Listen to concerns        0.74
# 4   2014-12-31    PAS     MPS  Relied on to be there        0.77
# ..         ...    ...     ...                    ...         ...
# 286 2023-12-31    PAS     MPS     Listen to concerns        0.57
# 287 2023-12-31    PAS     MPS  Relied on to be there        0.59
# 288 2023-12-31    PAS     MPS  Treat everyone fairly        0.62
# 289 2023-12-31    PAS     MPS              Trust MPS        0.69
# 290 2023-12-31    PAS     MPS      Understand issues        0.57
#
# [291 rows x 5 columns]

# %%
all_measures = set(Borough_df['Measure'].to_list())
all_measures
# Out:
# {'"Good Job" local',
#  'Contact ward officer',
#  'Informed local',
#  'Listen to concerns',
#  'Relied on to be there',
#  'Treat everyone fairly',
#  'Trust MPS',
#  'Understand issues'}

# %%
all_borough = set(Borough_df['Borough'].to_list())
all_borough
# Out:
# {'Barking and Dagenham',
#  'Barnet',
#  'Bexley',
#  'Brent',
#  'Bromley',
#  'Camden',
#  'City of Westminster',
#  'Croydon',
#  'Ealing',
#  'Enfield',
#  'Greenwich',
#  'Hackney',
#  'Hammersmith and Fulham',
#  'Haringey',
#  'Harrow',
#  'Havering',
#  'Hillingdon',
#  'Hounslow',
#  'Islington',
#  'Kensington and Chelsea',
#  'Kingston upon Thames',
#  'Lambeth',
#  'Lewisham',
#  'Merton',
#  'Newham',
#  'Redbridge',
#  'Richmond Upon Thames',
#  'Richmond upon Thames',
#  'Southwark',
#  'Sutton',
#  'Tower Hamlets',
#  'Waltham Forest',
#  'Wandsworth'}

# %%
# Group by Date and Measure, then calculate the average proportion for each quarter and measure
average_proportion = Borough_df.groupby(['Date', 'Measure'])['Proportion'].mean().reset_index()

# Line plot for the average proportion of each measure over time
plt.figure(figsize=(12, 6))

# Iterate over each measure
for measure_name, data in average_proportion.groupby('Measure'):
    plt.plot(data['Date'], data['Proportion'], label=measure_name)

plt.title('Average Proportion of Each Measure over Time')
plt.xlabel('Date')
plt.ylabel('Average Proportion')
plt.xticks(rotation=45)
plt.legend(title='Measure')
plt.grid(True)
plt.show()

# %%
# Bar plot for average Proportion by Measure
plt.figure(figsize=(12, 6))
sns.barplot(x='Measure', y='Proportion', data=Borough_df)
plt.title('Average Proportion by Measure')
plt.xlabel('Measure')
plt.ylabel('Average Proportion')
plt.xticks(rotation=45)
plt.show()

# %%
# Filter the DataFrame for a specific measure
measure_name = 'Trust MPS'
measure_df = Borough_df[Borough_df['Measure'] == measure_name]

# Line plot for the proportion of the chosen measure in different boroughs over time
average_proportion = measure_df.groupby('Date')['Proportion'].mean().reset_index()

# Line plot for the average proportion of the chosen measure over time
plt.figure(figsize=(12, 6))
plt.plot(average_proportion['Date'], average_proportion['Proportion'], marker='o', linestyle='-')
plt.title(f'Average Proportion of {measure_name} over Time')
plt.xlabel('Date')
plt.ylabel('Average Proportion')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Extract year from the 'Date' column
measure_df['Year'] = measure_df['Date'].dt.year

# Aggregate the data by year and borough, calculating the mean proportion
yearly_data = measure_df.groupby(['Year', 'Borough']).mean().reset_index()
# Out:
# C:\Users\assis\AppData\Local\Temp\ipykernel_6624\4183293003.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   measure_df['Year'] = measure_df['Date'].dt.year

# %%
year_to_visualize = 2022 
measure_name = 'Trust MPS'

# Filter the data for the specified year and measure
filtered_df = Borough_df[(Borough_df['Date'].dt.year == year_to_visualize) & (Borough_df['Measure'] == measure_name)]

# Bar plot for the proportion of the chosen measure in different boroughs for the specified year
plt.figure(figsize=(12, 6))
sns.barplot(x='Borough', y='Proportion', data=filtered_df)
plt.title(f'Proportion of {measure_name} by Borough in {year_to_visualize}')
plt.xlabel('Borough')
plt.ylabel('Proportion')
plt.xticks(rotation=45)
plt.show()

# %%
measures_data = Borough_df[['Borough','Measure', 'Proportion']]

# Pivot the DataFrame to have measures as columns and Borough as index
pivot_data = measures_data.pivot_table(index='Borough', columns='Measure', values='Proportion')

# Calculate the correlation matrix
correlation_matrix = pivot_data.corr()

# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Acceptance Rates for Different Measures')
plt.xlabel('Measure')
plt.ylabel('Measure')
plt.show()

# %%
Borough_df.columns
# Out:
# Index(['Date', 'Survey', 'Borough', 'Measure', 'Proportion', 'MPS'], dtype='object')

# %%
Borough_df['Date']
# Out:
# 0      2014-12-31
# 1      2014-12-31
# 2      2014-12-31
# 3      2014-12-31
# 4      2014-12-31
#           ...
# 9307   2023-12-31
# 9308   2023-12-31
# 9309   2023-12-31
# 9310   2023-12-31
# 9311   2023-12-31
# Name: Date, Length: 9312, dtype: datetime64[ns]

# %%
Borough_df['Date'] = pd.to_datetime(Borough_df['Date'], format='%d/%m/%Y')
Borough_df['month'] = Borough_df['Date'].dt.strftime('%b')
Borough_df['month']
# Out:
# 0       Dec
# 1       Dec
# 2       Dec
# 3       Dec
# 4       Dec
#        ...
# 9307    Dec
# 9308    Dec
# 9309    Dec
# 9310    Dec
# 9311    Dec
# Name: month, Length: 9312, dtype: object

# %%
# Convert 'Date' column to datetime format
Borough_df['Date'] = pd.to_datetime(Borough_df['Date'], format='%d/%m/%Y')

# Extract month and store it in a new column 'Month'
Borough_df['Month'] = Borough_df['Date'].dt.strftime('%b')

# Specify the year and measure to visualize
year_to_visualize = 2022
measure_name = 'Trust MPS'

# Filter the data for the specified year and measure
filtered_df = Borough_df[(Borough_df['Date'].dt.year == year_to_visualize) & (Borough_df['Measure'] == measure_name)]

# Bar plot for average Proportion by Measure
plt.figure(figsize=(12, 6))
sns.barplot(x='month', y='Proportion', data=filtered_df)  # Use 'month' instead of 'Month'
plt.title(f'Average Proportion of {measure_name} in {year_to_visualize} by Month')
plt.xlabel('Month')
plt.ylabel('Average Proportion')
plt.xticks(rotation=45)
plt.show()

# %%
filtered_df
# Out:
#            Date Survey               Borough    Measure  Proportion   MPS  \
# 7488 2022-03-31    PAS  Barking and Dagenham  Trust MPS        0.77  0.73
# 7489 2022-03-31    PAS                Barnet  Trust MPS        0.77  0.73
# 7490 2022-03-31    PAS                Bexley  Trust MPS        0.79  0.73
# 7491 2022-03-31    PAS                 Brent  Trust MPS        0.78  0.73
# 7492 2022-03-31    PAS               Bromley  Trust MPS        0.75  0.73
# ...         ...    ...                   ...        ...         ...   ...
# 8059 2022-12-31    PAS                Sutton  Trust MPS        0.80  0.71
# 8060 2022-12-31    PAS         Tower Hamlets  Trust MPS        0.68  0.71
# 8061 2022-12-31    PAS        Waltham Forest  Trust MPS        0.64  0.71
# 8062 2022-12-31    PAS            Wandsworth  Trust MPS        0.71  0.71
# 8063 2022-12-31    PAS   City of Westminster  Trust MPS        0.74  0.71
#
#      month Month
# 7488   Mar   Mar
# 7489   Mar   Mar
# 7490   Mar   Mar
# 7491   Mar   Mar
# 7492   Mar   Mar
# ...    ...   ...
# 8059   Dec   Dec
# 8060   Dec   Dec
# 8061   Dec   Dec
# 8062   Dec   Dec
# 8063   Dec   Dec
#
# [128 rows x 8 columns]

# %%
# for year_to_visualize in [2014,2023]
MPS_2016 = Borough_df[(Borough_df['Date'].dt.year == 2016) & (Borough_df['Date'].dt.month == 3) & (Borough_df['Measure'] == measure_name)]
MPS_2022 = Borough_df[(Borough_df['Date'].dt.year == 2022) & (Borough_df['Date'].dt.month == 12) & (Borough_df['Measure'] == measure_name)]

Dif_2022 = MPS_2022['Proportion'].to_list()
Dif_2016 = MPS_2016['Proportion'].to_list()

# %%
MPS_2016
# Out:
#            Date Survey                 Borough    Measure  Proportion   MPS  \
# 6720 2016-03-31    PAS    Barking and Dagenham  Trust MPS        0.83  0.86
# 6721 2016-03-31    PAS                  Barnet  Trust MPS        0.87  0.86
# 6722 2016-03-31    PAS                  Bexley  Trust MPS        0.90  0.86
# 6723 2016-03-31    PAS                   Brent  Trust MPS        0.83  0.86
# 6724 2016-03-31    PAS                 Bromley  Trust MPS        0.88  0.86
# 6725 2016-03-31    PAS                  Camden  Trust MPS        0.84  0.86
# 6726 2016-03-31    PAS                 Croydon  Trust MPS        0.82  0.86
# 6727 2016-03-31    PAS                  Ealing  Trust MPS        0.86  0.86
# 6728 2016-03-31    PAS                 Enfield  Trust MPS        0.77  0.86
# 6729 2016-03-31    PAS               Greenwich  Trust MPS        0.86  0.86
# 6730 2016-03-31    PAS                 Hackney  Trust MPS        0.82  0.86
# 6731 2016-03-31    PAS  Hammersmith and Fulham  Trust MPS        0.92  0.86
# 6732 2016-03-31    PAS                Haringey  Trust MPS        0.82  0.86
# 6733 2016-03-31    PAS                  Harrow  Trust MPS        0.86  0.86
# 6734 2016-03-31    PAS                Havering  Trust MPS        0.92  0.86
# 6735 2016-03-31    PAS              Hillingdon  Trust MPS        0.84  0.86
# 6736 2016-03-31    PAS                Hounslow  Trust MPS        0.87  0.86
# 6737 2016-03-31    PAS               Islington  Trust MPS        0.88  0.86
# 6738 2016-03-31    PAS  Kensington and Chelsea  Trust MPS        0.92  0.86
# 6739 2016-03-31    PAS    Kingston upon Thames  Trust MPS        0.89  0.86
# 6740 2016-03-31    PAS                 Lambeth  Trust MPS        0.85  0.86
# 6741 2016-03-31    PAS                Lewisham  Trust MPS        0.84  0.86
# 6742 2016-03-31    PAS                  Merton  Trust MPS        0.86  0.86
# 6743 2016-03-31    PAS                  Newham  Trust MPS        0.85  0.86
# 6744 2016-03-31    PAS               Redbridge  Trust MPS        0.89  0.86
# 6745 2016-03-31    PAS    Richmond upon Thames  Trust MPS        0.92  0.86
# 6746 2016-03-31    PAS               Southwark  Trust MPS        0.89  0.86
# 6747 2016-03-31    PAS                  Sutton  Trust MPS        0.85  0.86
# 6748 2016-03-31    PAS           Tower Hamlets  Trust MPS        0.87  0.86
# 6749 2016-03-31    PAS          Waltham Forest  Trust MPS        0.84  0.86
# 6750 2016-03-31    PAS              Wandsworth  Trust MPS        0.88  0.86
# 6751 2016-03-31    PAS     City of Westminster  Trust MPS        0.94  0.86
#
#      month Month
# 6720   Mar   Mar
# 6721   Mar   Mar
# 6722   Mar   Mar
# 6723   Mar   Mar
# 6724   Mar   Mar
# 6725   Mar   Mar
# 6726   Mar   Mar
# 6727   Mar   Mar
# 6728   Mar   Mar
# 6729   Mar   Mar
# 6730   Mar   Mar
# 6731   Mar   Mar
# 6732   Mar   Mar
# 6733   Mar   Mar
# 6734   Mar   Mar
# 6735   Mar   Mar
# 6736   Mar   Mar
# 6737   Mar   Mar
# 6738   Mar   Mar
# 6739   Mar   Mar
# 6740   Mar   Mar
# 6741   Mar   Mar
# 6742   Mar   Mar
# 6743   Mar   Mar
# 6744   Mar   Mar
# 6745   Mar   Mar
# 6746   Mar   Mar
# 6747   Mar   Mar
# 6748   Mar   Mar
# 6749   Mar   Mar
# 6750   Mar   Mar
# 6751   Mar   Mar

# %%
all_borough = ['Barking and Dagenham',
 'Barnet',
 'Bexley',
 'Brent',
 'Bromley',
 'Camden',
 'Croydon',
 'Ealing',
 'Enfield',
 'Greenwich',
 'Hackney',
 'Hammersmith and Fulham',
 'Haringey',
 'Harrow',
 'Havering',
 'Hillingdon',
 'Hounslow',
 'Islington',
 'Kensington and Chelsea',
 'Kingston upon Thames',
 'Lambeth',
 'Lewisham',
 'Merton',
 'Newham',
 'Redbridge',
 'Richmond upon Thames',
 'Southwark',
 'Sutton',
 'Tower Hamlets',
 'Waltham Forest',
 'Wandsworth', 'Westminster']

# %%
difference = [abs(p2 - p1) for p1, p2 in zip(Dif_2016, Dif_2022)]
difference
# Out:
# [0.09999999999999998,
#  0.10999999999999999,
#  0.17000000000000004,
#  0.09999999999999998,
#  0.16000000000000003,
#  0.15999999999999992,
#  0.19999999999999996,
#  0.09999999999999998,
#  0.07000000000000006,
#  0.17999999999999994,
#  0.16999999999999993,
#  0.2300000000000001,
#  0.1499999999999999,
#  0.06999999999999995,
#  0.16000000000000003,
#  0.010000000000000009,
#  0.12,
#  0.27,
#  0.17000000000000004,
#  0.13,
#  0.2899999999999999,
#  0.19999999999999996,
#  0.08999999999999997,
#  0.15000000000000002,
#  0.17000000000000004,
#  0.21000000000000008,
#  0.22999999999999998,
#  0.04999999999999993,
#  0.18999999999999995,
#  0.19999999999999996,
#  0.17000000000000004,
#  0.19999999999999996]

# %%
new_dict = {}
for i, j in zip(all_borough, difference):
    new_dict[i] = j

max_key = max(new_dict, key=lambda k: new_dict[k])
min_key = min(new_dict, key=lambda k: new_dict[k])

print(f'max: {max_key}, min: {min_key}')
# Out:
# max: Lambeth, min: Hillingdon

# %%
city_df = Borough_df[(Borough_df['Measure'] == measure_name) & (Borough_df['Borough'] == 'Lambeth')]
plt.plot(city_df['Date'], city_df['Proportion'])
plt.ylim(0.5, 1);

# %%
city_df = Borough_df[(Borough_df['Measure'] == measure_name) & (Borough_df['Borough'] == 'Wandsworth')]
plt.plot(city_df['Date'], city_df['Proportion'])
plt.ylim(0.5, 1);

# %%
for i in all_borough:
    city_df = Borough_df[(Borough_df['Measure'] == measure_name) & (Borough_df['Borough'] == i)]
    plt.figure()
    plt.plot(city_df['Date'], city_df['Proportion'])
    plt.ylim(0.5, 1)
    plt.title(f'{i} Proportion over Time')
    plt.xlabel('Date')
    plt.ylabel('Proportion')
    plt.show()

# %%
crime_df = pd.read_csv(r"C:\Users\assis\Downloads\combined_crime.csv")
# Out:
# C:\Users\assis\AppData\Local\Temp\ipykernel_128\1938710580.py:1: DtypeWarning: Columns (0,4,5,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   crime_df = pd.read_csv(r"C:\Users\assis\Downloads\combined_crime.csv")

# %%
crime_df.columns
# Out:
# Index(['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type',
#        'Last outcome category', 'Context'],
#       dtype='object')

# %%
list_of_lsoa_names = list(set(crime_df["LSOA name"].to_list()))
list_of_lsoa_names
# Out:
# [nan,
#  'Barking and Dagenham 011B',
#  'Teignbridge 017B',
#  'Southend-on-Sea 010F',
#  'Greenwich 008C',
#  'Redbridge 036A',
#  'Knowsley 018B',
#  'Braintree 009A',
#  'Mid Sussex 003E',
#  'Kensington and Chelsea 016D',
#  'Gravesham 007D',
#  'Wealden 018C',
#  'Bolton 031D',
#  'Tandridge 009D',
#  'Medway 018A',
#  'Cornwall 060B',
#  'Broxbourne 013C',
#  'Westminster 021B',
#  'Tonbridge and Malling 001H',
#  'South Northamptonshire 002B',
#  'Runnymede 007E',
#  'Ealing 006C',
#  'Brent 031H',
#  'Waltham Forest 012E',
#  'Milton Keynes 023E',
#  'Reading 002D',
#  'Rugby 007E',
#  'Hackney 030A',
#  'Basildon 020D',
#  'Stoke-on-Trent 020A',
#  'Enfield 023D',
#  'Thurrock 015E',
#  'Tower Hamlets 024E',
#  'St Albans 018G',
#  'West Oxfordshire 012C',
#  'Bexley 011E',
#  'Luton 010B',
#  'Hammersmith and Fulham 014D',
#  'Redbridge 037E',
#  'Bexley 017A',
#  'Rother 010C',
#  'Eastbourne 011B',
#  'Manchester 008D',
#  'Barnet 001A',
#  'Lambeth 034C',
#  'Guildford 004B',
#  'Tamworth 005D',
#  'Blackpool 005C',
#  'Havering 002B',
#  'Scarborough 007A',
#  'Dover 002D',
#  'Hillingdon 013A',
#  'Bromley 013C',
#  'Oldham 022B',
#  'Manchester 021C',
#  'Hackney 021B',
#  'Erewash 014A',
#  'Liverpool 049B',
#  'Birmingham 090E',
#  'Lambeth 024D',
#  'Islington 010D',
#  'Tendring 004F',
#  'Sheffield 027C',
#  'Ipswich 005B',
#  'Wyre Forest 005A',
#  'Cardiff 038B',
#  'Tower Hamlets 013A',
#  'Brent 005A',
#  'Southwark 014E',
#  'Maldon 004C',
#  'Ealing 039A',
#  'Telford and Wrekin 021A',
#  'Nottingham 039G',
#  'Lewisham 002C',
#  'Leeds 072C',
#  'Dartford 004C',
#  'Epping Forest 016A',
#  'Bexley 010A',
#  'North East Derbyshire 006C',
#  'East Hertfordshire 004E',
#  'North Lincolnshire 022A',
#  'Barnet 016C',
#  'Spelthorne 003E',
#  'Windsor and Maidenhead 002F',
#  'Harborough 003B',
#  'East Dorset 002E',
#  'Calderdale 004F',
#  'Hillingdon 015J',
#  'Redbridge 032F',
#  'Bradford 031C',
#  'Newham 039B',
#  'Rushcliffe 009E',
#  'Newham 025C',
#  'Coventry 027D',
#  'Chelmsford 005E',
#  'Tendring 014B',
#  'Thurrock 022D',
#  'Cardiff 037B',
#  'Welwyn Hatfield 013C',
#  'Southend-on-Sea 001B',
#  'Trafford 017D',
#  'Havering 021C',
#  'Fenland 006E',
#  'Southend-on-Sea 004A',
#  'Test Valley 004E',
#  'Tunbridge Wells 001C',
#  'Nottingham 022C',
#  'Wandsworth 015C',
#  'South Somerset 015D',
#  'Croydon 016D',
#  'Nottingham 032D',
#  'Cambridge 007C',
#  'Bromley 002C',
#  'Hammersmith and Fulham 003C',
#  'Tower Hamlets 017C',
#  'Isle of Wight 010B',
#  'Bristol 054C',
#  'Walsall 035C',
#  'Ealing 002B',
#  'Coventry 036G',
#  'Aylesbury Vale 015C',
#  'Tendring 008G',
#  'Wycombe 017E',
#  'Waverley 016C',
#  'Nottingham 017B',
#  'Fenland 005C',
#  'Rochdale 008G',
#  'Camden 026A',
#  'Havering 011C',
#  'North Lincolnshire 001E',
#  'Luton 015A',
#  'Slough 005D',
#  'Manchester 021D',
#  'Nottingham 022A',
#  'Braintree 015D',
#  'Leeds 112E',
#  'Waltham Forest 026B',
#  'Bolton 015C',
#  'Epping Forest 004A',
#  'Barking and Dagenham 002E',
#  'Exeter 004D',
#  'City of London 001B',
#  'Newham 035D',
#  'Redbridge 003B',
#  'Wandsworth 023A',
#  'Canterbury 006B',
#  'Ealing 033E',
#  'Southwark 004F',
#  'Waltham Forest 007A',
#  'Luton 012A',
#  'Arun 012D',
#  'Medway 015B',
#  'Lewisham 020F',
#  'Merton 018C',
#  'Tandridge 010D',
#  'Southend-on-Sea 004B',
#  'Southend-on-Sea 012A',
#  'Lambeth 032F',
#  'Hounslow 008E',
#  'Liverpool 030B',
#  'Merton 020B',
#  'Adur 006A',
#  'Lewisham 029C',
#  'Wandsworth 019A',
#  'Camden 022C',
#  'Thurrock 014B',
#  'Tandridge 004B',
#  'Poole 013B',
#  'Manchester 052A',
#  'Brent 025C',
#  'Hammersmith and Fulham 017D',
#  'Waverley 012B',
#  'Sevenoaks 004C',
#  'Islington 006C',
#  'Cotswold 004D',
#  'Slough 008D',
#  'Hastings 005D',
#  'Chelmsford 018D',
#  'Birmingham 050C',
#  'Ealing 021A',
#  'Croydon 016B',
#  'Buckinghamshire 058D',
#  'Hammersmith and Fulham 006A',
#  'Greenwich 036A',
#  'Hounslow 006B',
#  'Ipswich 012A',
#  'Birmingham 071C',
#  'Rotherham 014D',
#  'Dacorum 014A',
#  'Ipswich 008A',
#  'Newham 019B',
#  'Thurrock 004C',
#  'Dudley 031A',
#  'Kensington and Chelsea 020C',
#  'Slough 009C',
#  'Maidstone 014B',
#  'Haringey 022D',
#  'Blackpool 007C',
#  'Havering 025D',
#  'Tandridge 008C',
#  'Cornwall 063A',
#  'Carmarthenshire 024C',
#  'Stoke-on-Trent 019B',
#  'Kingston upon Thames 018D',
#  'Leeds 054D',
#  'Sevenoaks 008G',
#  'Camden 029E',
#  'Croydon 026C',
#  'Harrow 001A',
#  'Hillingdon 020E',
#  'Southampton 002D',
#  'Huntingdonshire 016C',
#  'Redbridge 004B',
#  'Gedling 014B',
#  'County Durham 051A',
#  'Huntingdonshire 011B',
#  'Cotswold 011F',
#  'Wandsworth 002D',
#  'Wolverhampton 013D',
#  'Great Yarmouth 006A',
#  'North East Lincolnshire 016B',
#  'Leicester 028D',
#  'Woking 003C',
#  'Oxford 013B',
#  'Newcastle upon Tyne 013D',
#  'Oadby and Wigston 005B',
#  'Leeds 099A',
#  'Epsom and Ewell 010A',
#  'Redbridge 006D',
#  'Brent 002D',
#  'Cornwall 023A',
#  'Salford 006C',
#  'Sevenoaks 009D',
#  'Worthing 010D',
#  'Slough 011H',
#  'Rother 002A',
#  'Medway 007D',
#  'Enfield 006E',
#  'Slough 003E',
#  'Worcester 008A',
#  'Waverley 018A',
#  'Denbighshire 009B',
#  'Islington 009B',
#  'Hambleton 004D',
#  'Bexley 015D',
#  'Aylesbury Vale 016C',
#  'North Hertfordshire 004A',
#  'Bournemouth, Christchurch and Poole 047B',
#  'Wiltshire 055D',
#  'Westminster 016E',
#  'Brentwood 001F',
#  'New Forest 011E',
#  'Southwark 022D',
#  'Ealing 006E',
#  'Hillingdon 010A',
#  'Chichester 003B',
#  'Wandsworth 018B',
#  'Welwyn Hatfield 006B',
#  'Bexley 009C',
#  'Cherwell 007D',
#  'Lambeth 021D',
#  'Elmbridge 017D',
#  'Norwich 013C',
#  'Luton 017A',
#  'Cardiff 037A',
#  'Central Bedfordshire 008E',
#  'South Gloucestershire 025E',
#  'Runnymede 007D',
#  'Haringey 033A',
#  'Birmingham 060C',
#  'Taunton Deane 008E',
#  'Brent 001E',
#  'Manchester 026A',
#  'Stratford-on-Avon 009B',
#  'Luton 021G',
#  'Merton 020E',
#  'Buckinghamshire 066B',
#  'Haringey 011D',
#  'Birmingham 043B',
#  'Dacorum 014B',
#  'Richmond upon Thames 021B',
#  'Lewisham 020D',
#  'Coventry 010A',
#  'Richmond upon Thames 013B',
#  'Newport 017B',
#  'Hastings 007D',
#  'Newham 042E',
#  'Kensington and Chelsea 005C',
#  'Merton 025C',
#  'Tonbridge and Malling 008A',
#  'Exeter 008A',
#  'Southwark 033E',
#  'Bromley 042C',
#  'Harrow 002B',
#  'Cheshire East 008B',
#  'Croydon 045C',
#  'Epsom and Ewell 004A',
#  'Southampton 013E',
#  'Brighton and Hove 002B',
#  'Bournemouth 013C',
#  'Aylesbury Vale 015F',
#  'East Riding of Yorkshire 031B',
#  'Stevenage 010B',
#  'Merton 008A',
#  'Sheffield 068E',
#  'Conwy 001B',
#  'Newark and Sherwood 013B',
#  'West Somerset 004C',
#  'Southwark 013E',
#  'Swindon 011A',
#  'Bath and North East Somerset 011D',
#  'Kingston upon Thames 020B',
#  'Cheltenham 009B',
#  'Lewisham 012F',
#  'Sandwell 029B',
#  'Brent 019A',
#  'Newham 027C',
#  'Swindon 018A',
#  'Hertsmere 013F',
#  'Sedgemoor 004B',
#  'Medway 003G',
#  'Welwyn Hatfield 004A',
#  'East Hertfordshire 005E',
#  'Hackney 028A',
#  'Salford 003B',
#  'East Dorset 008B',
#  'St Albans 005C',
#  'Guildford 001A',
#  'Brent 012D',
#  'Halton 012B',
#  'Westminster 013D',
#  'Leicester 038E',
#  'Greenwich 037B',
#  'Oxford 014A',
#  'Ashford 009D',
#  'Bexley 017D',
#  'Dover 004A',
#  'Harlow 008A',
#  'Doncaster 008B',
#  'Tower Hamlets 024G',
#  'Barrow-in-Furness 003B',
#  'Telford and Wrekin 015D',
#  'Hounslow 027A',
#  'Guildford 012D',
#  'Camden 003C',
#  'South Oxfordshire 009A',
#  'Newham 013E',
#  'Bracknell Forest 001E',
#  'Enfield 001D',
#  'Cheshire East 011B',
#  'Central Bedfordshire 012B',
#  'Bexley 018F',
#  'Westminster 007A',
#  'Brighton and Hove 019D',
#  'Reading 020D',
#  'Lambeth 007D',
#  'Bexley 020G',
#  'Enfield 035C',
#  'Redbridge 032C',
#  'Brent 035A',
#  'West Suffolk 011A',
#  'Reading 008A',
#  'Southwark 025D',
#  'Hertsmere 003E',
#  'Elmbridge 016C',
#  'Birmingham 087F',
#  'Hillingdon 017A',
#  'Hillingdon 007D',
#  'Haringey 008D',
#  'Newham 008D',
#  'Tamworth 006B',
#  'Birmingham 110C',
#  'Dartford 001D',
#  'Islington 011C',
#  'Redbridge 030A',
#  'Barnet 029D',
#  'Waltham Forest 004D',
#  'Haringey 002A',
#  'Tunbridge Wells 011D',
#  'Barking and Dagenham 007C',
#  'Waverley 013C',
#  'Sutton 003B',
#  'Hounslow 014D',
#  'Kensington and Chelsea 018E',
#  'Camden 029G',
#  'Redbridge 032E',
#  'Maidstone 019D',
#  'Birmingham 134C',
#  'Sunderland 012F',
#  'Mid Sussex 006D',
#  'Hackney 022A',
#  'Birmingham 049D',
#  'Greenwich 016C',
#  'Bromley 015A',
#  'Waltham Forest 028F',
#  'Milton Keynes 014E',
#  'Tower Hamlets 008F',
#  'Barnet 041C',
#  'Brent 031G',
#  'Darlington 008F',
#  'Newport 020F',
#  'Hackney 028E',
#  'Medway 030A',
#  'Sefton 009F',
#  'Bournemouth, Christchurch and Poole 044F',
#  'Bromsgrove 010B',
#  'Knowsley 019B',
#  'Hounslow 012D',
#  'Central Bedfordshire 013B',
#  'West Lancashire 006E',
#  'Castle Point 001B',
#  'Huntingdonshire 003B',
#  'Stratford-on-Avon 012B',
#  'Ealing 018F',
#  'Epping Forest 015F',
#  'Tendring 013D',
#  'Bournemouth, Christchurch and Poole 041B',
#  'Leeds 081A',
#  'St Edmundsbury 013B',
#  'Enfield 021D',
#  'Enfield 014C',
#  'Sheffield 048A',
#  'Walsall 018E',
#  'Manchester 029F',
#  'Hammersmith and Fulham 021B',
#  'Canterbury 017A',
#  'Norwich 003E',
#  'Enfield 002A',
#  'Derby 023B',
#  'Canterbury 011B',
#  'Birmingham 103F',
#  'Coventry 028E',
#  'Greenwich 023A',
#  'Tower Hamlets 023D',
#  'Croydon 019B',
#  'Elmbridge 004A',
#  'Birmingham 097D',
#  'Camden 001D',
#  'Sevenoaks 001C',
#  'Spelthorne 010C',
#  'Thanet 004A',
#  'Lambeth 031B',
#  'Hounslow 013E',
#  'Medway 015A',
#  'Wolverhampton 035H',
#  'Enfield 032E',
#  'Newport 006B',
#  'Cheshire East 007A',
#  'Barnet 021E',
#  'Exeter 008D',
#  'Ealing 041B',
#  'Manchester 020E',
#  'East Hampshire 001D',
#  'Forest of Dean 007D',
#  'Kingston upon Hull 011C',
#  'Newham 012B',
#  'Knowsley 013A',
#  'East Devon 002C',
#  'Hillingdon 017B',
#  'Coventry 007A',
#  'Bassetlaw 004E',
#  'Malvern Hills 011D',
#  'Corby 002C',
#  'Barking and Dagenham 008C',
#  'Hackney 006D',
#  'Blackburn with Darwen 003B',
#  'Havering 025C',
#  'Tower Hamlets 032A',
#  'Middlesbrough 003D',
#  'Cardiff 046D',
#  'Enfield 009A',
#  'Wychavon 003B',
#  'North Norfolk 007D',
#  'Luton 003B',
#  'Swansea 017B',
#  'Forest of Dean 005B',
#  'Bromley 018C',
#  'Kensington and Chelsea 015C',
#  'Greenwich 020A',
#  'Richmond upon Thames 009B',
#  'Slough 011E',
#  'Merton 018A',
#  'Bexley 013C',
#  'Chelmsford 017C',
#  'Wycombe 024F',
#  'Birmingham 030D',
#  'Kensington and Chelsea 019C',
#  'Newport 018D',
#  'Swindon 007D',
#  'Redbridge 001C',
#  'Exeter 011E',
#  'South Tyneside 002E',
#  'East Hampshire 007A',
#  'Broadland 017B',
#  'Bedford 021A',
#  'Islington 002B',
#  'Tower Hamlets 010F',
#  'Harrow 007A',
#  'Tower Hamlets 024F',
#  'Haringey 027B',
#  'Eastleigh 011E',
#  'Sandwell 032D',
#  'Ipswich 008E',
#  'Birmingham 048C',
#  'Eastleigh 015B',
#  'Lewisham 001G',
#  'Newham 004A',
#  'Cornwall 057A',
#  'Merton 014A',
#  'Coventry 015H',
#  'Ealing 009C',
#  'Tower Hamlets 018F',
#  'Bristol 056A',
#  'Brent 021E',
#  'Rushmoor 007C',
#  'Buckinghamshire 008F',
#  'Suffolk Coastal 001C',
#  'South Somerset 010A',
#  'Hyndburn 006B',
#  'Barnet 014E',
#  'Hillingdon 011D',
#  'Dacorum 017A',
#  'Barnet 020E',
#  'Maidstone 013E',
#  'Oxford 009C',
#  'Wolverhampton 017D',
#  'Hillingdon 030B',
#  'Epping Forest 014A',
#  'Leeds 075F',
#  'Elmbridge 017B',
#  'Melton 004F',
#  'Camden 023D',
#  'Oadby and Wigston 006E',
#  'Reading 005D',
#  'Greenwich 014C',
#  'Rutland 001B',
#  'Hammersmith and Fulham 001E',
#  'Breckland 009B',
#  'Barnet 021B',
#  'North Lincolnshire 005E',
#  'Harrow 005C',
#  'Coventry 012A',
#  'Bromley 001B',
#  'Reading 012E',
#  'Nottingham 005E',
#  'Tunbridge Wells 004B',
#  'Bath and North East Somerset 012F',
#  'Kirklees 047C',
#  'Redbridge 029D',
#  'Rother 011C',
#  'Hartlepool 014D',
#  'Havant 014E',
#  'Lambeth 012E',
#  'South Norfolk 004B',
#  'Merton 016B',
#  'Wyre 002B',
#  'Bromley 015C',
#  'Bedford 018D',
#  'Croydon 032C',
#  'Hounslow 010B',
#  'Sutton 007D',
#  'Swale 013C',
#  'Bolton 025B',
#  'Dover 006D',
#  'Reigate and Banstead 004D',
#  'Lambeth 020E',
#  'Preston 010D',
#  'Wrexham 011C',
#  'Hounslow 017G',
#  'Horsham 007D',
#  'Uttlesford 005C',
#  'Trafford 006E',
#  'Croydon 002D',
#  'Shropshire 006D',
#  'Lambeth 032D',
#  'West Oxfordshire 002A',
#  'Mendip 008A',
#  'Birmingham 008C',
#  'North Kesteven 010D',
#  'Lewisham 017E',
#  'Darlington 001B',
#  'Chesterfield 006B',
#  'East Riding of Yorkshire 041A',
#  'Stevenage 007B',
#  'Medway 037B',
#  'Barking and Dagenham 010C',
#  'Wokingham 014B',
#  'Kensington and Chelsea 003E',
#  'Breckland 016A',
#  'Kirklees 010B',
#  'Enfield 029A',
#  'Hounslow 017A',
#  'Harrow 017C',
#  'Mid Sussex 016A',
#  'Fenland 011F',
#  'Havering 018E',
#  'Tower Hamlets 001C',
#  'South Oxfordshire 002A',
#  'Enfield 018E',
#  'Leeds 007F',
#  'Slough 003D',
#  'Guildford 007B',
#  'Wigan 025B',
#  'Tonbridge and Malling 014H',
#  'Croydon 015C',
#  'Haringey 016A',
#  'Crawley 005D',
#  'Slough 011D',
#  'Lewisham 026B',
#  'Brighton and Hove 016B',
#  'Fareham 001B',
#  'Newham 016A',
#  'Mendip 001C',
#  'Bromley 014B',
#  'Watford 012A',
#  'Swale 006D',
#  'Hillingdon 028D',
#  'Richmond upon Thames 022F',
#  'Gravesham 004E',
#  'Canterbury 020B',
#  'Chesterfield 003A',
#  'Enfield 033C',
#  'Wellingborough 010B',
#  'Hackney 027F',
#  'Tower Hamlets 014E',
#  'North Dorset 003A',
#  'Waltham Forest 009E',
#  'Bedford 005D',
#  'Waltham Forest 017E',
#  'St Edmundsbury 009G',
#  'Coventry 042A',
#  'Windsor and Maidenhead 017C',
#  'Kirklees 017B',
#  'Wirral 018B',
#  'County Durham 028A',
#  'Basildon 015C',
#  'Waltham Forest 026C',
#  'Brent 021F',
#  'Cheltenham 004E',
#  'Sevenoaks 004B',
#  'Birmingham 132C',
#  'Greenwich 004C',
#  'Haringey 034B',
#  'Bromley 020D',
#  'Thurrock 005E',
#  'Bromley 005C',
#  'Welwyn Hatfield 002F',
#  'Fareham 009D',
#  'Barnet 005A',
#  'South Cambridgeshire 001D',
#  'Tunbridge Wells 002E',
#  'Bromley 030E',
#  'Elmbridge 018D',
#  'Wandsworth 007A',
#  'Wokingham 009D',
#  'Wrexham 007C',
#  'Hounslow 012E',
#  'Reading 008F',
#  'Kingston upon Thames 003A',
#  'Merton 013E',
#  'Sheffield 032A',
#  'Wigan 027C',
#  'Fareham 002D',
#  'Hertsmere 009B',
#  'Gloucester 001B',
#  'Southampton 021A',
#  'Bromley 024E',
#  'Barnet 004B',
#  'Brent 029E',
#  'Dudley 011D',
#  'York 013I',
#  'Isle of Wight 010A',
#  'Tendring 006A',
#  'South Cambridgeshire 002D',
#  'Chichester 004A',
#  'Castle Point 006B',
#  'Richmond upon Thames 021A',
#  'Hackney 004A',
#  'Sheffield 070B',
#  'Hertsmere 003B',
#  'South Staffordshire 009C',
#  'Richmondshire 001C',
#  'Lambeth 019C',
#  'Stockton-on-Tees 014A',
#  'Waltham Forest 028B',
#  'Northampton 025B',
#  'Three Rivers 010C',
#  'Wandsworth 008C',
#  'Tendring 015A',
#  'Merton 004D',
#  'East Lindsey 008E',
#  'Birmingham 033E',
#  'Forest Heath 008E',
#  'Lewisham 038B',
#  'Luton 003D',
#  'Hillingdon 021F',
#  'Newham 006D',
#  'Westminster 024F',
#  'Colchester 015H',
#  'St. Helens 005D',
#  'Kensington and Chelsea 008B',
#  'Hackney 020D',
#  'Broxbourne 012A',
#  'Tandridge 011A',
#  'North Tyneside 020B',
#  'Woking 009D',
#  'Bury 008F',
#  'Southend-on-Sea 007B',
#  'Barnet 010B',
#  'Barnet 041B',
#  'Sutton 013C',
#  'Greenwich 003A',
#  'North Somerset 013B',
#  'Three Rivers 008D',
#  'Wigan 025C',
#  'Epping Forest 013C',
#  'Hackney 014E',
#  'Tandridge 003D',
#  'Camden 007E',
#  'Suffolk Coastal 007H',
#  'Windsor and Maidenhead 002E',
#  'Wandsworth 029C',
#  'Liverpool 037F',
#  'Nottingham 023G',
#  'Haringey 016C',
#  'Oxford 013G',
#  'Harlow 010D',
#  'Harrow 023A',
#  'Croydon 010A',
#  'Elmbridge 018C',
#  'Hackney 004D',
#  'Bromley 033A',
#  'Hillingdon 026C',
#  'Rochdale 015D',
#  'Oxford 020C',
#  'Tower Hamlets 008D',
#  'Basildon 017D',
#  'Wycombe 011B',
#  'Oadby and Wigston 011E',
#  'Croydon 025B',
#  'Tendring 018B',
#  'Cardiff 042D',
#  'Enfield 031D',
#  'Birmingham 032C',
#  'Chelmsford 011D',
#  'Great Yarmouth 001B',
#  'Newham 023B',
#  'Dartford 007B',
#  'Lewisham 005A',
#  'Croydon 014D',
#  'Swansea 022E',
#  'South Northamptonshire 010D',
#  'Sevenoaks 004D',
#  'Wellingborough 007B',
#  'Mole Valley 003A',
#  'Bristol 059D',
#  'Tower Hamlets 026C',
#  'Camden 001A',
#  'Canterbury 001A',
#  'Westminster 007E',
#  'Hounslow 006G',
#  'Cornwall 018F',
#  'Camden 026C',
#  'Hammersmith and Fulham 021C',
#  'Uttlesford 006E',
#  'Mid Sussex 005B',
#  'Wokingham 001A',
#  'East Lindsey 012B',
#  'Chelmsford 016C',
#  'Lewisham 021E',
#  'Richmond upon Thames 008B',
#  'Mid Suffolk 009C',
#  'Barking and Dagenham 016E',
#  'Blackpool 016E',
#  'Greenwich 006B',
#  'Barnet 028B',
#  'Gravesham 008A',
#  'Sheffield 022B',
#  'Wolverhampton 005A',
#  "King's Lynn and West Norfolk 004C",
#  'Bournemouth 017A',
#  'Watford 008C',
#  'Telford and Wrekin 004C',
#  'Charnwood 021F',
#  'Newham 030D',
#  'Tandridge 006E',
#  'Maidstone 004A',
#  'Rochdale 008I',
#  'Dorset 020A',
#  'Barking and Dagenham 003C',
#  'Swale 006C',
#  'Monmouthshire 007F',
#  'Gateshead 004E',
#  'Dacorum 002D',
#  'Eden 005A',
#  'Dartford 006A',
#  'Brentwood 008A',
#  'West Devon 005E',
#  'Waltham Forest 028D',
#  'Bradford 049G',
#  'Northampton 016E',
#  'Croydon 019C',
#  'Newham 026D',
#  'Hart 005D',
#  'Harrow 010D',
#  'Tonbridge and Malling 007E',
#  'Slough 005C',
#  'Hertsmere 004D',
#  'North Somerset 010E',
#  'Tameside 022A',
#  'Worthing 007E',
#  'North Hertfordshire 016D',
#  'Sutton 004B',
#  'Uttlesford 005A',
#  'Medway 017A',
#  'Chichester 005B',
#  'Bromley 005G',
#  'Rhondda Cynon Taf 030B',
#  'Gateshead 027B',
#  'Breckland 014C',
#  'Merton 001D',
#  'Newham 004D',
#  'Enfield 037B',
#  'Wokingham 002E',
#  'Derby 016E',
#  'Calderdale 008E',
#  'Erewash 008E',
#  'Croydon 011C',
#  'Northampton 013B',
#  'Ealing 019G',
#  'Dacorum 015A',
#  'Rotherham 011C',
#  'Broxtowe 009E',
#  'Blackpool 003C',
#  'Haringey 018D',
#  'Wychavon 006B',
#  'Suffolk Coastal 015A',
#  'Bexley 002B',
#  'Lichfield 011B',
#  'North Hertfordshire 005D',
#  'Islington 001F',
#  'Islington 016A',
#  'Castle Point 010E',
#  'Nottingham 009B',
#  'Birmingham 037F',
#  'County Durham 030A',
#  'Sandwell 031D',
#  'North West Leicestershire 003A',
#  'Huntingdonshire 016F',
#  'St Albans 009A',
#  'Wandsworth 039B',
#  'Trafford 004B',
#  'Carmarthenshire 026E',
#  'Worthing 008A',
#  'Peterborough 015C',
#  'North Hertfordshire 010A',
#  'Broadland 016D',
#  'Bexley 028A',
#  'Islington 001B',
#  'North Hertfordshire 012E',
#  'Calderdale 013F',
#  'Central Bedfordshire 004B',
#  'Cornwall 032A',
#  'Hertsmere 010A',
#  'Reigate and Banstead 017D',
#  'Northumberland 019C',
#  'Elmbridge 012E',
#  'Broadland 014C',
#  'Huntingdonshire 010G',
#  'Northumberland 010B',
#  'Liverpool 050I',
#  'Swale 010B',
#  'West Lancashire 009D',
#  'Suffolk Coastal 010A',
#  'Enfield 036B',
#  'Medway 015F',
#  'Surrey Heath 012C',
#  'Reading 010C',
#  'Cornwall 030C',
#  'Greenwich 017C',
#  'Peterborough 011E',
#  'Dacorum 009A',
#  'Croydon 031A',
#  'Barnet 007E',
#  'Tendring 016C',
#  'Havering 029C',
#  'Islington 016F',
#  'Shepway 005F',
#  'Oxford 006D',
#  'Hackney 012D',
#  'Wealden 019B',
#  'Waltham Forest 004A',
#  'Spelthorne 004G',
#  'Thurrock 018C',
#  'Tewkesbury 007H',
#  'Surrey Heath 010C',
#  'Runnymede 001A',
#  'Bromley 029E',
#  'West Devon 001D',
#  'Croydon 021B',
#  'Wakefield 017D',
#  'Bury 016B',
#  'Tunbridge Wells 007D',
#  'Welwyn Hatfield 009D',
#  'Hart 006B',
#  'Swale 012D',
#  'Hillingdon 006C',
#  'Lewisham 001B',
#  'Hillingdon 004D',
#  'Havering 003B',
#  'Portsmouth 016F',
#  'Basildon 010C',
#  'Preston 016A',
#  'Waveney 002A',
#  'Rotherham 025C',
#  'Tamworth 003A',
#  'North Northamptonshire 011B',
#  'Birmingham 090A',
#  'County Durham 039D',
#  'Manchester 035E',
#  'Blackburn with Darwen 003E',
#  'Rochdale 009B',
#  'Milton Keynes 014B',
#  'Cotswold 009B',
#  'Brentwood 002B',
#  'Redditch 004A',
#  'Wandsworth 035F',
#  'Leeds 037A',
#  'Dudley 038B',
#  'Haringey 020D',
#  'Bedford 015B',
#  'Chorley 007C',
#  'Colchester 016A',
#  'Tendring 002D',
#  'Waltham Forest 016A',
#  'Southwark 017D',
#  'Harlow 011B',
#  'Nuneaton and Bedworth 003B',
#  'Leicester 002B',
#  'Sevenoaks 010C',
#  'Haringey 026B',
#  'Tower Hamlets 032E',
#  'Westminster 008B',
#  'Sandwell 034D',
#  'Bexley 027B',
#  'Wealden 005B',
#  'Tower Hamlets 021D',
#  'Ceredigion 002A',
#  'Westminster 021F',
#  'Windsor and Maidenhead 014E',
#  'Southampton 027B',
#  'Bromley 006B',
#  'Cherwell 008C',
#  'Hillingdon 018B',
#  'East Hampshire 006C',
#  'Barking and Dagenham 017B',
#  'Tower Hamlets 011D',
#  'Southwark 028C',
#  'Kingston upon Thames 011C',
#  'Walsall 013D',
#  'Redbridge 039A',
#  'West Dorset 006C',
#  'Buckinghamshire 056D',
#  'Stevenage 001A',
#  'Luton 010D',
#  'Newham 034M',
#  'Norwich 012B',
#  'New Forest 019C',
#  'Bexley 024E',
#  'Nottingham 023D',
#  'Barnet 023A',
#  'Birmingham 041G',
#  'Hounslow 017B',
#  'Rhondda Cynon Taf 016B',
#  'Wigan 038E',
#  'Blackpool 013B',
#  'Newham 028B',
#  'Derby 021A',
#  'Sutton 009A',
#  'Buckinghamshire 052C',
#  'Ealing 042B',
#  'Spelthorne 008E',
#  'Havering 028B',
#  'Broxbourne 006A',
#  'Kensington and Chelsea 001E',
#  'Lambeth 024B',
#  'Newcastle upon Tyne 029D',
#  'Hackney 006A',
#  'Welwyn Hatfield 010B',
#  'Redbridge 035E',
#  'Greenwich 035A',
#  'Gateshead 026C',
#  'Telford and Wrekin 012C',
#  'Vale of White Horse 006E',
#  'Havering 027E',
#  'Welwyn Hatfield 009C',
#  'Sunderland 029C',
#  'Hounslow 021E',
#  'Ealing 007D',
#  'Waverley 001B',
#  ...]

# %%
import re
list_of_boroughs = []
pattern = r'^([a-zA-Z\s]+)'
for i in list_of_lsoa_names[1:len(list_of_lsoa_names)]:
    match = re.findall(pattern, i)[0]
    match = match[0:len(match)-1]
    list_of_boroughs.append(match)
list_of_boroughs
# Out:
# ['Barking and Dagenham',
#  'Teignbridge',
#  'Southen',
#  'Greenwich',
#  'Redbridge',
#  'Knowsley',
#  'Braintree',
#  'Mid Sussex',
#  'Kensington and Chelsea',
#  'Gravesham',
#  'Wealden',
#  'Bolton',
#  'Tandridge',
#  'Medway',
#  'Cornwall',
#  'Broxbourne',
#  'Westminster',
#  'Tonbridge and Malling',
#  'South Northamptonshire',
#  'Runnymede',
#  'Ealing',
#  'Brent',
#  'Waltham Forest',
#  'Milton Keynes',
#  'Reading',
#  'Rugby',
#  'Hackney',
#  'Basildon',
#  'Stok',
#  'Enfield',
#  'Thurrock',
#  'Tower Hamlets',
#  'St Albans',
#  'West Oxfordshire',
#  'Bexley',
#  'Luton',
#  'Hammersmith and Fulham',
#  'Redbridge',
#  'Bexley',
#  'Rother',
#  'Eastbourne',
#  'Manchester',
#  'Barnet',
#  'Lambeth',
#  'Guildford',
#  'Tamworth',
#  'Blackpool',
#  'Havering',
#  'Scarborough',
#  'Dover',
#  'Hillingdon',
#  'Bromley',
#  'Oldham',
#  'Manchester',
#  'Hackney',
#  'Erewash',
#  'Liverpool',
#  'Birmingham',
#  'Lambeth',
#  'Islington',
#  'Tendring',
#  'Sheffield',
#  'Ipswich',
#  'Wyre Forest',
#  'Cardiff',
#  'Tower Hamlets',
#  'Brent',
#  'Southwark',
#  'Maldon',
#  'Ealing',
#  'Telford and Wrekin',
#  'Nottingham',
#  'Lewisham',
#  'Leeds',
#  'Dartford',
#  'Epping Forest',
#  'Bexley',
#  'North East Derbyshire',
#  'East Hertfordshire',
#  'North Lincolnshire',
#  'Barnet',
#  'Spelthorne',
#  'Windsor and Maidenhead',
#  'Harborough',
#  'East Dorset',
#  'Calderdale',
#  'Hillingdon',
#  'Redbridge',
#  'Bradford',
#  'Newham',
#  'Rushcliffe',
#  'Newham',
#  'Coventry',
#  'Chelmsford',
#  'Tendring',
#  'Thurrock',
#  'Cardiff',
#  'Welwyn Hatfield',
#  'Southen',
#  'Trafford',
#  'Havering',
#  'Fenland',
#  'Southen',
#  'Test Valley',
#  'Tunbridge Wells',
#  'Nottingham',
#  'Wandsworth',
#  'South Somerset',
#  'Croydon',
#  'Nottingham',
#  'Cambridge',
#  'Bromley',
#  'Hammersmith and Fulham',
#  'Tower Hamlets',
#  'Isle of Wight',
#  'Bristol',
#  'Walsall',
#  'Ealing',
#  'Coventry',
#  'Aylesbury Vale',
#  'Tendring',
#  'Wycombe',
#  'Waverley',
#  'Nottingham',
#  'Fenland',
#  'Rochdale',
#  'Camden',
#  'Havering',
#  'North Lincolnshire',
#  'Luton',
#  'Slough',
#  'Manchester',
#  'Nottingham',
#  'Braintree',
#  'Leeds',
#  'Waltham Forest',
#  'Bolton',
#  'Epping Forest',
#  'Barking and Dagenham',
#  'Exeter',
#  'City of London',
#  'Newham',
#  'Redbridge',
#  'Wandsworth',
#  'Canterbury',
#  'Ealing',
#  'Southwark',
#  'Waltham Forest',
#  'Luton',
#  'Arun',
#  'Medway',
#  'Lewisham',
#  'Merton',
#  'Tandridge',
#  'Southen',
#  'Southen',
#  'Lambeth',
#  'Hounslow',
#  'Liverpool',
#  'Merton',
#  'Adur',
#  'Lewisham',
#  'Wandsworth',
#  'Camden',
#  'Thurrock',
#  'Tandridge',
#  'Poole',
#  'Manchester',
#  'Brent',
#  'Hammersmith and Fulham',
#  'Waverley',
#  'Sevenoaks',
#  'Islington',
#  'Cotswold',
#  'Slough',
#  'Hastings',
#  'Chelmsford',
#  'Birmingham',
#  'Ealing',
#  'Croydon',
#  'Buckinghamshire',
#  'Hammersmith and Fulham',
#  'Greenwich',
#  'Hounslow',
#  'Ipswich',
#  'Birmingham',
#  'Rotherham',
#  'Dacorum',
#  'Ipswich',
#  'Newham',
#  'Thurrock',
#  'Dudley',
#  'Kensington and Chelsea',
#  'Slough',
#  'Maidstone',
#  'Haringey',
#  'Blackpool',
#  'Havering',
#  'Tandridge',
#  'Cornwall',
#  'Carmarthenshire',
#  'Stok',
#  'Kingston upon Thames',
#  'Leeds',
#  'Sevenoaks',
#  'Camden',
#  'Croydon',
#  'Harrow',
#  'Hillingdon',
#  'Southampton',
#  'Huntingdonshire',
#  'Redbridge',
#  'Gedling',
#  'County Durham',
#  'Huntingdonshire',
#  'Cotswold',
#  'Wandsworth',
#  'Wolverhampton',
#  'Great Yarmouth',
#  'North East Lincolnshire',
#  'Leicester',
#  'Woking',
#  'Oxford',
#  'Newcastle upon Tyne',
#  'Oadby and Wigston',
#  'Leeds',
#  'Epsom and Ewell',
#  'Redbridge',
#  'Brent',
#  'Cornwall',
#  'Salford',
#  'Sevenoaks',
#  'Worthing',
#  'Slough',
#  'Rother',
#  'Medway',
#  'Enfield',
#  'Slough',
#  'Worcester',
#  'Waverley',
#  'Denbighshire',
#  'Islington',
#  'Hambleton',
#  'Bexley',
#  'Aylesbury Vale',
#  'North Hertfordshire',
#  'Bournemout',
#  'Wiltshire',
#  'Westminster',
#  'Brentwood',
#  'New Forest',
#  'Southwark',
#  'Ealing',
#  'Hillingdon',
#  'Chichester',
#  'Wandsworth',
#  'Welwyn Hatfield',
#  'Bexley',
#  'Cherwell',
#  'Lambeth',
#  'Elmbridge',
#  'Norwich',
#  'Luton',
#  'Cardiff',
#  'Central Bedfordshire',
#  'South Gloucestershire',
#  'Runnymede',
#  'Haringey',
#  'Birmingham',
#  'Taunton Deane',
#  'Brent',
#  'Manchester',
#  'Stratfor',
#  'Luton',
#  'Merton',
#  'Buckinghamshire',
#  'Haringey',
#  'Birmingham',
#  'Dacorum',
#  'Richmond upon Thames',
#  'Lewisham',
#  'Coventry',
#  'Richmond upon Thames',
#  'Newport',
#  'Hastings',
#  'Newham',
#  'Kensington and Chelsea',
#  'Merton',
#  'Tonbridge and Malling',
#  'Exeter',
#  'Southwark',
#  'Bromley',
#  'Harrow',
#  'Cheshire East',
#  'Croydon',
#  'Epsom and Ewell',
#  'Southampton',
#  'Brighton and Hove',
#  'Bournemouth',
#  'Aylesbury Vale',
#  'East Riding of Yorkshire',
#  'Stevenage',
#  'Merton',
#  'Sheffield',
#  'Conwy',
#  'Newark and Sherwood',
#  'West Somerset',
#  'Southwark',
#  'Swindon',
#  'Bath and North East Somerset',
#  'Kingston upon Thames',
#  'Cheltenham',
#  'Lewisham',
#  'Sandwell',
#  'Brent',
#  'Newham',
#  'Swindon',
#  'Hertsmere',
#  'Sedgemoor',
#  'Medway',
#  'Welwyn Hatfield',
#  'East Hertfordshire',
#  'Hackney',
#  'Salford',
#  'East Dorset',
#  'St Albans',
#  'Guildford',
#  'Brent',
#  'Halton',
#  'Westminster',
#  'Leicester',
#  'Greenwich',
#  'Oxford',
#  'Ashford',
#  'Bexley',
#  'Dover',
#  'Harlow',
#  'Doncaster',
#  'Tower Hamlets',
#  'Barro',
#  'Telford and Wrekin',
#  'Hounslow',
#  'Guildford',
#  'Camden',
#  'South Oxfordshire',
#  'Newham',
#  'Bracknell Forest',
#  'Enfield',
#  'Cheshire East',
#  'Central Bedfordshire',
#  'Bexley',
#  'Westminster',
#  'Brighton and Hove',
#  'Reading',
#  'Lambeth',
#  'Bexley',
#  'Enfield',
#  'Redbridge',
#  'Brent',
#  'West Suffolk',
#  'Reading',
#  'Southwark',
#  'Hertsmere',
#  'Elmbridge',
#  'Birmingham',
#  'Hillingdon',
#  'Hillingdon',
#  'Haringey',
#  'Newham',
#  'Tamworth',
#  'Birmingham',
#  'Dartford',
#  'Islington',
#  'Redbridge',
#  'Barnet',
#  'Waltham Forest',
#  'Haringey',
#  'Tunbridge Wells',
#  'Barking and Dagenham',
#  'Waverley',
#  'Sutton',
#  'Hounslow',
#  'Kensington and Chelsea',
#  'Camden',
#  'Redbridge',
#  'Maidstone',
#  'Birmingham',
#  'Sunderland',
#  'Mid Sussex',
#  'Hackney',
#  'Birmingham',
#  'Greenwich',
#  'Bromley',
#  'Waltham Forest',
#  'Milton Keynes',
#  'Tower Hamlets',
#  'Barnet',
#  'Brent',
#  'Darlington',
#  'Newport',
#  'Hackney',
#  'Medway',
#  'Sefton',
#  'Bournemout',
#  'Bromsgrove',
#  'Knowsley',
#  'Hounslow',
#  'Central Bedfordshire',
#  'West Lancashire',
#  'Castle Point',
#  'Huntingdonshire',
#  'Stratfor',
#  'Ealing',
#  'Epping Forest',
#  'Tendring',
#  'Bournemout',
#  'Leeds',
#  'St Edmundsbury',
#  'Enfield',
#  'Enfield',
#  'Sheffield',
#  'Walsall',
#  'Manchester',
#  'Hammersmith and Fulham',
#  'Canterbury',
#  'Norwich',
#  'Enfield',
#  'Derby',
#  'Canterbury',
#  'Birmingham',
#  'Coventry',
#  'Greenwich',
#  'Tower Hamlets',
#  'Croydon',
#  'Elmbridge',
#  'Birmingham',
#  'Camden',
#  'Sevenoaks',
#  'Spelthorne',
#  'Thanet',
#  'Lambeth',
#  'Hounslow',
#  'Medway',
#  'Wolverhampton',
#  'Enfield',
#  'Newport',
#  'Cheshire East',
#  'Barnet',
#  'Exeter',
#  'Ealing',
#  'Manchester',
#  'East Hampshire',
#  'Forest of Dean',
#  'Kingston upon Hull',
#  'Newham',
#  'Knowsley',
#  'East Devon',
#  'Hillingdon',
#  'Coventry',
#  'Bassetlaw',
#  'Malvern Hills',
#  'Corby',
#  'Barking and Dagenham',
#  'Hackney',
#  'Blackburn with Darwen',
#  'Havering',
#  'Tower Hamlets',
#  'Middlesbrough',
#  'Cardiff',
#  'Enfield',
#  'Wychavon',
#  'North Norfolk',
#  'Luton',
#  'Swansea',
#  'Forest of Dean',
#  'Bromley',
#  'Kensington and Chelsea',
#  'Greenwich',
#  'Richmond upon Thames',
#  'Slough',
#  'Merton',
#  'Bexley',
#  'Chelmsford',
#  'Wycombe',
#  'Birmingham',
#  'Kensington and Chelsea',
#  'Newport',
#  'Swindon',
#  'Redbridge',
#  'Exeter',
#  'South Tyneside',
#  'East Hampshire',
#  'Broadland',
#  'Bedford',
#  'Islington',
#  'Tower Hamlets',
#  'Harrow',
#  'Tower Hamlets',
#  'Haringey',
#  'Eastleigh',
#  'Sandwell',
#  'Ipswich',
#  'Birmingham',
#  'Eastleigh',
#  'Lewisham',
#  'Newham',
#  'Cornwall',
#  'Merton',
#  'Coventry',
#  'Ealing',
#  'Tower Hamlets',
#  'Bristol',
#  'Brent',
#  'Rushmoor',
#  'Buckinghamshire',
#  'Suffolk Coastal',
#  'South Somerset',
#  'Hyndburn',
#  'Barnet',
#  'Hillingdon',
#  'Dacorum',
#  'Barnet',
#  'Maidstone',
#  'Oxford',
#  'Wolverhampton',
#  'Hillingdon',
#  'Epping Forest',
#  'Leeds',
#  'Elmbridge',
#  'Melton',
#  'Camden',
#  'Oadby and Wigston',
#  'Reading',
#  'Greenwich',
#  'Rutland',
#  'Hammersmith and Fulham',
#  'Breckland',
#  'Barnet',
#  'North Lincolnshire',
#  'Harrow',
#  'Coventry',
#  'Bromley',
#  'Reading',
#  'Nottingham',
#  'Tunbridge Wells',
#  'Bath and North East Somerset',
#  'Kirklees',
#  'Redbridge',
#  'Rother',
#  'Hartlepool',
#  'Havant',
#  'Lambeth',
#  'South Norfolk',
#  'Merton',
#  'Wyre',
#  'Bromley',
#  'Bedford',
#  'Croydon',
#  'Hounslow',
#  'Sutton',
#  'Swale',
#  'Bolton',
#  'Dover',
#  'Reigate and Banstead',
#  'Lambeth',
#  'Preston',
#  'Wrexham',
#  'Hounslow',
#  'Horsham',
#  'Uttlesford',
#  'Trafford',
#  'Croydon',
#  'Shropshire',
#  'Lambeth',
#  'West Oxfordshire',
#  'Mendip',
#  'Birmingham',
#  'North Kesteven',
#  'Lewisham',
#  'Darlington',
#  'Chesterfield',
#  'East Riding of Yorkshire',
#  'Stevenage',
#  'Medway',
#  'Barking and Dagenham',
#  'Wokingham',
#  'Kensington and Chelsea',
#  'Breckland',
#  'Kirklees',
#  'Enfield',
#  'Hounslow',
#  'Harrow',
#  'Mid Sussex',
#  'Fenland',
#  'Havering',
#  'Tower Hamlets',
#  'South Oxfordshire',
#  'Enfield',
#  'Leeds',
#  'Slough',
#  'Guildford',
#  'Wigan',
#  'Tonbridge and Malling',
#  'Croydon',
#  'Haringey',
#  'Crawley',
#  'Slough',
#  'Lewisham',
#  'Brighton and Hove',
#  'Fareham',
#  'Newham',
#  'Mendip',
#  'Bromley',
#  'Watford',
#  'Swale',
#  'Hillingdon',
#  'Richmond upon Thames',
#  'Gravesham',
#  'Canterbury',
#  'Chesterfield',
#  'Enfield',
#  'Wellingborough',
#  'Hackney',
#  'Tower Hamlets',
#  'North Dorset',
#  'Waltham Forest',
#  'Bedford',
#  'Waltham Forest',
#  'St Edmundsbury',
#  'Coventry',
#  'Windsor and Maidenhead',
#  'Kirklees',
#  'Wirral',
#  'County Durham',
#  'Basildon',
#  'Waltham Forest',
#  'Brent',
#  'Cheltenham',
#  'Sevenoaks',
#  'Birmingham',
#  'Greenwich',
#  'Haringey',
#  'Bromley',
#  'Thurrock',
#  'Bromley',
#  'Welwyn Hatfield',
#  'Fareham',
#  'Barnet',
#  'South Cambridgeshire',
#  'Tunbridge Wells',
#  'Bromley',
#  'Elmbridge',
#  'Wandsworth',
#  'Wokingham',
#  'Wrexham',
#  'Hounslow',
#  'Reading',
#  'Kingston upon Thames',
#  'Merton',
#  'Sheffield',
#  'Wigan',
#  'Fareham',
#  'Hertsmere',
#  'Gloucester',
#  'Southampton',
#  'Bromley',
#  'Barnet',
#  'Brent',
#  'Dudley',
#  'York',
#  'Isle of Wight',
#  'Tendring',
#  'South Cambridgeshire',
#  'Chichester',
#  'Castle Point',
#  'Richmond upon Thames',
#  'Hackney',
#  'Sheffield',
#  'Hertsmere',
#  'South Staffordshire',
#  'Richmondshire',
#  'Lambeth',
#  'Stockto',
#  'Waltham Forest',
#  'Northampton',
#  'Three Rivers',
#  'Wandsworth',
#  'Tendring',
#  'Merton',
#  'East Lindsey',
#  'Birmingham',
#  'Forest Heath',
#  'Lewisham',
#  'Luton',
#  'Hillingdon',
#  'Newham',
#  'Westminster',
#  'Colchester',
#  'S',
#  'Kensington and Chelsea',
#  'Hackney',
#  'Broxbourne',
#  'Tandridge',
#  'North Tyneside',
#  'Woking',
#  'Bury',
#  'Southen',
#  'Barnet',
#  'Barnet',
#  'Sutton',
#  'Greenwich',
#  'North Somerset',
#  'Three Rivers',
#  'Wigan',
#  'Epping Forest',
#  'Hackney',
#  'Tandridge',
#  'Camden',
#  'Suffolk Coastal',
#  'Windsor and Maidenhead',
#  'Wandsworth',
#  'Liverpool',
#  'Nottingham',
#  'Haringey',
#  'Oxford',
#  'Harlow',
#  'Harrow',
#  'Croydon',
#  'Elmbridge',
#  'Hackney',
#  'Bromley',
#  'Hillingdon',
#  'Rochdale',
#  'Oxford',
#  'Tower Hamlets',
#  'Basildon',
#  'Wycombe',
#  'Oadby and Wigston',
#  'Croydon',
#  'Tendring',
#  'Cardiff',
#  'Enfield',
#  'Birmingham',
#  'Chelmsford',
#  'Great Yarmouth',
#  'Newham',
#  'Dartford',
#  'Lewisham',
#  'Croydon',
#  'Swansea',
#  'South Northamptonshire',
#  'Sevenoaks',
#  'Wellingborough',
#  'Mole Valley',
#  'Bristol',
#  'Tower Hamlets',
#  'Camden',
#  'Canterbury',
#  'Westminster',
#  'Hounslow',
#  'Cornwall',
#  'Camden',
#  'Hammersmith and Fulham',
#  'Uttlesford',
#  'Mid Sussex',
#  'Wokingham',
#  'East Lindsey',
#  'Chelmsford',
#  'Lewisham',
#  'Richmond upon Thames',
#  'Mid Suffolk',
#  'Barking and Dagenham',
#  'Blackpool',
#  'Greenwich',
#  'Barnet',
#  'Gravesham',
#  'Sheffield',
#  'Wolverhampton',
#  'Kin',
#  'Bournemouth',
#  'Watford',
#  'Telford and Wrekin',
#  'Charnwood',
#  'Newham',
#  'Tandridge',
#  'Maidstone',
#  'Rochdale',
#  'Dorset',
#  'Barking and Dagenham',
#  'Swale',
#  'Monmouthshire',
#  'Gateshead',
#  'Dacorum',
#  'Eden',
#  'Dartford',
#  'Brentwood',
#  'West Devon',
#  'Waltham Forest',
#  'Bradford',
#  'Northampton',
#  'Croydon',
#  'Newham',
#  'Hart',
#  'Harrow',
#  'Tonbridge and Malling',
#  'Slough',
#  'Hertsmere',
#  'North Somerset',
#  'Tameside',
#  'Worthing',
#  'North Hertfordshire',
#  'Sutton',
#  'Uttlesford',
#  'Medway',
#  'Chichester',
#  'Bromley',
#  'Rhondda Cynon Taf',
#  'Gateshead',
#  'Breckland',
#  'Merton',
#  'Newham',
#  'Enfield',
#  'Wokingham',
#  'Derby',
#  'Calderdale',
#  'Erewash',
#  'Croydon',
#  'Northampton',
#  'Ealing',
#  'Dacorum',
#  'Rotherham',
#  'Broxtowe',
#  'Blackpool',
#  'Haringey',
#  'Wychavon',
#  'Suffolk Coastal',
#  'Bexley',
#  'Lichfield',
#  'North Hertfordshire',
#  'Islington',
#  'Islington',
#  'Castle Point',
#  'Nottingham',
#  'Birmingham',
#  'County Durham',
#  'Sandwell',
#  'North West Leicestershire',
#  'Huntingdonshire',
#  'St Albans',
#  'Wandsworth',
#  'Trafford',
#  'Carmarthenshire',
#  'Worthing',
#  'Peterborough',
#  'North Hertfordshire',
#  'Broadland',
#  'Bexley',
#  'Islington',
#  'North Hertfordshire',
#  'Calderdale',
#  'Central Bedfordshire',
#  'Cornwall',
#  'Hertsmere',
#  'Reigate and Banstead',
#  'Northumberland',
#  'Elmbridge',
#  'Broadland',
#  'Huntingdonshire',
#  'Northumberland',
#  'Liverpool',
#  'Swale',
#  'West Lancashire',
#  'Suffolk Coastal',
#  'Enfield',
#  'Medway',
#  'Surrey Heath',
#  'Reading',
#  'Cornwall',
#  'Greenwich',
#  'Peterborough',
#  'Dacorum',
#  'Croydon',
#  'Barnet',
#  'Tendring',
#  'Havering',
#  'Islington',
#  'Shepway',
#  'Oxford',
#  'Hackney',
#  'Wealden',
#  'Waltham Forest',
#  'Spelthorne',
#  'Thurrock',
#  'Tewkesbury',
#  'Surrey Heath',
#  'Runnymede',
#  'Bromley',
#  'West Devon',
#  'Croydon',
#  'Wakefield',
#  'Bury',
#  'Tunbridge Wells',
#  'Welwyn Hatfield',
#  'Hart',
#  'Swale',
#  'Hillingdon',
#  'Lewisham',
#  'Hillingdon',
#  'Havering',
#  'Portsmouth',
#  'Basildon',
#  'Preston',
#  'Waveney',
#  'Rotherham',
#  'Tamworth',
#  'North Northamptonshire',
#  'Birmingham',
#  'County Durham',
#  'Manchester',
#  'Blackburn with Darwen',
#  'Rochdale',
#  'Milton Keynes',
#  'Cotswold',
#  'Brentwood',
#  'Redditch',
#  'Wandsworth',
#  'Leeds',
#  'Dudley',
#  'Haringey',
#  'Bedford',
#  'Chorley',
#  'Colchester',
#  'Tendring',
#  'Waltham Forest',
#  'Southwark',
#  'Harlow',
#  'Nuneaton and Bedworth',
#  'Leicester',
#  'Sevenoaks',
#  'Haringey',
#  'Tower Hamlets',
#  'Westminster',
#  'Sandwell',
#  'Bexley',
#  'Wealden',
#  'Tower Hamlets',
#  'Ceredigion',
#  'Westminster',
#  'Windsor and Maidenhead',
#  'Southampton',
#  'Bromley',
#  'Cherwell',
#  'Hillingdon',
#  'East Hampshire',
#  'Barking and Dagenham',
#  'Tower Hamlets',
#  'Southwark',
#  'Kingston upon Thames',
#  'Walsall',
#  'Redbridge',
#  'West Dorset',
#  'Buckinghamshire',
#  'Stevenage',
#  'Luton',
#  'Newham',
#  'Norwich',
#  'New Forest',
#  'Bexley',
#  'Nottingham',
#  'Barnet',
#  'Birmingham',
#  'Hounslow',
#  'Rhondda Cynon Taf',
#  'Wigan',
#  'Blackpool',
#  'Newham',
#  'Derby',
#  'Sutton',
#  'Buckinghamshire',
#  'Ealing',
#  'Spelthorne',
#  'Havering',
#  'Broxbourne',
#  'Kensington and Chelsea',
#  'Lambeth',
#  'Newcastle upon Tyne',
#  'Hackney',
#  'Welwyn Hatfield',
#  'Redbridge',
#  'Greenwich',
#  'Gateshead',
#  'Telford and Wrekin',
#  'Vale of White Horse',
#  'Havering',
#  'Welwyn Hatfield',
#  'Sunderland',
#  'Hounslow',
#  'Ealing',
#  'Waverley',
#  'Redbridge',
#  ...]

# %%
pattern = r'^([a-zA-Z\s]+)'

def add_borough(i, pattern):
    if pd.isna(i):
        return None
    else:
        match = re.findall(pattern, i)[0]
        match = match[0:len(match)-1]
        return match

# %%
add_borough('Barking and Dagenham 011B', pattern)
# Out:
# 'Barking and Dagenham'

# %%
tqdm.pandas(desc="Adding Boroughs")
crime_df['Borough'] = crime_df['LSOA name'].progress_apply(lambda x: add_borough(x, pattern))
# Out:
# Adding Boroughs: 100%|█████████████████████████████████████████| 14131357/14131357 [01:23<00:00, 170057.06it/s]

# %%
tqdm.pandas()
filtered_crime_df = crime_df[crime_df['Borough'].progress_apply(lambda x: x in all_borough)]
borough_counts = filtered_crime_df['Borough'].value_counts()

plt.figure(figsize=(12, 8))
borough_counts.plot(kind='bar')
plt.title('Distribution of Crimes by Borough')
plt.xlabel('Borough')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████| 14131357/14131357 [00:25<00:00, 543886.04it/s]

# %%
filtered_crime_df
# Out:
#                                                    Crime ID    Month  \
# 0                                                       NaN  2010-12
# 1                                                       NaN  2010-12
# 2                                                       NaN  2010-12
# 3                                                       NaN  2010-12
# 4                                                       NaN  2010-12
# ...                                                     ...      ...
# 14130675  cb73daf6b8479ac3c6f0393ccaed8ba09d656bc8ec7daf...  2024-01
# 14130676  9bf4d909cbf838f713421c29a173c1fd1578393789ce37...  2024-01
# 14130677  90ce6cc23afb135dcbc5eb17784b4d363375f9a076a2fd...  2024-01
# 14130678  be7a1b283771dc0aefcef2b191a4f7e91403771e1d6065...  2024-01
# 14130679  9006968a8e2fb5779017e7c6f1887ad21232b565cfe6df...  2024-01
#
#                           Reported by                 Falls within Longitude  \
# 0         Metropolitan Police Service  Metropolitan Police Service  0.145949
# 1         Metropolitan Police Service  Metropolitan Police Service  0.140192
# 2         Metropolitan Police Service  Metropolitan Police Service  0.134947
# 3         Metropolitan Police Service  Metropolitan Police Service  0.134947
# 4         Metropolitan Police Service  Metropolitan Police Service  0.134947
# ...                               ...                          ...       ...
# 14130675  Metropolitan Police Service  Metropolitan Police Service  -0.13348
# 14130676  Metropolitan Police Service  Metropolitan Police Service -0.136284
# 14130677  Metropolitan Police Service  Metropolitan Police Service -0.136284
# 14130678  Metropolitan Police Service  Metropolitan Police Service  -0.13723
# 14130679  Metropolitan Police Service  Metropolitan Police Service -0.136284
#
#            Latitude                            Location  LSOA code  \
# 0         51.593914         On or near Providence Place  E01000027
# 1         51.582311              On or near Hatch Grove  E01000027
# 2         51.588063               On or near Mead Grove  E01000027
# 3         51.588063               On or near Mead Grove  E01000027
# 4         51.588063               On or near Mead Grove  E01000027
# ...             ...                                 ...        ...
# 14130675  51.486807  On or near St George'S Square Mews  E01035722
# 14130676  51.485152           On or near Petrol Station  E01035722
# 14130677  51.485152           On or near Petrol Station  E01035722
# 14130678  51.486309             On or near Parking Area  E01035722
# 14130679  51.485152           On or near Petrol Station  E01035722
#
#                           LSOA name                    Crime type  \
# 0         Barking and Dagenham 001A         Anti-social behaviour
# 1         Barking and Dagenham 001A         Anti-social behaviour
# 2         Barking and Dagenham 001A         Anti-social behaviour
# 3         Barking and Dagenham 001A         Anti-social behaviour
# 4         Barking and Dagenham 001A         Anti-social behaviour
# ...                             ...                           ...
# 14130675           Westminster 024G     Criminal damage and arson
# 14130676           Westminster 024G                   Other theft
# 14130677           Westminster 024G         Theft from the person
# 14130678           Westminster 024G  Violence and sexual offences
# 14130679           Westminster 024G  Violence and sexual offences
#
#                                   Last outcome category Context  \
# 0                                                   NaN     NaN
# 1                                                   NaN     NaN
# 2                                                   NaN     NaN
# 3                                                   NaN     NaN
# 4                                                   NaN     NaN
# ...                                                 ...     ...
# 14130675                            Under investigation     NaN
# 14130676                            Under investigation     NaN
# 14130677  Investigation complete; no suspect identified     NaN
# 14130678                            Under investigation     NaN
# 14130679  Investigation complete; no suspect identified     NaN
#
#                        Borough
# 0         Barking and Dagenham
# 1         Barking and Dagenham
# 2         Barking and Dagenham
# 3         Barking and Dagenham
# 4         Barking and Dagenham
# ...                        ...
# 14130675           Westminster
# 14130676           Westminster
# 14130677           Westminster
# 14130678           Westminster
# 14130679           Westminster
#
# [13931526 rows x 13 columns]
