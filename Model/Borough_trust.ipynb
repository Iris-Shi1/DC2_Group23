# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error, mean_absolute_error

# Load the data
print("Loading data...")
df = pd.read_csv('../project_data/PAS+crime+extra_final.csv')

# Drop rows where 'NQ135BD' is NaN and filter out 'NQ135BD' values >= 95
print("Cleaning data...")
df.dropna(subset=['NQ135BD'], inplace=True)
df = df[df['NQ135BD'] < 95]

# Removing columns that are named 'WT...'
columns_to_drop = df.filter(regex='^WT_').columns
df = df.drop(columns=columns_to_drop)

# Define features and target
print("Defining features and target...")
X = df.drop(columns='NQ135BD')
y = df['NQ135BD']

# Get unique boroughs
print("Identifying unique boroughs...")
boroughs = df['Borough'].unique()
print(f"Found {len(boroughs)} unique boroughs.")

# Dictionary to store models, results, and feature importances
models = {}
evals_results = {}
rmses = {}
perm_importances_dict = {}
top_features_dict = {}

# Iterate over each borough and train a model
for borough in boroughs:
    print(f"Processing borough: {borough}")
    
    # Filter the data for the current borough
    borough_data = df[df['Borough'] == borough]
    X_borough = borough_data.drop(columns=['NQ135BD', 'Borough'])
    y_borough = borough_data['NQ135BD']
    
    # Split the data into training and testing sets
    print(f"Splitting data for borough: {borough}")
    X_train, X_test, y_train, y_test = train_test_split(X_borough, y_borough, test_size=0.2, random_state=42)
    
    # Convert data into DMatrix format for XGBoost
    print(f"Converting data to DMatrix format for borough: {borough}")
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    
    # Define parameters
    params = {
        'objective': 'reg:squarederror',  # Use squared error for regression task
        'random_state': 42
    }
    
    # Train the model
    print(f"Training model for borough: {borough}")
    evals_result = {}
    model = xgb.train(params, dtrain, num_boost_round=100,
                      evals=[(dtrain, 'train'), (dtest, 'test')],
                      early_stopping_rounds=10, verbose_eval=10, evals_result=evals_result)
    
    # Make predictions on the test set
    print(f"Making predictions for borough: {borough}")
    y_pred = model.predict(dtest)
    
    # Calculate and store RMSE
    print(f"Calculating RMSE for borough: {borough}")
    rmse = root_mean_squared_error(y_test, y_pred)
    
    # Store the model, evals_result, and RMSE
    models[borough] = model
    evals_results[borough] = {'test': {'X': X_test, 'y': y_test}}
    rmses[borough] = rmse
    
    print(f"RMSE for {borough}: {rmse}")
    
    # Permutation Importance Calculation
    print(f"Calculating permutation importances for borough: {borough}")
    baseline_rmse = rmse
    perm_importances = np.zeros(X_test.shape[1])
    np.random.seed(42)
    n_permutations = 10
    
    for i in tqdm(range(X_test.shape[1]), desc=f"Calculating Permutation Importance for {borough}"):
        perm_importances_temp = []
        for _ in range(n_permutations):
            X_test_permuted = X_test.copy()
            X_test_permuted.iloc[:, i] = np.random.permutation(X_test_permuted.iloc[:, i])
            y_pred_permuted = model.predict(xgb.DMatrix(X_test_permuted))
            permuted_rmse = root_mean_squared_error(y_test, y_pred_permuted)
            perm_importance = baseline_rmse - permuted_rmse
            perm_importances_temp.append(perm_importance)
        perm_importances[i] = np.mean(perm_importances_temp)
    
    perm_importances_dict[borough] = perm_importances
    sorted_idx = np.argsort(perm_importances)[::-1]
    
    # Print the top 20 features by permutation importance
    print(f"Top 20 Feature Importance for {borough}:")
    for i in sorted_idx[:20]:
        print(f"{X_borough.columns[i]}: {perm_importances[i]:.4f}")
    
    # Select the top 20 most important features
    top_features = X_borough.columns[sorted_idx[:20]]
    top_features_dict[borough] = top_features
    
    # Create a new DataFrame with only the top features
    X_train_top = X_train[top_features]
    X_test_top = X_test[top_features]
    
    # Retrain the model using only the top features
    dtrain_top = xgb.DMatrix(X_train_top, label=y_train)
    dtest_top = xgb.DMatrix(X_test_top, label=y_test)
    
    model_top = xgb.train(params, dtrain_top, num_boost_round=100,
                          evals=[(dtrain_top, 'train'), (dtest_top, 'test')],
                          early_stopping_rounds=10, verbose_eval=10, evals_result=evals_result)
    
    # Make predictions on the test set with the top features
    y_pred_top = model_top.predict(dtest_top)
    
    # Calculate and print RMSE on the test set with the top features
    rmse_top = root_mean_squared_error(y_test, y_pred_top)
    print(f"RMSE on test set with top features for {borough}: {rmse_top}")
    
    # Get feature importance scores
    feature_importance = model_top.get_score(importance_type='weight')
    
    # Convert to DataFrame for better visualization
    importance_df = pd.DataFrame({
        'Feature': list(feature_importance.keys()),
        'Importance': list(feature_importance.values())
    })
    
    # Sort by importance
    importance_df = importance_df.sort_values(by='Importance', ascending=False)
    
    # Plot feature importance
    plt.figure(figsize=(10, 6))
    plt.barh(importance_df['Feature'], importance_df['Importance'])
    plt.xlabel('Importance')
    plt.ylabel('Feature')
    plt.title(f'Feature Importance with Top 20 Features for {borough}')
    plt.gca().invert_yaxis()
    plt.show()
    
    # Print feature importance
    print(importance_df)

# Print all RMSes
print("RMSE for all boroughs:")
for borough, rmse in rmses.items():
    print(f"{borough}: {rmse}")
# Out:
# Loading data...
# Cleaning data...
# Defining features and target...
# Identifying unique boroughs...
# Found 32 unique boroughs.
# Processing borough: 18
# Splitting data for borough: 18
# Converting data to DMatrix format for borough: 18
# Training model for borough: 18
# [0]	train-rmse:0.79030	test-rmse:0.80463
# [10]	train-rmse:0.40143	test-rmse:0.68112
# [20]	train-rmse:0.30990	test-rmse:0.68570
# [24]	train-rmse:0.28131	test-rmse:0.68816
# Making predictions for borough: 18
# Calculating RMSE for borough: 18
# RMSE for 18: 0.6881645040152967
# Calculating permutation importances for borough: 18
# Calculating Permutation Importance for 18: 100%|██████████| 597/597 [06:03<00:00,  1.64it/s]
# Top 20 Feature Importance for 18:
# SQ80D: 0.0047
# SQ80E: 0.0029
# PQ135AS: 0.0027
# Q10E: 0.0022
# Q15: 0.0020
# Q62E: 0.0020
# Anti-social behaviour: 0.0019
# NQ44BB: 0.0017
# NQ79BI: 0.0017
# Public order: 0.0017
# Q39BE: 0.0015
# NQ21: 0.0015
# SQ79DF: 0.0015
# SQ80C: 0.0014
# XQ8: 0.0013
# XQ122A: 0.0012
# Q79D: 0.0011
# Q79I: 0.0011
# Q79F: 0.0011
# Q14C: 0.0010
# [0]	train-rmse:0.86048	test-rmse:0.84976
# [10]	train-rmse:0.64450	test-rmse:0.83205
# [14]	train-rmse:0.60761	test-rmse:0.84966
# RMSE on test set with top features for 18: 0.8521144060377661
#                   Feature  Importance
# 0                   SQ80D        95.0
# 6   Anti-social behaviour        78.0
# 9            Public order        77.0
# 4                     Q15        53.0
# 5                    Q62E        51.0
# 1                   SQ80E        51.0
# 16                   Q79D        47.0
# 17                   Q79I        47.0
# 18                   Q79F        45.0
# 8                  NQ79BI        29.0
# 12                 SQ79DF        23.0
# 15                 XQ122A        23.0
# 3                    Q10E        21.0
# 13                  SQ80C        17.0
# 11                   NQ21        15.0
# 14                    XQ8        15.0
# 19                   Q14C        11.0
# 10                  Q39BE         9.0
# 7                  NQ44BB         5.0
# 2                 PQ135AS         5.0
# Processing borough: 28
# Splitting data for borough: 28
# Converting data to DMatrix format for borough: 28
# Training model for borough: 28
# [0]	train-rmse:0.66295	test-rmse:0.70100
# [10]	train-rmse:0.32770	test-rmse:0.61870
# [18]	train-rmse:0.26957	test-rmse:0.61459
# Making predictions for borough: 28
# Calculating RMSE for borough: 28
# RMSE for 28: 0.6145868526739416
# Calculating permutation importances for borough: 28
# Calculating Permutation Importance for 28: 100%|██████████| 597/597 [06:01<00:00,  1.65it/s]
# Top 20 Feature Importance for 28:
# Q3H: 0.0068
# Q59: 0.0044
# SQ79C: 0.0042
# NQCV15: 0.0027
# NQCV28: 0.0027
# XQ3B: 0.0025
# Criminal damage and arson: 0.0022
# Q65: 0.0021
# NQ79BB: 0.0020
# SQ80E: 0.0018
# NQCV12: 0.0018
# Q79I: 0.0017
# Q79H: 0.0015
# NQCV22: 0.0014
# Q54C: 0.0014
# XNQ135B: 0.0013
# Q10C: 0.0012
# Q195A: 0.0012
# NQ62B: 0.0011
# Q39BA: 0.0010
# [0]	train-rmse:0.71360	test-rmse:0.72635
# [10]	train-rmse:0.51135	test-rmse:0.69510
# [14]	train-rmse:0.48815	test-rmse:0.70334
# RMSE on test set with top features for 28: 0.7048286760459027
#                       Feature  Importance
# 6   Criminal damage and arson       124.0
# 11                       Q79I        66.0
# 0                         Q3H        58.0
# 8                      NQ79BB        52.0
# 12                       Q79H        48.0
# 2                       SQ79C        46.0
# 14                       Q54C        43.0
# 7                         Q65        41.0
# 1                         Q59        38.0
# 5                        XQ3B        37.0
# 4                      NQCV28        35.0
# 9                       SQ80E        29.0
# 17                      Q195A        22.0
# 15                    XNQ135B        17.0
# 18                      NQ62B        16.0
# 16                       Q10C        14.0
# 10                     NQCV12        13.0
# 19                      Q39BA        10.0
# 3                      NQCV15         6.0
# 13                     NQCV22         4.0
# Processing borough: 5
# Splitting data for borough: 5
# Converting data to DMatrix format for borough: 5
# Training model for borough: 5
# [0]	train-rmse:0.68640	test-rmse:0.70506
# [10]	train-rmse:0.34635	test-rmse:0.63211
# [20]	train-rmse:0.28755	test-rmse:0.63674
# [22]	train-rmse:0.27678	test-rmse:0.63899
# Making predictions for borough: 5
# Calculating RMSE for borough: 5
# RMSE for 5: 0.6389939941474156
# Calculating permutation importances for borough: 5
# Calculating Permutation Importance for 5: 100%|██████████| 597/597 [05:57<00:00,  1.67it/s]
# Top 20 Feature Importance for 5:
# NQ79BC: 0.0111
# NQ147r: 0.0056
# Q60: 0.0040
# Q62D: 0.0039
# Q54D: 0.0035
# Q126DA: 0.0029
# Q79J: 0.0025
# Q3J: 0.0025
# Q126DB: 0.0021
# XQ119A: 0.0021
# Burglary: 0.0020
# XQ21C: 0.0018
# XNQ135B: 0.0014
# NQ79ABD: 0.0014
# Q3K: 0.0014
# Criminal damage and arson: 0.0014
# NQCV2: 0.0014
# Q79F: 0.0012
# NQ62B: 0.0012
# Q132P: 0.0012
# [0]	train-rmse:0.72496	test-rmse:0.74359
# [10]	train-rmse:0.49173	test-rmse:0.69881
# [16]	train-rmse:0.45370	test-rmse:0.71283
# RMSE on test set with top features for 5: 0.7128307983655603
#                       Feature  Importance
# 2                         Q60        80.0
# 15  Criminal damage and arson        76.0
# 10                   Burglary        66.0
# 0                      NQ79BC        54.0
# 6                        Q79J        53.0
# 7                         Q3J        53.0
# 3                        Q62D        48.0
# 17                       Q79F        36.0
# 4                        Q54D        33.0
# 14                        Q3K        33.0
# 1                      NQ147r        32.0
# 12                    XNQ135B        30.0
# 5                      Q126DA        27.0
# 18                      NQ62B        26.0
# 9                      XQ119A        25.0
# 16                      NQCV2        24.0
# 11                      XQ21C        16.0
# 13                    NQ79ABD        13.0
# 8                      Q126DB        12.0
# 19                      Q132P         8.0
# Processing borough: 22
# Splitting data for borough: 22
# Converting data to DMatrix format for borough: 22
# Training model for borough: 22
# [0]	train-rmse:0.80912	test-rmse:0.83665
# [10]	train-rmse:0.37797	test-rmse:0.73603
# [18]	train-rmse:0.31115	test-rmse:0.73882
# Making predictions for borough: 22
# Calculating RMSE for borough: 22
# RMSE for 22: 0.7393245011914218
# Calculating permutation importances for borough: 22
# Calculating Permutation Importance for 22: 100%|██████████| 597/597 [05:56<00:00,  1.68it/s]
# Top 20 Feature Importance for 22:
# Q66: 0.0104
# Q79F: 0.0051
# XQ57C: 0.0049
# NQ79BC: 0.0028
# Drugs: 0.0026
# Q79A: 0.0026
# NQ48A: 0.0026
# SQ80F: 0.0025
# Q133: 0.0020
# XQ59B: 0.0020
# SQ132B: 0.0020
# NQ57AC: 0.0020
# XQ3A: 0.0019
# XNQ135B: 0.0016
# Vehicle crime: 0.0016
# XQ81: 0.0015
# Q54D: 0.0015
# Q21: 0.0014
# Q79E: 0.0014
# Other crime: 0.0014
# [0]	train-rmse:0.86878	test-rmse:0.87125
# [10]	train-rmse:0.62261	test-rmse:0.82685
# [16]	train-rmse:0.58333	test-rmse:0.83308
# RMSE on test set with top features for 22: 0.8330822088495722
#           Feature  Importance
# 1            Q79F        86.0
# 4           Drugs        85.0
# 5            Q79A        57.0
# 14  Vehicle crime        52.0
# 18           Q79E        50.0
# 3          NQ79BC        49.0
# 8            Q133        40.0
# 12           XQ3A        38.0
# 11         NQ57AC        37.0
# 0             Q66        36.0
# 19    Other crime        36.0
# 13        XNQ135B        35.0
# 17            Q21        35.0
# 9           XQ59B        32.0
# 7           SQ80F        30.0
# 2           XQ57C        22.0
# 16           Q54D        20.0
# 6           NQ48A        19.0
# 15           XQ81        15.0
# 10         SQ132B         5.0
# Processing borough: 3
# Splitting data for borough: 3
# Converting data to DMatrix format for borough: 3
# Training model for borough: 3
# [0]	train-rmse:0.68450	test-rmse:0.77491
# [10]	train-rmse:0.35989	test-rmse:0.69985
# [15]	train-rmse:0.31658	test-rmse:0.70597
# Making predictions for borough: 3
# Calculating RMSE for borough: 3
# RMSE for 3: 0.707827684959418
# Calculating permutation importances for borough: 3
# Calculating Permutation Importance for 3: 100%|██████████| 597/597 [05:58<00:00,  1.66it/s]
# Top 20 Feature Importance for 3:
# Q3C: 0.0056
# Q3H: 0.0050
# Q1: 0.0049
# NQ135BB: 0.0048
# Q62A: 0.0030
# Criminal damage and arson: 0.0025
# NQ57AC: 0.0022
# Q79E: 0.0021
# NQ57AA: 0.0020
# Q54A: 0.0020
# Q79I: 0.0019
# Other theft: 0.0019
# Q144: 0.0019
# Q62TJ: 0.0019
# NQ135BE: 0.0017
# Q10F: 0.0017
# Robbery: 0.0016
# XQ128A2C: 0.0016
# NQ47A: 0.0015
# Q54B: 0.0013
# [0]	train-rmse:0.71169	test-rmse:0.79359
# [10]	train-rmse:0.47389	test-rmse:0.77771
# [13]	train-rmse:0.44677	test-rmse:0.78502
# RMSE on test set with top features for 3: 0.7850198377176765
#                       Feature  Importance
# 2                          Q1        64.0
# 5   Criminal damage and arson        62.0
# 4                        Q62A        55.0
# 0                         Q3C        52.0
# 16                    Robbery        45.0
# 7                        Q79E        43.0
# 11                Other theft        37.0
# 10                       Q79I        36.0
# 13                      Q62TJ        32.0
# 14                    NQ135BE        32.0
# 6                      NQ57AC        31.0
# 12                       Q144        29.0
# 8                      NQ57AA        27.0
# 1                         Q3H        27.0
# 3                     NQ135BB        23.0
# 17                   XQ128A2C        21.0
# 18                      NQ47A        18.0
# 9                        Q54A        13.0
# 19                       Q54B        12.0
# 15                       Q10F         9.0
# Processing borough: 13
# Splitting data for borough: 13
# Converting data to DMatrix format for borough: 13
# Training model for borough: 13
# [0]	train-rmse:0.87344	test-rmse:0.95136
# [10]	train-rmse:0.42549	test-rmse:0.80850
# [20]	train-rmse:0.34225	test-rmse:0.81278
# Making predictions for borough: 13
# Calculating RMSE for borough: 13
# RMSE for 13: 0.8127819196980437
# Calculating permutation importances for borough: 13
# Calculating Permutation Importance for 13: 100%|██████████| 597/597 [05:34<00:00,  1.78it/s]
# Top 20 Feature Importance for 13:
# Q62TI: 0.0068
# NQ147r: 0.0061
# Q3K: 0.0029
# NQ62B: 0.0026
# NQ135BH: 0.0026
# Mixed/ Other: 0.0025
# NQ135BDD: 0.0021
# SQ79ED: 0.0019
# Q62A: 0.0019
# Q3H: 0.0018
# NQ57AB: 0.0016
# Drugs: 0.0015
# Q54C: 0.0015
# NQ135A_newS: 0.0014
# NNQ135A: 0.0013
# NQ57AE: 0.0013
# Public order: 0.0011
# SQ79C: 0.0011
# NQ135BDE: 0.0010
# SQ80D: 0.0010
# [0]	train-rmse:0.89933	test-rmse:0.99978
# [10]	train-rmse:0.58649	test-rmse:0.92606
# [16]	train-rmse:0.53283	test-rmse:0.92747
# RMSE on test set with top features for 13: 0.9274664384364325
#          Feature  Importance
# 4        NQ135BH        89.0
# 11         Drugs        68.0
# 0          Q62TI        66.0
# 16  Public order        59.0
# 8           Q62A        51.0
# 2            Q3K        50.0
# 1         NQ147r        48.0
# 19         SQ80D        48.0
# 3          NQ62B        44.0
# 9            Q3H        37.0
# 10        NQ57AB        37.0
# 14       NNQ135A        36.0
# 12          Q54C        34.0
# 15        NQ57AE        32.0
# 5   Mixed/ Other        23.0
# 6       NQ135BDD        22.0
# 17         SQ79C        16.0
# 7         SQ79ED        15.0
# 18      NQ135BDE        14.0
# 13   NQ135A_newS         7.0
# Processing borough: 14
# Splitting data for borough: 14
# Converting data to DMatrix format for borough: 14
# Training model for borough: 14
# [0]	train-rmse:0.75071	test-rmse:0.81457
# [10]	train-rmse:0.40087	test-rmse:0.70195
# [17]	train-rmse:0.34998	test-rmse:0.70814
# Making predictions for borough: 14
# Calculating RMSE for borough: 14
# RMSE for 14: 0.7073465596560545
# Calculating permutation importances for borough: 14
# Calculating Permutation Importance for 14: 100%|██████████| 597/597 [05:27<00:00,  1.82it/s]
# Top 20 Feature Importance for 14:
# Q62TG: 0.0039
# XQ9A: 0.0037
# Q3C: 0.0035
# NQ135BDD: 0.0027
# Q62F: 0.0025
# Q194: 0.0024
# Q1: 0.0021
# Q196B: 0.0019
# Possession of weapons: 0.0019
# XQ128A2B: 0.0018
# XQ59A: 0.0018
# Q16D: 0.0016
# Q196C: 0.0016
# NQ79BC: 0.0015
# Q62A: 0.0014
# Shoplifting: 0.0014
# Burglary: 0.0014
# XQ59D: 0.0014
# Q13: 0.0014
# Q3K: 0.0013
# [0]	train-rmse:0.77347	test-rmse:0.83156
# [10]	train-rmse:0.54208	test-rmse:0.79048
# [18]	train-rmse:0.47682	test-rmse:0.79523
# RMSE on test set with top features for 14: 0.7952252672914006
#                   Feature  Importance
# 0                   Q62TG        93.0
# 15            Shoplifting        83.0
# 8   Possession of weapons        77.0
# 2                     Q3C        70.0
# 4                    Q62F        67.0
# 16               Burglary        66.0
# 14                   Q62A        58.0
# 6                      Q1        57.0
# 18                    Q13        47.0
# 19                    Q3K        45.0
# 13                 NQ79BC        44.0
# 3                NQ135BDD        32.0
# 17                  XQ59D        30.0
# 5                    Q194        25.0
# 10                  XQ59A        24.0
# 7                   Q196B        22.0
# 11                   Q16D        14.0
# 12                  Q196C        14.0
# 9                XQ128A2B        14.0
# 1                    XQ9A        12.0
# Processing borough: 9
# Splitting data for borough: 9
# Converting data to DMatrix format for borough: 9
# Training model for borough: 9
# [0]	train-rmse:0.80756	test-rmse:0.91561
# [10]	train-rmse:0.41097	test-rmse:0.73276
# [20]	train-rmse:0.33562	test-rmse:0.71953
# [28]	train-rmse:0.29206	test-rmse:0.72148
# Making predictions for borough: 9
# Calculating RMSE for borough: 9
# RMSE for 9: 0.7206125594808357
# Calculating permutation importances for borough: 9
# Calculating Permutation Importance for 9: 100%|██████████| 597/597 [05:22<00:00,  1.85it/s]
# Top 20 Feature Importance for 9:
# Anti-social behaviour: 0.0037
# Q21: 0.0033
# Q132NN: 0.0029
# Month_Number: 0.0019
# NQCV6: 0.0018
# PQ135AAG: 0.0016
# IMDQuartile: 0.0014
# NQ44BD: 0.0014
# Q131: 0.0013
# XQ21A: 0.0012
# SQ132P: 0.0012
# Q39A_2: 0.0012
# Q79H: 0.0011
# Criminal damage and arson: 0.0011
# NQ193B: 0.0011
# ZQ10C: 0.0011
# NQ135A_newAC: 0.0009
# PQ135BN: 0.0009
# Q144: 0.0009
# NQ79D: 0.0008
# [0]	train-rmse:0.90121	test-rmse:1.00113
# [10]	train-rmse:0.71782	test-rmse:0.99497
# [12]	train-rmse:0.69960	test-rmse:0.99487
# RMSE on test set with top features for 9: 0.9948666526089159
#                       Feature  Importance
# 0       Anti-social behaviour        85.0
# 18                       Q144        58.0
# 3                Month_Number        57.0
# 13  Criminal damage and arson        57.0
# 1                         Q21        53.0
# 12                       Q79H        51.0
# 8                        Q131        44.0
# 11                     Q39A_2        44.0
# 19                      NQ79D        23.0
# 15                      ZQ10C        21.0
# 6                 IMDQuartile        16.0
# 9                       XQ21A        15.0
# 14                     NQ193B        15.0
# 10                     SQ132P        14.0
# 5                    PQ135AAG        10.0
# 2                      Q132NN        10.0
# 4                       NQCV6         9.0
# 16               NQ135A_newAC         6.0
# 7                      NQ44BD         5.0
# 17                    PQ135BN         4.0
# Processing borough: 7
# Splitting data for borough: 7
# Converting data to DMatrix format for borough: 7
# Training model for borough: 7
# [0]	train-rmse:0.76584	test-rmse:0.77224
# [10]	train-rmse:0.36597	test-rmse:0.66831
# [20]	train-rmse:0.30024	test-rmse:0.67055
# Making predictions for borough: 7
# Calculating RMSE for borough: 7
# RMSE for 7: 0.6705465836665674
# Calculating permutation importances for borough: 7
# Calculating Permutation Importance for 7: 100%|██████████| 597/597 [05:26<00:00,  1.83it/s]
# Top 20 Feature Importance for 7:
# Q79B: 0.0081
# Q79C: 0.0051
# Q62TG: 0.0034
# A121: 0.0026
# NNQ27E: 0.0021
# SQ80D: 0.0020
# Q3I: 0.0018
# Q79D: 0.0018
# ZQ10I: 0.0017
# Q3L: 0.0017
# Q62F: 0.0017
# ZQ10A: 0.0017
# Q62TI: 0.0016
# XQ21E: 0.0016
# Burglary: 0.0015
# Q54D: 0.0013
# Q141: 0.0013
# XQ59B: 0.0011
# SQ79C: 0.0010
# Q3J: 0.0010
# [0]	train-rmse:0.78580	test-rmse:0.79104
# [10]	train-rmse:0.48569	test-rmse:0.73492
# [13]	train-rmse:0.46522	test-rmse:0.73584
# RMSE on test set with top features for 7: 0.7373339446671081
#      Feature  Importance
# 0       Q79B        84.0
# 14  Burglary        67.0
# 3       A121        63.0
# 5      SQ80D        53.0
# 2      Q62TG        52.0
# 1       Q79C        50.0
# 7       Q79D        49.0
# 6        Q3I        36.0
# 9        Q3L        33.0
# 10      Q62F        33.0
# 12     Q62TI        31.0
# 15      Q54D        30.0
# 16      Q141        30.0
# 19       Q3J        26.0
# 13     XQ21E        25.0
# 18     SQ79C        25.0
# 8      ZQ10I        22.0
# 17     XQ59B        21.0
# 11     ZQ10A        16.0
# 4     NNQ27E        16.0
# Processing borough: 24
# Splitting data for borough: 24
# Converting data to DMatrix format for borough: 24
# Training model for borough: 24
# [0]	train-rmse:0.77055	test-rmse:0.81102
# [10]	train-rmse:0.37268	test-rmse:0.66013
# [16]	train-rmse:0.32610	test-rmse:0.66532
# Making predictions for borough: 24
# Calculating RMSE for borough: 24
# RMSE for 24: 0.6638154033853801
# Calculating permutation importances for borough: 24
# Calculating Permutation Importance for 24: 100%|██████████| 597/597 [05:26<00:00,  1.83it/s]
# Top 20 Feature Importance for 24:
# Q21: 0.0051
# NQ135BH: 0.0037
# Q3K: 0.0036
# Q3C: 0.0029
# Q136r: 0.0024
# Q79J: 0.0024
# Q62E: 0.0023
# Q39A_2: 0.0022
# NQ57AA: 0.0021
# Q141: 0.0020
# XQ8: 0.0019
# PQ135AAV: 0.0018
# NQCV6: 0.0017
# Public order: 0.0017
# Other theft: 0.0017
# Q38D: 0.0016
# Q146: 0.0016
# Criminal damage and arson: 0.0015
# Q3G: 0.0013
# NQCV25: 0.0013
# [0]	train-rmse:0.82089	test-rmse:0.86943
# [10]	train-rmse:0.55528	test-rmse:0.81338
# [14]	train-rmse:0.52375	test-rmse:0.81995
# RMSE on test set with top features for 24: 0.8199542622561271
#                       Feature  Importance
# 1                     NQ135BH        66.0
# 5                        Q79J        63.0
# 14                Other theft        61.0
# 13               Public order        59.0
# 0                         Q21        52.0
# 3                         Q3C        50.0
# 8                      NQ57AA        46.0
# 6                        Q62E        45.0
# 7                      Q39A_2        45.0
# 2                         Q3K        44.0
# 17  Criminal damage and arson        38.0
# 4                       Q136r        35.0
# 9                        Q141        32.0
# 18                        Q3G        28.0
# 19                     NQCV25        25.0
# 16                       Q146        17.0
# 12                      NQCV6        11.0
# 10                        XQ8         9.0
# 11                   PQ135AAV         6.0
# 15                       Q38D         3.0
# Processing borough: 1
# Splitting data for borough: 1
# Converting data to DMatrix format for borough: 1
# Training model for borough: 1
# [0]	train-rmse:0.76074	test-rmse:0.78975
# [10]	train-rmse:0.38042	test-rmse:0.67146
# [20]	train-rmse:0.30753	test-rmse:0.67486
# [21]	train-rmse:0.30214	test-rmse:0.67693
# Making predictions for borough: 1
# Calculating RMSE for borough: 1
# RMSE for 1: 0.6769267646314773
# Calculating permutation importances for borough: 1
# Calculating Permutation Importance for 1: 100%|██████████| 597/597 [05:26<00:00,  1.83it/s]
# Top 20 Feature Importance for 1:
# Q62F: 0.0056
# Q79H: 0.0043
# Q79A: 0.0038
# Q60: 0.0033
# NQCV14: 0.0032
# NQCV22: 0.0027
# Q79C: 0.0024
# Bicycle theft: 0.0023
# NQ135BDE: 0.0021
# SQ132AM: 0.0021
# Anti-social behaviour: 0.0017
# NQ193B: 0.0016
# Q54B: 0.0014
# Drugs: 0.0012
# XQ128A2C: 0.0011
# Q62E: 0.0010
# NQ79BC: 0.0010
# Q39BC: 0.0010
# PQ135AAG: 0.0010
# Q9: 0.0010
# [0]	train-rmse:0.79235	test-rmse:0.78743
# [10]	train-rmse:0.51682	test-rmse:0.73559
# [14]	train-rmse:0.49101	test-rmse:0.74177
# RMSE on test set with top features for 1: 0.7426689763418596
#                   Feature  Importance
# 0                    Q62F        89.0
# 1                    Q79H        77.0
# 10  Anti-social behaviour        71.0
# 3                     Q60        55.0
# 7           Bicycle theft        55.0
# 2                    Q79A        54.0
# 13                  Drugs        48.0
# 6                    Q79C        46.0
# 16                 NQ79BC        36.0
# 15                   Q62E        34.0
# 12                   Q54B        25.0
# 4                  NQCV14        23.0
# 14               XQ128A2C        22.0
# 11                 NQ193B        22.0
# 8                NQ135BDE        19.0
# 19                     Q9        18.0
# 9                 SQ132AM        10.0
# 17                  Q39BC        10.0
# 5                  NQCV22         9.0
# 18               PQ135AAG         7.0
# Processing borough: 15
# Splitting data for borough: 15
# Converting data to DMatrix format for borough: 15
# Training model for borough: 15
# [0]	train-rmse:0.72389	test-rmse:0.77880
# [10]	train-rmse:0.36435	test-rmse:0.65997
# [20]	train-rmse:0.30346	test-rmse:0.66497
# Making predictions for borough: 15
# Calculating RMSE for borough: 15
# RMSE for 15: 0.6649736877614899
# Calculating permutation importances for borough: 15
# Calculating Permutation Importance for 15: 100%|██████████| 597/597 [05:25<00:00,  1.84it/s]
# Top 20 Feature Importance for 15:
# Q62A: 0.0117
# Q144: 0.0078
# Q39A_2: 0.0038
# Total: 0.0033
# Q60: 0.0031
# Q79A: 0.0027
# Possession of weapons: 0.0026
# NQ79D: 0.0024
# Q1: 0.0021
# NQ7A: 0.0020
# Q3F: 0.0017
# Q126DC: 0.0017
# SQ79B: 0.0017
# Shoplifting: 0.0016
# NQ135BB: 0.0014
# NQ147r: 0.0014
# ReQ136: 0.0013
# Q79J: 0.0012
# ReNQ147: 0.0012
# Q9: 0.0011
# [0]	train-rmse:0.76134	test-rmse:0.79378
# [10]	train-rmse:0.51524	test-rmse:0.69871
# [18]	train-rmse:0.44796	test-rmse:0.71104
# RMSE on test set with top features for 15: 0.7110399188549077
#                   Feature  Importance
# 0                    Q62A        97.0
# 13            Shoplifting        74.0
# 6   Possession of weapons        67.0
# 4                     Q60        64.0
# 5                    Q79A        64.0
# 1                    Q144        62.0
# 8                      Q1        60.0
# 2                  Q39A_2        48.0
# 10                    Q3F        44.0
# 17                   Q79J        40.0
# 14                NQ135BB        33.0
# 12                  SQ79B        31.0
# 7                   NQ79D        30.0
# 9                    NQ7A        26.0
# 3                   Total        25.0
# 16                 ReQ136        24.0
# 15                 NQ147r        17.0
# 19                     Q9        17.0
# 11                 Q126DC        15.0
# 18                ReNQ147        10.0
# Processing borough: 25
# Splitting data for borough: 25
# Converting data to DMatrix format for borough: 25
# Training model for borough: 25
# [0]	train-rmse:0.72698	test-rmse:0.70883
# [10]	train-rmse:0.35277	test-rmse:0.61552
# [17]	train-rmse:0.30253	test-rmse:0.61716
# Making predictions for borough: 25
# Calculating RMSE for borough: 25
# RMSE for 25: 0.6164045345221422
# Calculating permutation importances for borough: 25
# Calculating Permutation Importance for 25: 100%|██████████| 597/597 [05:19<00:00,  1.87it/s]
# Top 20 Feature Importance for 25:
# XQ128A2C: 0.0031
# Public order: 0.0025
# NQCV16: 0.0024
# Q62F: 0.0021
# NNQ135A: 0.0021
# Q79I: 0.0021
# Q10B: 0.0018
# ReNQ147: 0.0016
# NQ57AE: 0.0015
# NQCV15: 0.0015
# Q139r: 0.0014
# Q62TI: 0.0013
# NQ21: 0.0013
# NQ135BH: 0.0012
# Q3H: 0.0012
# Theft from the person: 0.0011
# Criminal damage and arson: 0.0011
# Q3C: 0.0010
# Q10F: 0.0009
# IMDQuartile: 0.0009
# [0]	train-rmse:0.77830	test-rmse:0.74317
# [10]	train-rmse:0.54287	test-rmse:0.72065
# [12]	train-rmse:0.52494	test-rmse:0.72353
# RMSE on test set with top features for 25: 0.7267214000576673
#                       Feature  Importance
# 1                Public order       113.0
# 3                        Q62F        54.0
# 15      Theft from the person        44.0
# 16  Criminal damage and arson        42.0
# 5                        Q79I        42.0
# 11                      Q62TI        39.0
# 13                    NQ135BH        34.0
# 14                        Q3H        33.0
# 8                      NQ57AE        31.0
# 10                      Q139r        30.0
# 4                     NNQ135A        30.0
# 0                    XQ128A2C        28.0
# 17                        Q3C        27.0
# 6                        Q10B        20.0
# 7                     ReNQ147        15.0
# 2                      NQCV16        14.0
# 19                IMDQuartile        10.0
# 9                      NQCV15         9.0
# 12                       NQ21         7.0
# 18                       Q10F         5.0
# Processing borough: 27
# Splitting data for borough: 27
# Converting data to DMatrix format for borough: 27
# Training model for borough: 27
# [0]	train-rmse:0.76611	test-rmse:0.87543
# [10]	train-rmse:0.37070	test-rmse:0.74908
# [20]	train-rmse:0.29607	test-rmse:0.75375
# [21]	train-rmse:0.29002	test-rmse:0.75378
# Making predictions for borough: 27
# Calculating RMSE for borough: 27
# RMSE for 27: 0.7537797593792922
# Calculating permutation importances for borough: 27
# Calculating Permutation Importance for 27: 100%|██████████| 597/597 [05:25<00:00,  1.84it/s]
# Top 20 Feature Importance for 27:
# Q14D: 0.0045
# Q60: 0.0043
# Drugs: 0.0042
# NQ57AB: 0.0035
# Robbery: 0.0032
# Q15: 0.0029
# XQ3A: 0.0029
# Q132N: 0.0028
# NQ79BI: 0.0026
# Q3C: 0.0026
# Other crime: 0.0020
# NQ43: 0.0017
# NQCV24: 0.0016
# XQ123: 0.0015
# NQ7A: 0.0014
# ReNQ147: 0.0014
# Shoplifting: 0.0012
# NQ7B: 0.0012
# Bicycle theft: 0.0012
# Q62B: 0.0012
# [0]	train-rmse:0.79671	test-rmse:0.91503
# [10]	train-rmse:0.54739	test-rmse:0.86500
# [15]	train-rmse:0.50966	test-rmse:0.86901
# RMSE on test set with top features for 27: 0.8711982260909529
#           Feature  Importance
# 2           Drugs        69.0
# 1             Q60        64.0
# 4         Robbery        58.0
# 3          NQ57AB        56.0
# 19           Q62B        45.0
# 8          NQ79BI        44.0
# 5             Q15        40.0
# 17           NQ7B        38.0
# 18  Bicycle theft        34.0
# 16    Shoplifting        34.0
# 9             Q3C        31.0
# 11           NQ43        30.0
# 15        ReNQ147        29.0
# 10    Other crime        28.0
# 6            XQ3A        23.0
# 12         NQCV24        18.0
# 14           NQ7A        17.0
# 13          XQ123        12.0
# 0            Q14D        11.0
# 7           Q132N         4.0
# Processing borough: 21
# Splitting data for borough: 21
# Converting data to DMatrix format for borough: 21
# Training model for borough: 21
# [0]	train-rmse:0.77289	test-rmse:0.83877
# [10]	train-rmse:0.36546	test-rmse:0.67332
# [16]	train-rmse:0.30372	test-rmse:0.67889
# Making predictions for borough: 21
# Calculating RMSE for borough: 21
# RMSE for 21: 0.678771846054679
# Calculating permutation importances for borough: 21
# Calculating Permutation Importance for 21: 100%|██████████| 597/597 [05:29<00:00,  1.81it/s]
# Top 20 Feature Importance for 21:
# NQ79D: 0.0045
# NQ147r: 0.0042
# Drugs: 0.0030
# SQ79DA: 0.0029
# Burglary: 0.0025
# Q62F: 0.0023
# Q119: 0.0022
# White: 0.0020
# XQ128A2B: 0.0020
# SQ80F: 0.0019
# NQ79BB: 0.0017
# NQCV11: 0.0017
# Q125: 0.0016
# SQ79DB: 0.0015
# Other theft: 0.0015
# SQ132L: 0.0014
# Q126DA: 0.0014
# Q132AM: 0.0013
# SQ80D: 0.0012
# Q15: 0.0012
# [0]	train-rmse:0.82984	test-rmse:0.89262
# [10]	train-rmse:0.60711	test-rmse:0.80381
# [19]	train-rmse:0.53145	test-rmse:0.80930
# RMSE on test set with top features for 21: 0.8131495143059847
#         Feature  Importance
# 5          Q62F       112.0
# 2         Drugs        94.0
# 4      Burglary        72.0
# 14  Other theft        70.0
# 18        SQ80D        66.0
# 1        NQ147r        62.0
# 19          Q15        58.0
# 10       NQ79BB        47.0
# 11       NQCV11        44.0
# 0         NQ79D        43.0
# 9         SQ80F        31.0
# 17       Q132AM        23.0
# 16       Q126DA        22.0
# 8      XQ128A2B        20.0
# 6          Q119        20.0
# 7         White        14.0
# 12         Q125        14.0
# 3        SQ79DA        11.0
# 15       SQ132L        10.0
# 13       SQ79DB         7.0
# Processing borough: 17
# Splitting data for borough: 17
# Converting data to DMatrix format for borough: 17
# Training model for borough: 17
# [0]	train-rmse:0.70752	test-rmse:0.71794
# [10]	train-rmse:0.37325	test-rmse:0.65324
# [20]	train-rmse:0.30592	test-rmse:0.65614
# Making predictions for borough: 17
# Calculating RMSE for borough: 17
# RMSE for 17: 0.6561397438777611
# Calculating permutation importances for borough: 17
# Calculating Permutation Importance for 17: 100%|██████████| 597/597 [05:21<00:00,  1.85it/s]
# Top 20 Feature Importance for 17:
# Q3L: 0.0100
# Q79I: 0.0031
# Q136r: 0.0023
# Q79F: 0.0022
# ZQ10I: 0.0021
# Q3H: 0.0020
# NQ62D: 0.0018
# XQ59D: 0.0016
# NQ79ABD: 0.0016
# NQCV25: 0.0013
# NQ44BA: 0.0013
# Q39A_2: 0.0012
# Q13: 0.0012
# NQCV15: 0.0012
# NQCV2: 0.0011
# NQ135BB: 0.0011
# Q1: 0.0010
# Q62TJ: 0.0009
# Q3F: 0.0009
# NQCV5: 0.0009
# [0]	train-rmse:0.77373	test-rmse:0.75691
# [10]	train-rmse:0.59082	test-rmse:0.75434
# [14]	train-rmse:0.55732	test-rmse:0.75662
# RMSE on test set with top features for 17: 0.7566168007102425
#     Feature  Importance
# 1      Q79I        75.0
# 0       Q3L        56.0
# 16       Q1        54.0
# 3      Q79F        49.0
# 12      Q13        42.0
# 2     Q136r        38.0
# 11   Q39A_2        38.0
# 6     NQ62D        36.0
# 17    Q62TJ        35.0
# 5       Q3H        31.0
# 18      Q3F        27.0
# 9    NQCV25        22.0
# 15  NQ135BB        22.0
# 4     ZQ10I        21.0
# 7     XQ59D        17.0
# 13   NQCV15        14.0
# 10   NQ44BA        12.0
# 14    NQCV2         8.0
# 8   NQ79ABD         8.0
# 19    NQCV5         3.0
# Processing borough: 10
# Splitting data for borough: 10
# Converting data to DMatrix format for borough: 10
# Training model for borough: 10
# [0]	train-rmse:0.77511	test-rmse:0.72655
# [10]	train-rmse:0.38086	test-rmse:0.62306
# [18]	train-rmse:0.31153	test-rmse:0.62705
# Making predictions for borough: 10
# Calculating RMSE for borough: 10
# RMSE for 10: 0.6268824860255632
# Calculating permutation importances for borough: 10
# Calculating Permutation Importance for 10: 100%|██████████| 597/597 [05:24<00:00,  1.84it/s]
# Top 20 Feature Importance for 10:
# NQ79BD: 0.0057
# NQ79BC: 0.0033
# Q3G: 0.0032
# XQ21A: 0.0030
# A121: 0.0026
# NNQ135A: 0.0024
# NQ135BF: 0.0024
# XQ59B: 0.0024
# XQ135r: 0.0021
# Drugs: 0.0021
# Q66: 0.0019
# XQ21E: 0.0018
# SQ132O: 0.0018
# XNQ135B: 0.0017
# Q79I: 0.0017
# Q79B: 0.0016
# NQCV2: 0.0015
# Q37: 0.0014
# NQ2A: 0.0013
# XQ128A2A: 0.0013
# [0]	train-rmse:0.81267	test-rmse:0.77745
# [10]	train-rmse:0.57042	test-rmse:0.73340
# [13]	train-rmse:0.54853	test-rmse:0.73398
# RMSE on test set with top features for 10: 0.7343034426336631
#      Feature  Importance
# 9      Drugs        77.0
# 4       A121        64.0
# 15      Q79B        59.0
# 0     NQ79BD        58.0
# 2        Q3G        56.0
# 14      Q79I        45.0
# 1     NQ79BC        40.0
# 6    NQ135BF        38.0
# 5    NNQ135A        35.0
# 7      XQ59B        30.0
# 8     XQ135r        28.0
# 11     XQ21E        22.0
# 17       Q37        22.0
# 3      XQ21A        20.0
# 10       Q66        19.0
# 13   XNQ135B        19.0
# 12    SQ132O        11.0
# 18      NQ2A         8.0
# 16     NQCV2         7.0
# 19  XQ128A2A         7.0
# Processing borough: 20
# Splitting data for borough: 20
# Converting data to DMatrix format for borough: 20
# Training model for borough: 20
# [0]	train-rmse:0.64268	test-rmse:0.70058
# [10]	train-rmse:0.35117	test-rmse:0.61072
# [20]	train-rmse:0.28007	test-rmse:0.60930
# [30]	train-rmse:0.23673	test-rmse:0.60997
# [34]	train-rmse:0.22030	test-rmse:0.61255
# Making predictions for borough: 20
# Calculating RMSE for borough: 20
# RMSE for 20: 0.6124377641521
# Calculating permutation importances for borough: 20
# Calculating Permutation Importance for 20: 100%|██████████| 597/597 [05:28<00:00,  1.82it/s]
# Top 20 Feature Importance for 20:
# Q62B: 0.0133
# Q79E: 0.0093
# NQ135BH: 0.0069
# Q79F: 0.0034
# PQ135AA: 0.0032
# NQ135BI: 0.0031
# NQ135BE: 0.0028
# SQ79DA: 0.0021
# Q62A: 0.0021
# Q62TI: 0.0021
# SQ79DF: 0.0021
# PQ135AC: 0.0020
# Q79C: 0.0017
# BQ90F: 0.0015
# NQ135BDE: 0.0013
# NQCV14: 0.0013
# PQ135AAV: 0.0013
# ZQ10E: 0.0013
# Q14C: 0.0012
# Theft from the person: 0.0012
# [0]	train-rmse:0.66099	test-rmse:0.71483
# [10]	train-rmse:0.45617	test-rmse:0.67118
# [16]	train-rmse:0.41949	test-rmse:0.68322
# RMSE on test set with top features for 20: 0.6832212638305257
#                   Feature  Importance
# 1                    Q79E        95.0
# 19  Theft from the person        92.0
# 0                    Q62B        82.0
# 8                    Q62A        71.0
# 2                 NQ135BH        63.0
# 3                    Q79F        56.0
# 12                   Q79C        49.0
# 5                 NQ135BI        41.0
# 9                   Q62TI        33.0
# 6                 NQ135BE        28.0
# 14               NQ135BDE        24.0
# 17                  ZQ10E        24.0
# 13                  BQ90F        18.0
# 7                  SQ79DA        17.0
# 10                 SQ79DF        15.0
# 15                 NQCV14        13.0
# 4                 PQ135AA        13.0
# 18                   Q14C         8.0
# 11                PQ135AC         8.0
# 16               PQ135AAV         7.0
# Processing borough: 23
# Splitting data for borough: 23
# Converting data to DMatrix format for borough: 23
# Training model for borough: 23
# [0]	train-rmse:0.67277	test-rmse:0.66960
# [10]	train-rmse:0.35890	test-rmse:0.56174
# [20]	train-rmse:0.29393	test-rmse:0.56194
# [25]	train-rmse:0.27652	test-rmse:0.56089
# Making predictions for borough: 23
# Calculating RMSE for borough: 23
# RMSE for 23: 0.5608858340739515
# Calculating permutation importances for borough: 23
# Calculating Permutation Importance for 23: 100%|██████████| 597/597 [05:29<00:00,  1.81it/s]
# Top 20 Feature Importance for 23:
# NQCV6: 0.0044
# Q62TG: 0.0038
# NQ7B: 0.0032
# Q62H: 0.0029
# NQ44BA: 0.0026
# Q3G: 0.0024
# XQ128A2C: 0.0020
# Q3I: 0.0019
# XQ128A2B: 0.0018
# Q15: 0.0017
# Q62TJ: 0.0017
# Possession of weapons: 0.0017
# NQ193A: 0.0016
# Drugs: 0.0014
# Q54B: 0.0013
# ZQ10E: 0.0013
# Q60: 0.0012
# Q141: 0.0011
# SQ80F: 0.0011
# Q1: 0.0011
# [0]	train-rmse:0.70987	test-rmse:0.68834
# [10]	train-rmse:0.50533	test-rmse:0.65727
# [14]	train-rmse:0.47979	test-rmse:0.66043
# RMSE on test set with top features for 23: 0.6624845581663893
#                   Feature  Importance
# 1                   Q62TG        66.0
# 13                  Drugs        59.0
# 11  Possession of weapons        57.0
# 2                    NQ7B        53.0
# 19                     Q1        49.0
# 16                    Q60        42.0
# 10                  Q62TJ        41.0
# 7                     Q3I        40.0
# 5                     Q3G        37.0
# 3                    Q62H        37.0
# 9                     Q15        35.0
# 18                  SQ80F        28.0
# 14                   Q54B        26.0
# 15                  ZQ10E        21.0
# 17                   Q141        19.0
# 8                XQ128A2B        18.0
# 0                   NQCV6        13.0
# 12                 NQ193A        12.0
# 4                  NQ44BA        12.0
# 6                XQ128A2C        11.0
# Processing borough: 2
# Splitting data for borough: 2
# Converting data to DMatrix format for borough: 2
# Training model for borough: 2
# [0]	train-rmse:0.71262	test-rmse:0.73308
# [10]	train-rmse:0.38638	test-rmse:0.60686
# [19]	train-rmse:0.31543	test-rmse:0.60990
# Making predictions for borough: 2
# Calculating RMSE for borough: 2
# RMSE for 2: 0.609904880838875
# Calculating permutation importances for borough: 2
# Calculating Permutation Importance for 2: 100%|██████████| 597/597 [05:25<00:00,  1.83it/s]
# Top 20 Feature Importance for 2:
# Q79G: 0.0040
# Q3C: 0.0031
# NQ135BDE: 0.0025
# Q66: 0.0022
# Shoplifting: 0.0022
# Q14B: 0.0021
# NQ135BI: 0.0019
# NQ62A: 0.0017
# XQ57B: 0.0016
# ZQ10J: 0.0015
# NQCV8: 0.0014
# Public order: 0.0014
# NQ57AB: 0.0013
# SQ79EB: 0.0013
# Robbery: 0.0012
# NQ135A_newAV: 0.0012
# Burglary: 0.0011
# Q3F: 0.0011
# XQ57A: 0.0010
# Q196B: 0.0010
# [0]	train-rmse:0.77205	test-rmse:0.79880
# [10]	train-rmse:0.58566	test-rmse:0.80207
# [11]	train-rmse:0.57731	test-rmse:0.80319
# RMSE on test set with top features for 2: 0.8062456987258291
#          Feature  Importance
# 1            Q3C        65.0
# 0           Q79G        60.0
# 4    Shoplifting        58.0
# 11  Public order        51.0
# 14       Robbery        44.0
# 16      Burglary        41.0
# 12        NQ57AB        40.0
# 17           Q3F        36.0
# 2       NQ135BDE        33.0
# 6        NQ135BI        32.0
# 7          NQ62A        25.0
# 3            Q66        21.0
# 5           Q14B        15.0
# 9          ZQ10J        14.0
# 18         XQ57A        11.0
# 15  NQ135A_newAV        11.0
# 19         Q196B         8.0
# 10         NQCV8         7.0
# 13        SQ79EB         4.0
# 8          XQ57B         4.0
# Processing borough: 26
# Splitting data for borough: 26
# Converting data to DMatrix format for borough: 26
# Training model for borough: 26
# [0]	train-rmse:0.67407	test-rmse:0.70537
# [10]	train-rmse:0.37547	test-rmse:0.64151
# [16]	train-rmse:0.33133	test-rmse:0.64672
# Making predictions for borough: 26
# Calculating RMSE for borough: 26
# RMSE for 26: 0.645632195443362
# Calculating permutation importances for borough: 26
# Calculating Permutation Importance for 26: 100%|██████████| 597/597 [05:23<00:00,  1.85it/s]
# Top 20 Feature Importance for 26:
# Theft from the person: 0.0068
# Q9: 0.0041
# Shoplifting: 0.0039
# Q62A: 0.0034
# Q3K: 0.0031
# NQ62D: 0.0028
# NQ135A_newAY: 0.0027
# Q3I: 0.0027
# Q3C: 0.0020
# NNQ135A: 0.0017
# Q54E: 0.0016
# Q132P: 0.0016
# Q79E: 0.0015
# XQ59A: 0.0015
# NQ135BC: 0.0015
# ZQ10E: 0.0014
# ZQ10J: 0.0013
# Other crime: 0.0013
# Q79F: 0.0012
# Q62TG: 0.0012
# [0]	train-rmse:0.70648	test-rmse:0.71165
# [10]	train-rmse:0.50382	test-rmse:0.68456
# [13]	train-rmse:0.48072	test-rmse:0.68908
# RMSE on test set with top features for 26: 0.6910993307707897
#                   Feature  Importance
# 0   Theft from the person        70.0
# 3                    Q62A        55.0
# 12                   Q79E        49.0
# 2             Shoplifting        49.0
# 19                  Q62TG        48.0
# 7                     Q3I        40.0
# 9                 NNQ135A        40.0
# 17            Other crime        40.0
# 1                      Q9        36.0
# 5                   NQ62D        35.0
# 8                     Q3C        32.0
# 18                   Q79F        30.0
# 4                     Q3K        27.0
# 10                   Q54E        27.0
# 14                NQ135BC        25.0
# 15                  ZQ10E        18.0
# 16                  ZQ10J        15.0
# 13                  XQ59A        14.0
# 11                  Q132P         8.0
# 6            NQ135A_newAY         6.0
# Processing borough: 16
# Splitting data for borough: 16
# Converting data to DMatrix format for borough: 16
# Training model for borough: 16
# [0]	train-rmse:0.75252	test-rmse:0.75951
# [10]	train-rmse:0.37631	test-rmse:0.65569
# [17]	train-rmse:0.31980	test-rmse:0.65582
# Making predictions for borough: 16
# Calculating RMSE for borough: 16
# RMSE for 16: 0.655817953457283
# Calculating permutation importances for borough: 16
# Calculating Permutation Importance for 16: 100%|██████████| 597/597 [05:30<00:00,  1.81it/s]
# Top 20 Feature Importance for 16:
# Q79F: 0.0028
# Q62E: 0.0024
# Q58: 0.0021
# Possession of weapons: 0.0019
# SQ80E: 0.0017
# NQ79ABD: 0.0015
# Vehicle crime: 0.0015
# NQ147r: 0.0014
# Q10E: 0.0014
# Q124: 0.0013
# Q9: 0.0013
# Anti-social behaviour: 0.0012
# Q16B: 0.0012
# NQ79D: 0.0010
# Public order: 0.0010
# PQ119: 0.0009
# XQ8: 0.0009
# NQ57AD: 0.0009
# Q79I: 0.0009
# SQ132NN: 0.0008
# [0]	train-rmse:0.81152	test-rmse:0.78704
# [10]	train-rmse:0.61747	test-rmse:0.80202
# [11]	train-rmse:0.61189	test-rmse:0.80323
# RMSE on test set with top features for 16: 0.8043526728310032
#                   Feature  Importance
# 0                    Q79F        67.0
# 1                    Q62E        59.0
# 6           Vehicle crime        44.0
# 2                     Q58        41.0
# 14           Public order        40.0
# 13                  NQ79D        38.0
# 11  Anti-social behaviour        37.0
# 3   Possession of weapons        36.0
# 4                   SQ80E        36.0
# 17                 NQ57AD        35.0
# 18                   Q79I        29.0
# 7                  NQ147r        26.0
# 16                    XQ8        22.0
# 10                     Q9        17.0
# 9                    Q124        13.0
# 5                 NQ79ABD        12.0
# 8                    Q10E         8.0
# 19                SQ132NN         7.0
# 12                   Q16B         4.0
# 15                  PQ119         1.0
# Processing borough: 4
# Splitting data for borough: 4
# Converting data to DMatrix format for borough: 4
# Training model for borough: 4
# [0]	train-rmse:0.77507	test-rmse:0.83413
# [10]	train-rmse:0.38948	test-rmse:0.71242
# [18]	train-rmse:0.32188	test-rmse:0.72433
# Making predictions for borough: 4
# Calculating RMSE for borough: 4
# RMSE for 4: 0.7243295857110669
# Calculating permutation importances for borough: 4
# Calculating Permutation Importance for 4: 100%|██████████| 597/597 [05:25<00:00,  1.83it/s]
# Top 20 Feature Importance for 4:
# Q62TG: 0.0081
# NQ57AB: 0.0061
# Possession of weapons: 0.0045
# Q62F: 0.0042
# Q13: 0.0035
# Q60: 0.0029
# NQ79BC: 0.0027
# BQ90F: 0.0027
# Q62TJ: 0.0025
# NQ79BB: 0.0024
# SQ79EN: 0.0023
# PQ135BD: 0.0022
# SQ80E: 0.0022
# NQCV11: 0.0017
# ZQ10B: 0.0017
# Q3H: 0.0016
# SQ80C: 0.0016
# Criminal damage and arson: 0.0015
# Q21: 0.0015
# Q3L: 0.0014
# [0]	train-rmse:0.80783	test-rmse:0.84603
# [10]	train-rmse:0.53671	test-rmse:0.80656
# [13]	train-rmse:0.51278	test-rmse:0.81383
# RMSE on test set with top features for 4: 0.821023369513245
#                       Feature  Importance
# 0                       Q62TG        75.0
# 2       Possession of weapons        71.0
# 17  Criminal damage and arson        53.0
# 1                      NQ57AB        53.0
# 5                         Q60        50.0
# 6                      NQ79BC        42.0
# 19                        Q3L        40.0
# 8                       Q62TJ        33.0
# 4                         Q13        32.0
# 15                        Q3H        30.0
# 3                        Q62F        30.0
# 9                      NQ79BB        29.0
# 18                        Q21        27.0
# 12                      SQ80E        26.0
# 13                     NQCV11        22.0
# 14                      ZQ10B        18.0
# 16                      SQ80C        14.0
# 10                     SQ79EN        14.0
# 7                       BQ90F        13.0
# 11                    PQ135BD         2.0
# Processing borough: 8
# Splitting data for borough: 8
# Converting data to DMatrix format for borough: 8
# Training model for borough: 8
# [0]	train-rmse:0.71468	test-rmse:0.72859
# [10]	train-rmse:0.37643	test-rmse:0.61420
# [20]	train-rmse:0.29802	test-rmse:0.61370
# [24]	train-rmse:0.28250	test-rmse:0.61628
# Making predictions for borough: 8
# Calculating RMSE for borough: 8
# RMSE for 8: 0.6162804029243596
# Calculating permutation importances for borough: 8
# Calculating Permutation Importance for 8: 100%|██████████| 597/597 [05:33<00:00,  1.79it/s]
# Top 20 Feature Importance for 8:
# Q60: 0.0069
# Q62B: 0.0041
# Q21: 0.0038
# Q79A: 0.0035
# NQ57AD: 0.0035
# Q1: 0.0033
# NQ47A: 0.0026
# Shoplifting: 0.0025
# Q39BC: 0.0022
# Anti-social behaviour: 0.0020
# ZQ10B: 0.0019
# Q14B: 0.0019
# SQ79EG: 0.0018
# ZQ10I: 0.0017
# NQ135A_newC: 0.0017
# Q58: 0.0016
# NQ80H: 0.0016
# NQ79BB: 0.0014
# Q79G: 0.0014
# Q79H: 0.0013
# [0]	train-rmse:0.74818	test-rmse:0.74851
# [10]	train-rmse:0.52765	test-rmse:0.71080
# [18]	train-rmse:0.48340	test-rmse:0.72374
# RMSE on test set with top features for 8: 0.7237404050364813
#                   Feature  Importance
# 0                     Q60        87.0
# 9   Anti-social behaviour        80.0
# 7             Shoplifting        71.0
# 3                    Q79A        64.0
# 19                   Q79H        59.0
# 5                      Q1        57.0
# 4                  NQ57AD        56.0
# 1                    Q62B        56.0
# 2                     Q21        50.0
# 18                   Q79G        50.0
# 6                   NQ47A        28.0
# 10                  ZQ10B        27.0
# 15                    Q58        26.0
# 17                 NQ79BB        25.0
# 12                 SQ79EG        19.0
# 14            NQ135A_newC        13.0
# 11                   Q14B         9.0
# 16                  NQ80H         6.0
# 8                   Q39BC         4.0
# 13                  ZQ10I         3.0
# Processing borough: 31
# Splitting data for borough: 31
# Converting data to DMatrix format for borough: 31
# Training model for borough: 31
# [0]	train-rmse:0.74417	test-rmse:0.78076
# [10]	train-rmse:0.37411	test-rmse:0.63317
# [20]	train-rmse:0.29660	test-rmse:0.63358
# Making predictions for borough: 31
# Calculating RMSE for borough: 31
# RMSE for 31: 0.6343283550962598
# Calculating permutation importances for borough: 31
# Calculating Permutation Importance for 31: 100%|██████████| 597/597 [05:38<00:00,  1.76it/s]
# Top 20 Feature Importance for 31:
# Q79B: 0.0022
# NNQ27C: 0.0022
# SQ79EC: 0.0022
# PQ135BA: 0.0021
# Q62TI: 0.0021
# Q58: 0.0021
# NQCV26: 0.0019
# Q62D: 0.0012
# Anti-social behaviour: 0.0012
# NQ57AD: 0.0011
# SQ80C: 0.0011
# NQ7B: 0.0011
# Q21: 0.0011
# SQ79DB: 0.0010
# NQCV28: 0.0010
# Q3J: 0.0010
# NQ2C: 0.0010
# Q39A_2: 0.0009
# Q144: 0.0008
# PQ135AAG: 0.0008
# [0]	train-rmse:0.79255	test-rmse:0.81611
# [10]	train-rmse:0.56488	test-rmse:0.77063
# [14]	train-rmse:0.52730	test-rmse:0.77805
# RMSE on test set with top features for 31: 0.7789775594818372
#                   Feature  Importance
# 8   Anti-social behaviour       108.0
# 0                    Q79B        69.0
# 7                    Q62D        56.0
# 4                   Q62TI        55.0
# 18                   Q144        52.0
# 17                 Q39A_2        45.0
# 15                    Q3J        43.0
# 9                  NQ57AD        41.0
# 5                     Q58        35.0
# 2                  SQ79EC        33.0
# 1                  NNQ27C        32.0
# 11                   NQ7B        31.0
# 12                    Q21        30.0
# 6                  NQCV26        23.0
# 14                 NQCV28        23.0
# 10                  SQ80C        16.0
# 13                 SQ79DB        14.0
# 3                 PQ135BA        14.0
# 19               PQ135AAG        11.0
# 16                   NQ2C         9.0
# Processing borough: 29
# Splitting data for borough: 29
# Converting data to DMatrix format for borough: 29
# Training model for borough: 29
# [0]	train-rmse:0.76992	test-rmse:0.86743
# [10]	train-rmse:0.39620	test-rmse:0.67824
# [20]	train-rmse:0.32458	test-rmse:0.67231
# [28]	train-rmse:0.27049	test-rmse:0.67973
# Making predictions for borough: 29
# Calculating RMSE for borough: 29
# RMSE for 29: 0.6805820415712001
# Calculating permutation importances for borough: 29
# Calculating Permutation Importance for 29: 100%|██████████| 597/597 [05:36<00:00,  1.77it/s]
# Top 20 Feature Importance for 29:
# NQ135A_newAE: 0.0044
# Q62D: 0.0037
# Month_Number: 0.0027
# White: 0.0024
# Burglary: 0.0023
# IMDQuartile: 0.0022
# NQ135A_newAG: 0.0020
# PQ135AAG: 0.0017
# NQ57AA: 0.0017
# Q3G: 0.0015
# NQ62B: 0.0015
# Violence and sexual offences: 0.0014
# Anti-social behaviour: 0.0013
# Q196C: 0.0012
# PQ135AO: 0.0011
# NQ135BB: 0.0010
# Asian: 0.0010
# ZQ10F: 0.0009
# PQ135AAC: 0.0009
# Q126DB: 0.0008
# [0]	train-rmse:0.82993	test-rmse:0.93029
# [10]	train-rmse:0.65538	test-rmse:0.89831
# [20]	train-rmse:0.60131	test-rmse:0.91454
# [21]	train-rmse:0.60074	test-rmse:0.91607
# RMSE on test set with top features for 29: 0.915001245548804
#                          Feature  Importance
# 2                   Month_Number       128.0
# 8                         NQ57AA       105.0
# 4                       Burglary       103.0
# 1                           Q62D       100.0
# 9                            Q3G        73.0
# 10                         NQ62B        70.0
# 11  Violence and sexual offences        55.0
# 12         Anti-social behaviour        54.0
# 0                   NQ135A_newAE        46.0
# 17                         ZQ10F        45.0
# 15                       NQ135BB        37.0
# 5                    IMDQuartile        32.0
# 19                        Q126DB        26.0
# 7                       PQ135AAG        24.0
# 13                         Q196C        19.0
# 18                      PQ135AAC         9.0
# 16                         Asian         8.0
# 14                       PQ135AO         3.0
# 6                   NQ135A_newAG         2.0
# 3                          White         1.0
# Processing borough: 12
# Splitting data for borough: 12
# Converting data to DMatrix format for borough: 12
# Training model for borough: 12
# [0]	train-rmse:0.73422	test-rmse:0.72849
# [10]	train-rmse:0.37621	test-rmse:0.59993
# [20]	train-rmse:0.29578	test-rmse:0.59873
# [22]	train-rmse:0.28261	test-rmse:0.59681
# Making predictions for borough: 12
# Calculating RMSE for borough: 12
# RMSE for 12: 0.5968130124690624
# Calculating permutation importances for borough: 12
# Calculating Permutation Importance for 12: 100%|██████████| 597/597 [05:40<00:00,  1.75it/s]
# Top 20 Feature Importance for 12:
# Q79E: 0.0076
# NQ62D: 0.0039
# Q60: 0.0029
# Drugs: 0.0027
# Q54B: 0.0025
# Other crime: 0.0023
# Q15: 0.0023
# Criminal damage and arson: 0.0022
# Q3K: 0.0020
# Q136r: 0.0019
# XQ9A: 0.0018
# NQ57AA: 0.0012
# Q196A: 0.0010
# Q62F: 0.0010
# XQ21A: 0.0010
# Q79A: 0.0009
# ZQ10D: 0.0009
# Q62TG: 0.0008
# NQ79BI: 0.0008
# XQ59C: 0.0007
# [0]	train-rmse:0.75621	test-rmse:0.74933
# [10]	train-rmse:0.50909	test-rmse:0.71475
# [15]	train-rmse:0.47904	test-rmse:0.72043
# RMSE on test set with top features for 12: 0.7204306576131888
#                       Feature  Importance
# 3                       Drugs        66.0
# 0                        Q79E        65.0
# 2                         Q60        59.0
# 5                 Other crime        56.0
# 15                       Q79A        50.0
# 1                       NQ62D        49.0
# 8                         Q3K        42.0
# 17                      Q62TG        40.0
# 9                       Q136r        38.0
# 7   Criminal damage and arson        36.0
# 13                       Q62F        33.0
# 4                        Q54B        33.0
# 19                      XQ59C        28.0
# 11                     NQ57AA        28.0
# 6                         Q15        28.0
# 18                     NQ79BI        27.0
# 12                      Q196A        17.0
# 16                      ZQ10D        16.0
# 14                      XQ21A        12.0
# 10                       XQ9A         3.0
# Processing borough: 32
# Splitting data for borough: 32
# Converting data to DMatrix format for borough: 32
# Training model for borough: 32
# [0]	train-rmse:0.70293	test-rmse:0.77264
# [10]	train-rmse:0.36849	test-rmse:0.64945
# [20]	train-rmse:0.30284	test-rmse:0.64926
# [21]	train-rmse:0.29805	test-rmse:0.64785
# Making predictions for borough: 32
# Calculating RMSE for borough: 32
# RMSE for 32: 0.6477699927096968
# Calculating permutation importances for borough: 32
# Calculating Permutation Importance for 32: 100%|██████████| 597/597 [05:43<00:00,  1.74it/s]
# Top 20 Feature Importance for 32:
# Q79H: 0.0072
# Q54A: 0.0053
# Q37: 0.0039
# NQ135B_newB: 0.0029
# Violence and sexual offences: 0.0028
# SQ80E: 0.0027
# Q62H: 0.0026
# Q144: 0.0025
# Q136r: 0.0023
# NQCV16: 0.0023
# ReQ136: 0.0021
# SQ132P: 0.0019
# BQ90B: 0.0015
# NQ44A: 0.0014
# Q54E: 0.0014
# NNQ135A: 0.0012
# NQ62C: 0.0012
# NQ79BC: 0.0011
# NQ79BI: 0.0011
# Q39A_2: 0.0011
# [0]	train-rmse:0.73697	test-rmse:0.81583
# [10]	train-rmse:0.52046	test-rmse:0.76525
# [16]	train-rmse:0.48235	test-rmse:0.77050
# RMSE on test set with top features for 32: 0.7704969174210724
#                          Feature  Importance
# 4   Violence and sexual offences       100.0
# 0                           Q79H        76.0
# 7                           Q144        66.0
# 2                            Q37        48.0
# 1                           Q54A        42.0
# 6                           Q62H        42.0
# 15                       NNQ135A        37.0
# 8                          Q136r        33.0
# 19                        Q39A_2        32.0
# 5                          SQ80E        32.0
# 17                        NQ79BC        30.0
# 18                        NQ79BI        29.0
# 16                         NQ62C        28.0
# 10                        ReQ136        26.0
# 13                         NQ44A        22.0
# 14                          Q54E        14.0
# 11                        SQ132P        11.0
# 12                         BQ90B        11.0
# 3                    NQ135B_newB         9.0
# 9                         NQCV16         6.0
# Processing borough: 19
# Splitting data for borough: 19
# Converting data to DMatrix format for borough: 19
# Training model for borough: 19
# [0]	train-rmse:0.69673	test-rmse:0.67790
# [10]	train-rmse:0.35558	test-rmse:0.59716
# [20]	train-rmse:0.28704	test-rmse:0.60126
# [22]	train-rmse:0.27698	test-rmse:0.60345
# Making predictions for borough: 19
# Calculating RMSE for borough: 19
# RMSE for 19: 0.603301587514639
# Calculating permutation importances for borough: 19
# Calculating Permutation Importance for 19: 100%|██████████| 597/597 [05:43<00:00,  1.74it/s]
# Top 20 Feature Importance for 19:
# Q79D: 0.0095
# Q79C: 0.0043
# Vehicle crime: 0.0037
# Q141: 0.0036
# NNQ27C: 0.0034
# NQCV28: 0.0030
# Q62E: 0.0027
# Q79I: 0.0020
# Q54A: 0.0019
# Q195B: 0.0019
# Q79G: 0.0018
# Other theft: 0.0015
# Possession of weapons: 0.0015
# NQ135BB: 0.0014
# XQ3B: 0.0014
# Public order: 0.0013
# Q21: 0.0012
# NQ57AC: 0.0012
# Drugs: 0.0011
# NQCV27: 0.0011
# [0]	train-rmse:0.73913	test-rmse:0.70036
# [10]	train-rmse:0.53257	test-rmse:0.68819
# [12]	train-rmse:0.51918	test-rmse:0.69475
# RMSE on test set with top features for 19: 0.6947521195782134
#                   Feature  Importance
# 0                    Q79D        66.0
# 11            Other theft        41.0
# 1                    Q79C        38.0
# 7                    Q79I        38.0
# 6                    Q62E        37.0
# 2           Vehicle crime        35.0
# 15           Public order        35.0
# 5                  NQCV28        34.0
# 18                  Drugs        30.0
# 17                 NQ57AC        27.0
# 10                   Q79G        26.0
# 3                    Q141        25.0
# 9                   Q195B        21.0
# 16                    Q21        21.0
# 12  Possession of weapons        18.0
# 14                   XQ3B        17.0
# 4                  NNQ27C        17.0
# 13                NQ135BB        14.0
# 8                    Q54A        14.0
# 19                 NQCV27        13.0
# Processing borough: 30
# Splitting data for borough: 30
# Converting data to DMatrix format for borough: 30
# Training model for borough: 30
# [0]	train-rmse:0.80612	test-rmse:0.93161
# [10]	train-rmse:0.39602	test-rmse:0.76356
# [20]	train-rmse:0.32142	test-rmse:0.77011
# [23]	train-rmse:0.30866	test-rmse:0.77084
# Making predictions for borough: 30
# Calculating RMSE for borough: 30
# RMSE for 30: 0.7708415377752351
# Calculating permutation importances for borough: 30
# Calculating Permutation Importance for 30: 100%|██████████| 597/597 [05:41<00:00,  1.75it/s]
# Top 20 Feature Importance for 30:
# Q62TG: 0.0044
# Anti-social behaviour: 0.0039
# Q79E: 0.0031
# NNQ135A: 0.0027
# Q37: 0.0023
# Other theft: 0.0022
# Violence and sexual offences: 0.0022
# Q79F: 0.0021
# Q79G: 0.0020
# Q195B: 0.0019
# Q79I: 0.0018
# Burglary: 0.0018
# Shoplifting: 0.0017
# ReXQ135: 0.0015
# Q54C: 0.0014
# Q54E: 0.0013
# Black: 0.0012
# Q3C: 0.0011
# NQ62A: 0.0011
# Q62F: 0.0011
# [0]	train-rmse:0.84177	test-rmse:0.96178
# [10]	train-rmse:0.55650	test-rmse:0.90612
# [17]	train-rmse:0.50171	test-rmse:0.91346
# RMSE on test set with top features for 30: 0.9112168232534532
#                          Feature  Importance
# 0                          Q62TG        86.0
# 1          Anti-social behaviour        83.0
# 2                           Q79E        69.0
# 3                        NNQ135A        59.0
# 12                   Shoplifting        51.0
# 8                           Q79G        51.0
# 7                           Q79F        50.0
# 6   Violence and sexual offences        49.0
# 11                      Burglary        47.0
# 10                          Q79I        47.0
# 5                    Other theft        46.0
# 19                          Q62F        45.0
# 4                            Q37        38.0
# 14                          Q54C        32.0
# 15                          Q54E        32.0
# 17                           Q3C        31.0
# 9                          Q195B        30.0
# 18                         NQ62A        25.0
# 13                       ReXQ135        12.0
# 16                         Black        10.0
# Processing borough: 11
# Splitting data for borough: 11
# Converting data to DMatrix format for borough: 11
# Training model for borough: 11
# [0]	train-rmse:0.81576	test-rmse:0.91840
# [10]	train-rmse:0.41160	test-rmse:0.76475
# [20]	train-rmse:0.33629	test-rmse:0.75702
# [30]	train-rmse:0.26967	test-rmse:0.75778
# [31]	train-rmse:0.26579	test-rmse:0.75858
# Making predictions for borough: 11
# Calculating RMSE for borough: 11
# RMSE for 11: 0.7578020418112391
# Calculating permutation importances for borough: 11
# Calculating Permutation Importance for 11: 100%|██████████| 597/597 [05:21<00:00,  1.85it/s]
# Top 20 Feature Importance for 11:
# Q126DA: 0.0041
# XQ59D: 0.0037
# Q14A: 0.0035
# Q62F: 0.0028
# ZQ10I: 0.0027
# NQ57AD: 0.0024
# NNQ27C: 0.0021
# Q3J: 0.0019
# NQ135B_newW: 0.0018
# NQ135BF: 0.0018
# Q14C: 0.0018
# Q39BA: 0.0016
# Q196C: 0.0016
# Q3L: 0.0016
# Q10E: 0.0015
# Q136r: 0.0015
# XQ128A2C: 0.0015
# Q62A: 0.0015
# Q62D: 0.0014
# Q14D: 0.0013
# [0]	train-rmse:0.86887	test-rmse:0.96430
# [10]	train-rmse:0.62963	test-rmse:0.93690
# [15]	train-rmse:0.59410	test-rmse:0.94347
# RMSE on test set with top features for 11: 0.9461566787197898
#         Feature  Importance
# 3          Q62F        82.0
# 7           Q3J        73.0
# 17         Q62A        65.0
# 5        NQ57AD        58.0
# 13          Q3L        54.0
# 18         Q62D        52.0
# 15        Q136r        45.0
# 1         XQ59D        40.0
# 6        NNQ27C        39.0
# 9       NQ135BF        39.0
# 0        Q126DA        34.0
# 12        Q196C        31.0
# 14         Q10E        30.0
# 16     XQ128A2C        28.0
# 4         ZQ10I        19.0
# 2          Q14A        18.0
# 19         Q14D        13.0
# 11        Q39BA        12.0
# 10         Q14C        10.0
# 8   NQ135B_newW         9.0
# Processing borough: 6
# Splitting data for borough: 6
# Converting data to DMatrix format for borough: 6
# Training model for borough: 6
# [0]	train-rmse:0.78121	test-rmse:0.81808
# [10]	train-rmse:0.40741	test-rmse:0.70842
# [18]	train-rmse:0.32645	test-rmse:0.70936
# Making predictions for borough: 6
# Calculating RMSE for borough: 6
# RMSE for 6: 0.7093598660300021
# Calculating permutation importances for borough: 6
# Calculating Permutation Importance for 6: 100%|██████████| 597/597 [05:22<00:00,  1.85it/s]
# Top 20 Feature Importance for 6:
# Possession of weapons: 0.0048
# SQ132AM: 0.0037
# ReXQ135: 0.0026
# NQ62A: 0.0022
# XQ59B: 0.0019
# SQ132G: 0.0019
# NQ135A_newA: 0.0018
# XQ122: 0.0016
# SQ80C: 0.0014
# PQ135AA: 0.0014
# Q3J: 0.0013
# Q3G: 0.0012
# XQ21A: 0.0011
# A120: 0.0011
# NQ136BF: 0.0010
# NQ79BB: 0.0009
# NQ57AC: 0.0009
# ZQ10B: 0.0008
# Q39BD: 0.0008
# Q54E: 0.0008
# [0]	train-rmse:0.86067	test-rmse:0.88073
# [10]	train-rmse:0.63624	test-rmse:0.87193
# [12]	train-rmse:0.62515	test-rmse:0.88049
# RMSE on test set with top features for 6: 0.880349891092527
#                   Feature  Importance
# 0   Possession of weapons       125.0
# 13                   A120        62.0
# 3                   NQ62A        55.0
# 15                 NQ79BB        50.0
# 10                    Q3J        49.0
# 16                 NQ57AC        45.0
# 19                   Q54E        41.0
# 4                   XQ59B        39.0
# 11                    Q3G        35.0
# 17                  ZQ10B        28.0
# 1                 SQ132AM        23.0
# 12                  XQ21A        20.0
# 8                   SQ80C        17.0
# 18                  Q39BD        17.0
# 9                 PQ135AA        14.0
# 7                   XQ122        11.0
# 5                  SQ132G         9.0
# 6             NQ135A_newA         9.0
# 2                 ReXQ135         9.0
# 14                NQ136BF         4.0
# RMSE for all boroughs:
# 18: 0.6881645040152967
# 28: 0.6145868526739416
# 5: 0.6389939941474156
# 22: 0.7393245011914218
# 3: 0.707827684959418
# 13: 0.8127819196980437
# 14: 0.7073465596560545
# 9: 0.7206125594808357
# 7: 0.6705465836665674
# 24: 0.6638154033853801
# 1: 0.6769267646314773
# 15: 0.6649736877614899
# 25: 0.6164045345221422
# 27: 0.7537797593792922
# 21: 0.678771846054679
# 17: 0.6561397438777611
# 10: 0.6268824860255632
# 20: 0.6124377641521
# 23: 0.5608858340739515
# 2: 0.609904880838875
# 26: 0.645632195443362
# 16: 0.655817953457283
# 4: 0.7243295857110669
# 8: 0.6162804029243596
# 31: 0.6343283550962598
# 29: 0.6805820415712001
# 12: 0.5968130124690624
# 32: 0.6477699927096968
# 19: 0.603301587514639
# 30: 0.7708415377752351
# 11: 0.7578020418112391
# 6: 0.7093598660300021
